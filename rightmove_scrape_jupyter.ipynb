# %%
# import the necessary libraries
from bs4 import BeautifulSoup
import requests
import json
import re
import datetime

# %%
# this function handles the situation when the html is embedded within javascript
def javascript_html_parse(source_arg):
	"""Return the JSON object as a dictionary"""
	start = "<script>window.__PRELOADED_STATE__ = "
	end = "</script"
	x = source_arg[source_arg.find(start)+len(start):]
	x = x[:x.find(end)]
	x = json.loads(x)
	return x

# %%
# Obtain all of the URL's that need to be scraped from 
# This is the first URL we start at, here we are collecting all of the URL's to be scraped from into 
# local area URL's 
url = "https://www.rightmove.co.uk/house-prices-in-London.html"
source = requests.get(url).text
soup = BeautifulSoup(source, 'lxml')
b = soup.find_all("a", class_="head")
london_urls = []
for i in b:
	london_urls.append(i["href"])

borough_urls = []
for url in london_urls:
	source = requests.get(url).text
	soup = BeautifulSoup(source, 'lxml')
	b = soup.find_all("a", class_="head")
	for i in b:
		borough_urls.append(i["href"])

local_area_urls = []
for url in borough_urls:
	source = requests.get(url).text
	soup = BeautifulSoup(source, 'lxml')
	b = soup.find_all("a", class_="head")
	for i in b:
		local_area_urls.append(i["href"])

# %%
# iterate over all of the URL's and scrape from them, and store the scraped data into a variable called houses
houses = {}
for area_url in local_area_urls[:2]:

	# while loop that obtains the address, property type, last sold price, last sold date, and its url (if it has one) from each house. 
	# Stores each value into a list. This is from the web page which shows different houses from a particular area.

	page_number = 1
	addresses, property_type, last_sold_price, last_sold_date, url = [], [], [], [], []
	#bush_hill_url = "https://www.rightmove.co.uk/house-prices/bush-hill-park.html"
	# obtain the number of pages to use in the while loop condition
	source = requests.get(area_url).text
	a = javascript_html_parse(source)
	num_pages = a["pagination"]["last"]
	#houses = {}
	while page_number <= num_pages:

		if page_number == 1:
			source = requests.get(area_url).text
		else:
			source = requests.get(area_url+f"?page={page_number}").text

		# all we want to extract is the address, the price & date of the last sale, and the URL.
		x = javascript_html_parse(source)
		for house in x["results"]["properties"]:
			addresses.append(house["address"])
			property_type.append(house["propertyType"])
			last_sold_price.append(house["transactions"][0]["displayPrice"])
			last_sold_date.append(house["transactions"][0]["dateSold"])
			url.append(house["detailUrl"])



		page_number += 1


	# Create a dictionary with all of the scraped info stored in it so far
	#houses = {}
	for i in range(len(addresses)):
		houses[addresses[i]] = {"property_type":property_type[i], "price":last_sold_price[i], "date":last_sold_date[i], "url": url[i]}




	for v in houses.values():
		if v['url'] == '':
			continue
		else:
			source = requests.get(v['url']).text
			soup = BeautifulSoup(source, 'lxml')
			script = soup.find("script", {"type":"text/javascript"}).text
			# Regex used to convert the JSON data structure into a python dict 
			# Use regex to extract json data from the script text
			json_script=re.findall(("(?s)(?<=window.PAGE_MODEL = )(.*$)"), script)[0]
			# Transforming json data within string into dictionary
			json_dict=json.loads(json_script)

			# The bullet pointed features # 
			try:
				features = json_dict["soldPropertyData"]["property"]["keyFeatures"]
			except TypeError: 
				pass
			else:
				v["features"] = features
			# got the floorplan URL
			try:
				floorplan_url = json_dict["soldPropertyData"]["property"]["floorplans"][0]['url']
			except Exception:
				# seen a TypeError and an IndexError
				pass
			else:
				v["floorplan_url"] = floorplan_url	
			# Scrape the pictures of the house ## commented this out for now, as I'm not using the images
			#house_image_urls = []
			#for image in json_dict["soldPropertyData"]["property"]["images"]:
			#	house_image_urls.append(image['url'])
			#v["house_image_urls"] = house_image_urls
			# location of the house
			latitude = json_dict["soldPropertyData"]["property"]["location"]["latitude"]
			longitude = json_dict["soldPropertyData"]["property"]["location"]["longitude"]
			v["latitude"] = latitude
			v["longitude"] = longitude
			# proximity to the stations
			station_names, distances = [], []
			for station in json_dict["soldPropertyData"]["property"]["nearestStations"]:
				station_names.append(station["name"])
				distances.append(station["distance"])
			station_proximities = {station:distance for station, distance in zip(station_names, distances)}
			v["station_proximities"] = station_proximities
			# size of the property
			units, sizes = [], []
			for i in json_dict["soldPropertyData"]["property"]["sizings"]:
				units.append(i['unit'])
				sizes.append(i['maximumSize'])
			dimensions = {unit:size for unit, size in zip(units, sizes)}
			v["property_size"] = dimensions

			# number of bedrooms and bathrooms
			bedrooms = json_dict["soldPropertyData"]["property"]['bedrooms']
			bathrooms = json_dict["soldPropertyData"]["property"]['bathrooms']
			v["bedrooms"] = bedrooms
			v["bathrooms"] = bathrooms

			# Whether the property is a new build or not
			new_build = json_dict["soldPropertyData"]["transactions"][0]['newBuild']
			v["new_build"] = new_build

# %%
houses
# Out:
# {'105, Canonsleigh Road, Dagenham, Greater London RM9 4DH': {'property_type': 'Terraced',
#   'price': '£390,000',
#   'date': '16 May 2022',
#   'url': ''},
#  '59, Bateman Close, Barking, Greater London IG11 8QS': {'property_type': 'Flat',
#   'price': '£225,000',
#   'date': '12 May 2022',
#   'url': 'https://www.rightmove.co.uk/house-prices/details/england-123105338-14974252?s=791fe9e857a8dea92f2d04177af0a010ed90647d8449404cd8f3099af0e6d49f',
#   'features': [],
#   'floorplan_url': 'https://media.rightmove.co.uk/60k/59646/123105338/59646_CW0434_FLP_00_0000.jpeg',
#   'latitude': 51.54126,
#   'longitude': 0.08243,
#   'station_proximities': {'Barking Station': 0.14006575393753187,
#    'Upney Station': 0.8457992920654402,
#    'Ilford Station': 1.3208233936340128},
#   'property_size': {'ac': 0.01, 'ha': 0, 'sqft': 506, 'sqm': 47},
#   'bedrooms': 1,
#   'bathrooms': 1,
#   'new_build': False},
#  '54, Greenslade Road, Barking, Greater London IG11 9XE': {'property_type': 'Flat',
#   'price': '£241,000',
#   'date': '11 May 2022',
#   'url': 'https://www.rightmove.co.uk/house-prices/details/england-115102496-14974342?s=fb8af65fb80afb811abebb05215fd28bcdff9193da6b48bc501dcafc411ba4ac',
#   'features': ['EPC RATING D',
#    'Two bedrooms',
#    'Lounge',
#    'Kitchen',
#    'Bathroom',
#    'Parking',
#    'Close to Barking Station',
#    'Lease 164 years'],
#   'latitude': 51.538168,
#   'longitude': 0.089375,
#   'station_proximities': {'Barking Station': 0.34386191509746006,
#    'Upney Station': 0.5216595998294455,
#    'East Ham Station': 1.6301863560020884},
#   'property_size': {},
#   'bedrooms': 2,
#   'bathrooms': 1,
#   'new_build': False},
#  '21, Felton Road, Barking, Greater London IG11 7XZ': {'property_type': 'Terraced',
#   'price': '£435,000',
#   'date': '10 May 2022',
#   'url': 'https://www.rightmove.co.uk/house-prices/details/england-114572909-14974216?s=e0e73f3737db9e443df7a9d41022456ec205747086c32884e5c7ed295cb34da6',
#   'features': ['EPC - D',
#    'Side access',
#    'End terraced house',
#    'Three bedrooms',
#    'Large reception',
#    'Kitchen/Diner',
#    'Gas central heating',
#    'Double glazing'],
#   'floorplan_url': 'https://media.rightmove.co.uk/14k/13345/114572909/13345_31014351_FLP_00_0001.jpeg',
#   'latitude': 51.531142,
#   'longitude': 0.093814,
#   'station_proximities': {'Upney Station': 0.5961229381400764,
#    'Barking Station': 0.7714892849810918,
#    'Becontree Station': 1.5597990404450608},
#   'property_size': {},
#   'bedrooms': 3,
#   'bathrooms': 1,
#   'new_build': False},
#  '28, Sparsholt Road, Barking, Greater London IG11 7YQ': {'property_type': 'Terraced',
#   'price': '£337,000',
#   'date': '29 Apr 2022',
#   'url': 'https://www.rightmove.co.uk/house-prices/details/england-120065753-14974225?s=1fe88f997bfaa202d7ad1789b68eebb3c6bd7ea562dad14d7d8ca3c00523bd2d',
#   'features': ["FOR SALE BY ONLINE AUCTION T&amp;C'S APPLY",
#    'Fantastic size living space',
#    'Lovely size lounge/diner',
#    'Modern Kitchen',
#    'Modern Bathroom',
#    'Separate WC',
#    'Nice Size Rear Garden',
#    '0.5 miles to Upney station and 0.6 miles to Barking station',
#    'Great investment with a potential yield of 5.9%'],
#   'floorplan_url': 'https://media.rightmove.co.uk/75k/74660/120065753/74660_393158_FLP_00_0000.jpeg',
#   'latitude': 51.53375,
#   'longitude': 0.09174,
#   'station_proximities': {'Upney Station': 0.5252772877650792,
#    'Barking Station': 0.5814680261545995,
#    'Becontree Station': 1.5820836475328188},
#   'property_size': {},
#   'bedrooms': 2,
#   'bathrooms': None,
#   'new_build': False},
#  '36, Halsham Crescent, Barking, Greater London IG11 9HG': {'property_type': 'Terraced',
#   'price': '£500,000',
#   'date': '14 Apr 2022',
#   'url': 'https://www.rightmove.co.uk/house-prices/details/england-112852988-92994882?s=917f38af7b974ef5309fe5d6733a7c7b33734cb5526f69470334fd49cc06ba8e',
#   'features': ['LEFTLEY ESTATE',
#    'THREE BEDROOM TERRACE HOUSE',
#    'TWO RECEPTION ROOMS',
#    'GOOD SIZE GARDEN',
#    'GREAT LOCATION',
#    'CATCHMENT AREA FOR MANOR SCHOOL'],
#   'latitude': 51.54652,
#   'longitude': 0.10012,
#   'station_proximities': {'Upney Station': 0.5699910847643922,
#    'Barking Station': 0.9413842456733089,
#    'Seven Kings Station': 1.1818231602745783},
#   'property_size': {},
#   'bedrooms': 3,
#   'bathrooms': 1,
#   'new_build': False},
#  '10a, Sandringham Road, Barking, Greater London IG11 9AA': {'property_type': 'Semi-Detached',
#   'price': '£645,000',
#   'date': '14 Apr 2022',
#   'url': 'https://www.rightmove.co.uk/house-prices/details/england-113907608-14974270?s=1cb2cd4d9884ef7edef8f8e670dcc00ff1ed6184a1c7a992587d2dc3bcbdbb82',
#   'features': ['EPC RATING D',
#    'Three bedrooms',
#    'One reception room',
#    'Kitchen',
#    'Bathroom',
#    'Garden',
#    'Double garage'],
#   'floorplan_url': 'https://media.rightmove.co.uk/14k/13345/113907608/13345_30975020_FLP_00_0002.jpeg',
#   'latitude': 51.541494,
#   'longitude': 0.098756,
#   'station_proximities': {'Upney Station': 0.24872581115434403,
#    'Barking Station': 0.7547301668936481,
#    'Becontree Station': 1.2185546139356807},
#   'property_size': {},
#   'bedrooms': 3,
#   'bathrooms': 2,
#   'new_build': False},
#  '60, Wedderburn Road, Barking, Greater London IG11 7XG': {'property_type': 'Terraced',
#   'price': '£405,000',
#   'date': '14 Apr 2022',
#   'url': 'https://www.rightmove.co.uk/house-prices/details/england-52948397-92994828?s=a309abe85f55987c1ccb7c22c2ca0f6e0828295459737b692814a492cf48de38',
#   'features': ['GCH',
#    'Excellent Condition',
#    'Double Glazing',
#    'Garden',
#    'Wooden Floors',
#    'SOLE AGENTS'],
#   'latitude': 51.53403,
#   'longitude': 0.08988,
#   'station_proximities': {'Barking Station': 0.5098781241574322,
#    'Upney Station': 0.5812033463890981,
#    'Becontree Station': 1.6540886256549543},
#   'property_size': {},
#   'bedrooms': 3,
#   'bathrooms': None,
#   'new_build': False},
#  '33, Westminster Gardens, Barking, Greater London IG11 0BJ': {'property_type': 'Terraced',
#   'price': '£390,000',
#   'date': '14 Apr 2022',
#   'url': 'https://www.rightmove.co.uk/house-prices/details/england-52658818-92994789?s=288d439e47c63d252304eba8af6627d23d80e05f4afc2d0b66344d119b049803',
#   'features': ['first floor bathroom',
#    'Fitted Kitchen',
#    'Ideal Family Home',
#    'Large private rear garden',
#    'Must be seen ',
#    'Newly refurbished property ',
#    'No Ground Rent',
#    'No Onward Chain',
#    'Off-street parking',
#    'Sought After Location'],
#   'floorplan_url': 'https://media.rightmove.co.uk/46k/45641/52658818/45641_RS0048_FLP_01_0000.jpg',
#   'latitude': 51.528289,
#   'longitude': 0.089402,
#   'station_proximities': {'Barking Station': 0.832241141350607,
#    'Upney Station': 0.8671630349044476,
#    'Beckton Station': 1.5334639362038498},
#   'property_size': {},
#   'bedrooms': 3,
#   'bathrooms': 2,
#   'new_build': False},
#  '29, Edgefield Avenue, Barking, Greater London IG11 9JL': {'property_type': 'Terraced',
#   'price': '£515,000',
#   'date': '8 Apr 2022',
#   'url': 'https://www.rightmove.co.uk/house-prices/details/england-121862396-92994888?s=fd9029ec9aa9ed7353c517e7a7038b69faff7d36300913b257abfa5eb9f3179b',
#   'features': [],
#   'latitude': 51.53912,
#   'longitude': 0.103353,
#   'station_proximities': {'Upney Station': 0.09824976396690367,
#    'Barking Station': 0.9376520333844574,
#    'Becontree Station': 1.0198116402067932},
#   'property_size': {},
#   'bedrooms': 3,
#   'bathrooms': None,
#   'new_build': False},
#  '164, Park Avenue, Barking, Greater London IG11 8QY': {'property_type': 'Terraced',
#   'price': '£530,000',
#   'date': '8 Apr 2022',
#   'url': 'https://www.rightmove.co.uk/house-prices/details/england-51746176-92994861?s=5a780d399bc19659f402dba1ebb59cd8174776b06ad0b790a8924d74d4cf287c',
#   'features': [],
#   'floorplan_url': 'https://media.rightmove.co.uk/1k/218/51746176/218_BAR150376_FLP_00_0000.JPG',
#   'latitude': 51.54401,
#   'longitude': 0.07952,
#   'station_proximities': {'Barking Station': 0.3379233592816707,
#    'Upney Station': 1.0249779777248265,
#    'Ilford Station': 1.0960083062163342},
#   'property_size': {},
#   'bedrooms': 3,
#   'bathrooms': None,
#   'new_build': False},
#  '94, Bastable Avenue, Barking, Greater London IG11 0LF': {'property_type': 'Flat',
#   'price': '£260,000',
#   'date': '8 Apr 2022',
#   'url': 'https://www.rightmove.co.uk/house-prices/details/england-109820012-14974165?s=4bd7096afbb213554a3c080e5954430735a9cf5df784927f9bc041c5ebf82ae4',
#   'features': [],
#   'floorplan_url': 'https://media.rightmove.co.uk/75k/74746/109820012/74746_102491002028_FLP_00_0000.png',
#   'latitude': 51.52776,
#   'longitude': 0.09868,
#   'station_proximities': {'Upney Station': 0.7400455046313016,
#    'Barking Station': 1.0856680536134722,
#    'Becontree Station': 1.4917201908735183},
#   'property_size': {'sqm': 77, 'ac': 0.02, 'ha': 0.01, 'sqft': 833},
#   'bedrooms': 2,
#   'bathrooms': 1,
#   'new_build': False},
#  '127, Fanshawe Avenue, Barking, Greater London IG11 8RF': {'property_type': 'Terraced',
#   'price': '£450,000',
#   'date': '8 Apr 2022',
#   'url': 'https://www.rightmove.co.uk/house-prices/details/england-113843432-14974255?s=e9e666710babc3dcdb9ebe596efcc817c378009c842658392167879d8072e26a',
#   'features': ['FOUR BEDROOM VICTORIAN PROPERTY',
#    'REQUIRES FULL MODERNISATION',
#    'CLOSE TO BARKING STATION',
#    'CHAIN FREE',
#    'CLOSE TO LOCAL AMENITIES',
#    'BUS ROUTES'],
#   'floorplan_url': 'https://media.rightmove.co.uk/4k/3886/113843432/3886_BKG103028_FLP_00_0000.jpeg',
#   'latitude': 51.54266,
#   'longitude': 0.07975,
#   'station_proximities': {'Barking Station': 0.24578917611864165,
#    'Upney Station': 0.9834576898684728,
#    'Ilford Station': 1.1860461701933986},
#   'property_size': {},
#   'bedrooms': 4,
#   'bathrooms': 1,
#   'new_build': False},
#  'Flat 29, St Aidans Court, Blessing Way, Barking, Greater London IG11 0XH': {'property_type': 'Flat',
#   'price': '£200,000',
#   'date': '4 Apr 2022',
#   'url': 'https://www.rightmove.co.uk/house-prices/details/england-87964106-14974177?s=f176e14859ff2fd90bfa35054ab2f305f864da9fca1f267a45b57b57416742b9',
#   'features': [],
#   'floorplan_url': 'https://media.rightmove.co.uk/1k/218/87964106/218_BAR190118_FLP_01_0000.jpg',
#   'latitude': 51.52688,
#   'longitude': 0.11738,
#   'station_proximities': {'Becontree Station': 1.009110073824787,
#    'Upney Station': 1.0471651616276645,
#    'Dagenham Dock Station': 1.2494810416646394},
#   'property_size': {},
#   'bedrooms': 2,
#   'bathrooms': 1,
#   'new_build': False},
#  '405, Lodge Avenue, Dagenham, Greater London RM9 4QD': {'property_type': 'Terraced',
#   'price': '£189,400',
#   'date': '1 Apr 2022',
#   'url': ''},
#  '32, Sparsholt Road, Barking, Greater London IG11 7YQ': {'property_type': 'Terraced',
#   'price': '£325,000',
#   'date': '31 Mar 2022',
#   'url': 'https://www.rightmove.co.uk/house-prices/details/england-113118203-92994834?s=9cda147e83cd6dd287ef974a9077b85132146f1a57583983cf557d3dd17634f6',
#   'features': ['Two bedrooms',
#    'Great for first time buyer / investor house.',
#    'Located close by A13',
#    'Popular location'],
#   'floorplan_url': 'https://media.rightmove.co.uk/1k/218/113118203/218_BAR210259_FLP_00_0000.jpeg',
#   'latitude': 51.53373,
#   'longitude': 0.0916,
#   'station_proximities': {'Upney Station': 0.530937948871915,
#    'Barking Station': 0.5778671239983861,
#    'Becontree Station': 1.5882661865596484},
#   'property_size': {},
#   'bedrooms': 2,
#   'bathrooms': 1,
#   'new_build': False},
#  '13, Shirley Gardens, Barking, Greater London IG11 9UZ': {'property_type': 'Terraced',
#   'price': '£500,000',
#   'date': '31 Mar 2022',
#   'url': ''},
#  '16, Fairfield Road, Ilford, Greater London IG1 2JL': {'property_type': 'Terraced',
#   'price': '£510,000',
#   'date': '30 Mar 2022',
#   'url': 'https://www.rightmove.co.uk/house-prices/details/england-65174661-14973853?s=9cd589c64d020ab74b6938eec5586cfa327679429b975fc1ccb4d83f1c5f1f94',
#   'features': ['FOUR BEDROOM MID TERRACE HOUSE',
#    'TWO RECEPTION ROOM',
#    'TWO BATHROOM',
#    'LARGE KITCHEN/DINNER',
#    'EXCEPTIONALLY LARGE OUTHOUSE',
#    'EXCELLENT CONDITION THROUGHOUT',
#    'PERFECT FAMILY HOME',
#    'CLOSE TO A VAST ARRAY SHOPS AND RESTAURANTS',
#    'CLOSE ILFORD &amp; BARKING TRAIN STATION'],
#   'latitude': 51.544511,
#   'longitude': 0.074814,
#   'station_proximities': {'Barking Station': 0.4644385106912864,
#    'Ilford Station': 0.9993493362909769,
#    'East Ham Station': 1.061148168400449},
#   'property_size': {},
#   'bedrooms': 4,
#   'bathrooms': 2,
#   'new_build': False},
#  '20, Faircross Mansions, Longbridge Road, Barking, Greater London IG11 8UP': {'property_type': 'Flat',
#   'price': '£228,000',
#   'date': '30 Mar 2022',
#   'url': ''},
#  '420, Lodge Avenue, Dagenham, Greater London RM9 4QU': {'property_type': 'Terraced',
#   'price': '£410,000',
#   'date': '29 Mar 2022',
#   'url': ''},
#  '408, Lodge Avenue, Dagenham, Greater London RM9 4QU': {'property_type': 'Terraced',
#   'price': '£390,000',
#   'date': '28 Mar 2022',
#   'url': 'https://www.rightmove.co.uk/house-prices/details/england-121862465-93088068?s=2e46d60727e1fad410c31c2121b07dbd8382c8f295651cec2a523b0c9b01de79',
#   'features': [],
#   'floorplan_url': 'https://media.rightmove.co.uk/1k/232/121862465/232_DAG200427_FLP_00_0000.jpeg',
#   'latitude': 51.536049,
#   'longitude': 0.111575,
#   'station_proximities': {'Upney Station': 0.463184329534941,
#    'Becontree Station': 0.7220639783737582,
#    'Barking Station': 1.3115584889524814},
#   'property_size': {},
#   'bedrooms': 2,
#   'bathrooms': 1,
#   'new_build': False},
#  '3, Chilworth Place, Barking, Greater London IG11 0FL': {'property_type': 'Terraced',
#   'price': '£302,000',
#   'date': '25 Mar 2022',
#   'url': ''},
#  '14, Lyndhurst Gardens, Barking, Greater London IG11 9YB': {'property_type': 'Terraced',
#   'price': '£520,000',
#   'date': '25 Mar 2022',
#   'url': 'https://www.rightmove.co.uk/house-prices/details/england-115507229-14974348?s=fb81c898f1435f99e39376f58f9f43e12e8224c8a5f9067284bb174bbfdabe73',
#   'features': ['EPC RATING - C',
#    'THREE BEDROOMS',
#    'TWO RECEPTION ROOMS',
#    'FIRST FLOOR BATHROOM',
#    'GOOD SZIE GARDEN',
#    'SPACIOUS GARDEN',
#    'DOUBLE GLAZED WINDOWS'],
#   'floorplan_url': 'https://media.rightmove.co.uk/14k/13345/115507229/13345_31062102_FLP_00_0000.jpeg',
#   'latitude': 51.543991,
#   'longitude': 0.091938,
#   'station_proximities': {'Upney Station': 0.5680651324499264,
#    'Barking Station': 0.5509368062395386,
#    'Seven Kings Station': 1.3649051924939533},
#   'property_size': {},
#   'bedrooms': 3,
#   'bathrooms': 1,
#   'new_build': False},
#  '2, Cecil Avenue, Barking, Greater London IG11 9TA': {'property_type': 'Terraced',
#   'price': '£530,000',
#   'date': '24 Mar 2022',
#   'url': 'https://www.rightmove.co.uk/house-prices/details/england-108631253-14974333?s=d2f4054be45d25d382745b8d579f90d5591d2f76e9ea096d6fd67b0ca2b23ec2',
#   'features': ['EPC RATING - E',
#    'DOUBLE GLAZED WINDOWS',
#    'BASEMENT',
#    'GAS CENTRAL HEATING',
#    'REAR ACCESS TO GARDEN',
#    'FOUR BEDROOM HOUSE',
#    'END TERRACE',
#    'TWO LARGE RECEPTION ROOMS.'],
#   'floorplan_url': 'https://media.rightmove.co.uk/14k/13345/108631253/13345_30723151_FLP_00_0001.jpeg',
#   'latitude': 51.540587,
#   'longitude': 0.084162,
#   'station_proximities': {'Barking Station': 0.14152370339756776,
#    'Upney Station': 0.7626109116027343,
#    'East Ham Station': 1.405684005311977},
#   'property_size': {},
#   'bedrooms': 4,
#   'bathrooms': 1,
#   'new_build': False},
#  '157, Maplestead Road, Dagenham, Greater London RM9 4XU': {'property_type': 'Terraced',
#   'price': '£338,500',
#   'date': '23 Mar 2022',
#   'url': 'https://www.rightmove.co.uk/house-prices/details/england-59626675-15075376?s=20f0880c7ec7dc22907c7fa3aa8f2ecbf6caf41130e0ee3b641540a19cda3512',
#   'features': ['Three  Bedrooms',
#    'Terraced House',
#    'Lounge Dining ',
#    'Fitted Kitchen',
#    'Garden',
#    'Two Toilets',
#    'Three Piece Bathroom',
#    'Off Road Parking'],
#   'floorplan_url': 'https://media.rightmove.co.uk/152k/151079/59626675/151079_223115-1_FLP_07_0000.gif',
#   'latitude': 51.533498,
#   'longitude': 0.114764,
#   'station_proximities': {'Upney Station': 0.6631982072348066,
#    'Becontree Station': 0.700325420617907,
#    'Dagenham Dock Station': 1.4544425059528812},
#   'property_size': {},
#   'bedrooms': 3,
#   'bathrooms': 1,
#   'new_build': False},
#  '370a, Longbridge Road, Barking, Greater London IG11 9EF': {'property_type': 'Flat',
#   'price': '£260,000',
#   'date': '22 Mar 2022',
#   'url': 'https://www.rightmove.co.uk/house-prices/details/england-8660586-14974294?s=fd93cd34aedf9083f550bd71bf8efadcc013e3c97a393e77562c82d935297ca0',
#   'features': ['Laminated Flooring',
#    '2 Large Bedrooms',
#    'Study Room',
#    'New Fitted Kitchen',
#    'New Bathroom',
#    'Good Condition',
#    'No Chain',
#    'Communal Gardens',
#    'Close To Barking Station',
#    'Ideal For 1st Time Buyers'],
#   'latitude': 51.54866,
#   'longitude': 0.10166,
#   'station_proximities': {'Upney Station': 0.7150342372374018,
#    'Seven Kings Station': 1.046127257703796,
#    'Barking Station': 1.079914742808776},
#   'property_size': {},
#   'bedrooms': 2,
#   'bathrooms': None,
#   'new_build': False},
#  '16, Sutton Road, Barking, Greater London IG11 7YD': {'property_type': 'Terraced',
#   'price': '£307,500',
#   'date': '21 Mar 2022',
#   'url': ''},
#  '94, Waterside Close, Barking, Greater London IG11 9EQ': {'property_type': 'Flat',
#   'price': '£265,000',
#   'date': '18 Mar 2022',
#   'url': 'https://www.rightmove.co.uk/house-prices/details/england-107667539-14974297?s=146d2eed88b3111d835db2f70ae40a366653b9cd99ef8c7d98b3a6bd38654f32',
#   'features': ['TWO BEDROOM MAISONETTE',
#    'CHAIN FREE',
#    'COMMUNAL GARDENS',
#    'ALLOCATED PARKING SPACE',
#    'CLOSE TO TRANSPORT LINKS AND AMENITIES'],
#   'floorplan_url': 'https://media.rightmove.co.uk/4k/3886/107667539/3886_BKG102836_FLP_01_0000.jpeg',
#   'latitude': 51.55008,
#   'longitude': 0.10749,
#   'station_proximities': {'Upney Station': 0.8535964991823323,
#    'Seven Kings Station': 1.0343003587199844,
#    'Goodmayes Station': 1.0750775911358563},
#   'property_size': {},
#   'bedrooms': 2,
#   'bathrooms': 1,
#   'new_build': False},
#  '382, Lodge Avenue, Dagenham, Greater London RM9 4QX': {'property_type': 'Terraced',
#   'price': '£357,000',
#   'date': '18 Mar 2022',
#   'url': 'https://www.rightmove.co.uk/house-prices/details/england-115494677-15075370?s=ce5568208de729141fdab3ba4270054468a3491d17a10381520e9b5097571fcd',
#   'features': ['Three Bedroom Terrace House',
#    'Mid-Terraced House',
#    'Family Bathroom',
#    'One Reception',
#    'Double Glazed &amp; Gas Central Heating',
#    'Private Rear Garden',
#    'Potential To Extend (STPP)'],
#   'floorplan_url': 'https://media.rightmove.co.uk/203k/202751/115494677/202751_1266758-1_FLP_00_0000.jpeg',
#   'latitude': 51.537264,
#   'longitude': 0.11209,
#   'station_proximities': {'Upney Station': 0.46373903682763523,
#    'Becontree Station': 0.6717586020978101,
#    'Barking Station': 1.321858627572797},
#   'property_size': {},
#   'bedrooms': 3,
#   'bathrooms': 1,
#   'new_build': False},
#  '254, Stamford Road, Dagenham, Greater London RM9 4EJ': {'property_type': 'Terraced',
#   'price': '£345,000',
#   'date': '16 Mar 2022',
#   'url': 'https://www.rightmove.co.uk/house-prices/details/england-114224180-93088053?s=45797d911004150be68ca7e8669dc9ae7b8ae75b9acf64e80186739487b54ada',
#   'features': ['Two Bedroom Mid Terraced Property',
#    'First Floor Shower Room',
#    'Well Maintained Throughout',
#    'Off Street Parking',
#    'No Onward Chain',
#    'Close To Becontree Station'],
#   'floorplan_url': 'https://media.rightmove.co.uk/203k/202751/114224180/202751_1252686-1_FLP_00_0000.jpeg',
#   'latitude': 51.535807,
#   'longitude': 0.115109,
#   'station_proximities': {'Becontree Station': 0.5937586647679007,
#    'Upney Station': 0.613281232826402,
#    'Dagenham Heathway Station': 1.4588073348148916},
#   'property_size': {},
#   'bedrooms': 2,
#   'bathrooms': 1,
#   'new_build': False},
#  'Flat 6, Victory Court, Atlantis Close, Barking, Greater London IG11 0GP': {'property_type': 'Flat',
#   'price': '£248,000',
#   'date': '11 Mar 2022',
#   'url': 'https://www.rightmove.co.uk/house-prices/details/england-116231291-92994795?s=f73f6786dda27898bd0806ead21439af15a9e28cd79b7d29012bccdbc3c56a6e',
#   'features': ['2nd Floor flat set in a secure development',
#    'Delightful reception with a Juliette balcony',
#    'Separate kitchen with integrated appliances',
#    '2 Double bedrooms',
#    'Modern bathroom'],
#   'floorplan_url': 'https://media.rightmove.co.uk/182k/181043/116231291/181043_1188722_FLP_00_0000.png',
#   'latitude': 51.52235,
#   'longitude': 0.111355,
#   'station_proximities': {'Upney Station': 1.1837250893492084,
#    'Becontree Station': 1.4054333167392936,
#    'Dagenham Dock Station': 1.5300990261489877},
#   'property_size': {'sqft': 599, 'ha': 0.01, 'sqm': 56, 'ac': 0.01},
#   'bedrooms': 2,
#   'bathrooms': 1,
#   'new_build': False},
#  '52, Capel Gardens, Ilford, Greater London IG3 9DG': {'property_type': 'Terraced',
#   'price': '£540,000',
#   'date': '7 Mar 2022',
#   'url': 'https://www.rightmove.co.uk/house-prices/details/england-43058264-14974486?s=b969950deddc27687ddc83559c5eae4edb42f5baab31165c1a00b59437275e6d',
#   'features': ['Beautiful three bedroom ',
#    'Two receptions',
#    'Newly refurbished',
#    'Black gloss fully fitted kitchen open plan to lounge',
#    'Ground floor guest W/C',
#    'Landscaped garden and built in shed',
#    'Neutral decor throughout',
#    'Gas central heating, double glazed',
#    'Off street parking',
#    'Close to barking tube and Seven Kings Rail Station'],
#   'latitude': 51.55072,
#   'longitude': 0.10175,
#   'station_proximities': {'Upney Station': 0.8575167212809995,
#    'Seven Kings Station': 0.9078260316660406,
#    'Goodmayes Station': 1.0932723365051582},
#   'property_size': {},
#   'bedrooms': 3,
#   'bathrooms': 2,
#   'new_build': False},
#  '31, Bateman Close, Barking, Greater London IG11 8QR': {'property_type': 'Flat',
#   'price': '£240,000',
#   'date': '7 Mar 2022',
#   'url': 'https://www.rightmove.co.uk/house-prices/details/england-54611797-14974246?s=2f409d0b57aa70b6b38335a7f37a9bf5aa205bd75e79a39c129f49b3a8306d8c',
#   'features': ['ONE BEDROOM',
#    'FIRST FLOOR',
#    'DOUBLE BEDROOM',
#    'WALKING DISTANCE TO STATION',
#    'CLOSE TO SCHOOLS',
#    'CHAIN FREE'],
#   'floorplan_url': 'https://media.rightmove.co.uk/12k/11664/54611797/11664_0041_HRT004111612_FLP_01_0001.JPG',
#   'latitude': 51.54128,
#   'longitude': 0.08142,
#   'station_proximities': {'Barking Station': 0.13715729068976681,
#    'Upney Station': 0.8884528194164957,
#    'East Ham Station': 1.2916589213582352},
#   'property_size': {},
#   'bedrooms': 1,
#   'bathrooms': 1,
#   'new_build': False},
#  '90, Lambourne Road, Barking, Greater London IG11 9QA': {'property_type': 'Terraced',
#   'price': '£340,000',
#   'date': '4 Mar 2022',
#   'url': 'https://www.rightmove.co.uk/house-prices/details/england-112610513-14974318?s=662a2cef26de3f49ab920192bb89c4619034836870fe414b8498116144a8d623',
#   'features': ['ClOSE TO UPNEY STATION',
#    'TWO BEDROOMS',
#    'LOUNGE',
#    'DINER',
#    'KITCHEN',
#    'FIRST FLOOR BATHROOM',
#    'FF WC',
#    'REAR GARDEN',
#    'NO ONWARD CHAIN',
#    'IDEAL FIRST HOME'],
#   'latitude': 51.537578,
#   'longitude': 0.098592,
#   'station_proximities': {'Upney Station': 0.1342919849954579,
#    'Barking Station': 0.7419026453142522,
#    'Becontree Station': 1.2357615119066938},
#   'property_size': {},
#   'bedrooms': 2,
#   'bathrooms': 1,
#   'new_build': False},
#  '2, Lupin Crescent, Ilford, Greater London IG1 2JR': {'property_type': 'Terraced',
#   'price': '£440,000',
#   'date': '4 Mar 2022',
#   'url': 'https://www.rightmove.co.uk/house-prices/details/england-19764388-14973856?s=b528c10e63636eac0839ca3b150e79292d66eab65d60075592e9e92b614c0004',
#   'features': ['Fully Furnished',
#    'Shops and amenities nearby',
#    'Fitted Kitchen',
#    'Double glazing',
#    'Close to public transport',
#    'Garden',
#    'Parking'],
#   'latitude': 51.54433,
#   'longitude': 0.07204,
#   'station_proximities': {'Barking Station': 0.5396715649904265,
#    'East Ham Station': 0.9446605884298649,
#    'Ilford Station': 0.9913738644344926},
#   'property_size': {},
#   'bedrooms': 4,
#   'bathrooms': None,
#   'new_build': False},
#  'Flat 114, Academy Court, 566, Longbridge Road, Dagenham, Greater London RM8 2AR': {'property_type': 'Flat',
#   'price': '£240,000',
#   'date': '28 Feb 2022',
#   'url': ''},
#  '35, Ridley Close, Barking, Greater London IG11 9PJ': {'property_type': 'Flat',
#   'price': '£285,000',
#   'date': '25 Feb 2022',
#   'url': 'https://www.rightmove.co.uk/house-prices/details/england-113049578-14974315?s=55197aad147ed5207aaca850768ff80e4e757f8fed24489a9e0f7e1aa94c42bb',
#   'features': ['Great investment',
#    'Great first time purchase',
#    'Local to Upney station',
#    '110 year lease (Approx to be confirmed) ',
#    'En-suite to main bedroom',
#    'Fantastic transport links'],
#   'floorplan_url': 'https://media.rightmove.co.uk/1k/218/113049578/218_BAR210252_FLP_00_0000.jpeg',
#   'latitude': 51.53998,
#   'longitude': 0.09909,
#   'station_proximities': {'Upney Station': 0.15397375174994432,
#    'Barking Station': 0.7552047598353046,
#    'Becontree Station': 1.2009796102388153},
#   'property_size': {},
#   'bedrooms': 2,
#   'bathrooms': 2,
#   'new_build': False},
#  '73, Westbury Road, Barking, Greater London IG11 7PL': {'property_type': 'Flat',
#   'price': '£203,000',
#   'date': '25 Feb 2022',
#   'url': 'https://www.rightmove.co.uk/house-prices/details/england-112583789-14974198?s=7633c1bb8ddc95b99c8d123f98605bf3c49ac4efd37c356fbae31b40b3e90884',
#   'features': ['Chain Free',
#    'Double Glazing',
#    'Easy Reach of C2C station',
#    'Fitted Kitchen',
#    'Entry Phone System ',
#    'Excellent Condition'],
#   'floorplan_url': 'https://media.rightmove.co.uk/75k/74609/112583789/74609_RS0023_FLP_00_0000.jpeg',
#   'latitude': 51.534513,
#   'longitude': 0.084883,
#   'station_proximities': {'Barking Station': 0.3598445356923717,
#    'Upney Station': 0.7621869019795803,
#    'East Ham Station': 1.4733403500977942},
#   'property_size': {},
#   'bedrooms': 1,
#   'bathrooms': 1,
#   'new_build': False},
#  '30, Cavendish Gardens, Barking, Greater London IG11 9DU': {'property_type': 'Semi-Detached',
#   'price': '£550,000',
#   'date': '24 Feb 2022',
#   'url': ''},
#  '73, Essex Road, Barking, Greater London IG11 7QN': {'property_type': 'Terraced',
#   'price': '£500,000',
#   'date': '23 Feb 2022',
#   'url': 'https://www.rightmove.co.uk/house-prices/details/england-120535865-14974204?s=d47a5dcb2cf2991c67e40b8d10371e3817e510d357a57bcdf34d701fa222684a',
#   'features': [],
#   'latitude': 51.536631,
#   'longitude': 0.086987,
#   'station_proximities': {'Barking Station': 0.2963479544162566,
#    'Upney Station': 0.6353644248583672,
#    'East Ham Station': 1.5368841904161161},
#   'property_size': {},
#   'bedrooms': 5,
#   'bathrooms': 2,
#   'new_build': False},
#  '135, St Awdrys Road, Barking, Greater London IG11 7QE': {'property_type': 'Terraced',
#   'price': '£395,000',
#   'date': '18 Feb 2022',
#   'url': 'https://www.rightmove.co.uk/house-prices/details/england-79889283-14974201?s=4b476d3055c5fcbfec0b10308426e741f30fbced9cd32fe56ff74f82f416065d',
#   'features': ['Full Of Character',
#    'Excellently Maintained Throughout',
#    'Two Double Bedrooms',
#    'First Floor Family Bath/Shower Suite',
#    'Further Scope To Extend STPP',
#    'Benefitting With Rear Access',
#    '0.2 Miles From Barking Town &amp; Station',
#    'Surrounded With Excellent Transport Facilities',
#    'Local To Shops, Supermarkets &amp; Schools',
#    'Local To A406, A13 &amp; M11 Roads'],
#   'floorplan_url': 'https://media.rightmove.co.uk/205k/204362/79889283/204362_224613_FLP_00_0000.jpeg',
#   'latitude': 51.537237,
#   'longitude': 0.0839,
#   'station_proximities': {'Barking Station': 0.17349538845328888,
#    'Upney Station': 0.7613432153479548,
#    'East Ham Station': 1.3998231566376431},
#   'property_size': {},
#   'bedrooms': 2,
#   'bathrooms': 1,
#   'new_build': False},
#  '5, Graham Mansions, Lansbury Avenue, Barking, Greater London IG11 9NL': {'property_type': 'Flat',
#   'price': '£260,000',
#   'date': '18 Feb 2022',
#   'url': ''},
#  '18, Rosedale Gardens, Dagenham, Greater London RM9 4EA': {'property_type': 'Terraced',
#   'price': '£340,000',
#   'date': '18 Feb 2022',
#   'url': 'https://www.rightmove.co.uk/house-prices/details/england-21263060-15075340?s=48d7cc2206113d50961d9f07bbd001959bb387ff4ce5e0e3715ccb7aaf47a779',
#   'features': ['TWO-BEDROOM HOME WITH OWN DRIVEWAY PARKING',
#    "LOUNGE : 12' 11 x 12' 8 (3.94m x 3.86m)",
#    "FITTED KITCHEN : 10' 3 x 8' 2 (3.12m x 2.49m)",
#    "SUN LOUNGE AT THE BACK OF THE HOUSE TO LINK THE KITCHEN WITH A SEPARATE DINING AREA : 11' 0 x 7' 6 (",
#    'RADIATOR CENTRAL HEATING\tUPVC DOUBLE-GLAZED WINDOWS &amp; DOORS',
#    "BEDROOM ONE WITH STYLISH FURNITURE : 16' 2 x 9' 11 (4.94m x 3.02m)",
#    "BEDROOM TWO WITH FITTED WARDROBES : 11' 7 x 9' 10 (3.54m x 2.99m)",
#    'UPSTAIRS BATHROOM/WC'],
#   'latitude': 51.53665,
#   'longitude': 0.11423,
#   'station_proximities': {'Upney Station': 0.5622253662311234,
#    'Becontree Station': 0.6005327741574055,
#    'Barking Station': 1.4185145413241877},
#   'property_size': {},
#   'bedrooms': 2,
#   'bathrooms': None,
#   'new_build': False},
#  '199, Westrow Drive, Barking, Greater London IG11 9BS': {'property_type': 'Terraced',
#   'price': '£580,000',
#   'date': '17 Feb 2022',
#   'url': 'https://www.rightmove.co.uk/house-prices/details/england-116740940-14974288?s=f83574206c32c01ac46bf28248a88fd3c9dc3344aa93979cfe4200b4ad22b067',
#   'features': ['Spacious garden',
#    '1 Bathroom',
#    '3 Bedrooms',
#    'Excellent transport links',
#    'Off street parking'],
#   'floorplan_url': 'https://media.rightmove.co.uk/239k/238325/116740940/238325_S23_FLP_00_0000.jpeg',
#   'latitude': 51.54668,
#   'longitude': 0.10661,
#   'station_proximities': {'Upney Station': 0.619102074880409,
#    'Becontree Station': 0.9844432745906524,
#    'Barking Station': 1.1926171675639554},
#   'property_size': {},
#   'bedrooms': 3,
#   'bathrooms': 1,
#   'new_build': False},
#  '9, Lodge Avenue, Dagenham, Greater London RM8 2JA': {'property_type': 'Terraced',
#   'price': '£345,000',
#   'date': '15 Feb 2022',
#   'url': 'https://www.rightmove.co.uk/house-prices/details/england-111005870-15075277?s=37820a7e6d6850f5fd206b3e49375802a0d9d5682e77d772511e4cdea0bd2b60',
#   'features': ['Two Bedroom House ',
#    'CHAIN FREE',
#    'Fully Refurbished',
#    'Good Transport Links ',
#    '70ft Plus Garden ',
#    'New Roof and Windows',
#    'Brand New Kitchen and Bathroom '],
#   'floorplan_url': 'https://media.rightmove.co.uk/51k/50598/111005870/50598_10976141_FLP_00_0000.jpeg',
#   'latitude': 51.55069,
#   'longitude': 0.113523,
#   'station_proximities': {'Becontree Station': 0.9277785315274418,
#    'Upney Station': 1.0008468225630884,
#    'Goodmayes Station': 1.0300969417944925},
#   'property_size': {},
#   'bedrooms': 2,
#   'bathrooms': 1,
#   'new_build': False},
#  '17, Stern Close, Barking, Greater London IG11 0XW': {'property_type': 'Terraced',
#   'price': '£430,000',
#   'date': '14 Feb 2022',
#   'url': 'https://www.rightmove.co.uk/house-prices/details/england-109400963-92994810?s=37cff2082441f58011a3c6bc2a32a4b4259a7e20ca618d90a8d80614aff72f3d',
#   'features': ['THREE BEDROOMS',
#    'THROUGH LOUNGE',
#    'CONSERVATORY',
#    'WELL-MAINTAINED REAR GARDEN',
#    'ATTACHED GARAGE'],
#   'floorplan_url': 'https://media.rightmove.co.uk/4k/3886/109400963/3886_BKG102885_FLP_01_0000.jpeg',
#   'latitude': 51.52775,
#   'longitude': 0.119,
#   'station_proximities': {'Becontree Station': 0.9264859690921198,
#    'Upney Station': 1.051543462870483,
#    'Dagenham Dock Station': 1.18401457623822},
#   'property_size': {},
#   'bedrooms': 3,
#   'bathrooms': 1,
#   'new_build': False},
#  '45, Devon Road, Barking, Greater London IG11 7QX': {'property_type': 'Terraced',
#   'price': '£385,000',
#   'date': '14 Feb 2022',
#   'url': 'https://www.rightmove.co.uk/house-prices/details/england-114297305-14974207?s=cbe25bac9264885bbf4c7af86f372e4d47c64fb4f4935dfd534d36f2a0327e75',
#   'features': ['CHAIN FREE',
#    'THREE BEDROOMS',
#    'CHARACTER PROPERTY',
#    'ORIGINAL FEATURES',
#    'CLOSE TO TRANSPORT LINKS'],
#   'floorplan_url': 'https://media.rightmove.co.uk/4k/3886/114297305/3886_BKG103083_FLP_00_0000.jpeg',
#   'latitude': 51.53426,
#   'longitude': 0.09191,
#   'station_proximities': {'Upney Station': 0.4987701671119957,
#    'Barking Station': 0.5645685157142195,
#    'Becontree Station': 1.5654227989904166},
#   'property_size': {},
#   'bedrooms': 3,
#   'bathrooms': 1,
#   'new_build': False},
#  '30, Sandringham Road, Barking, Greater London IG11 9AJ': {'property_type': 'Terraced',
#   'price': '£565,000',
#   'date': '11 Feb 2022',
#   'url': 'https://www.rightmove.co.uk/house-prices/details/england-115180100-14646448?s=f8c6264e0011b261280ab18d7cd8a660c5ae21bf4f2bd77aa1bb6e2ac6d75924',
#   'features': ['Sold by Douglas Allen',
#    'Potential to extend into the loft and rear (sstp)',
#    'Close to local shops and transport services',
#    'No Onward Chain',
#    'Has Integral garage as well as Off Road Parking',
#    'Walking Distance to Barking Abbey school as well as Barking Park',
#    'EPC energy rating E'],
#   'latitude': 51.54695,
#   'longitude': 0.10361,
#   'station_proximities': {'Upney Station': 0.6038361507771566,
#    'Barking Station': 1.08609613190931,
#    'Becontree Station': 1.1089177400515375},
#   'property_size': {},
#   'bedrooms': 4,
#   'bathrooms': 1,
#   'new_build': False},
#  '71, Woodbridge Road, Barking, Greater London IG11 9ES': {'property_type': 'Terraced',
#   'price': '£540,000',
#   'date': '11 Feb 2022',
#   'url': 'https://www.rightmove.co.uk/house-prices/details/england-80125011-14974300?s=24b01e29c295018cc0d03cef15ac0e649cadb28b7c3307f5a6386ed5e8b01ce2',
#   'features': ['LEFTLEY ESTATE',
#    'ATTACHED GARAGE',
#    'THREE BEDROOMS ',
#    'LARGE THROUGH LOUNGE',
#    'LARGE REAR GARDEN'],
#   'floorplan_url': 'https://media.rightmove.co.uk/4k/3886/80125011/3886_BKG102740_FLP_00_0000.jpeg',
#   'latitude': 51.54541,
#   'longitude': 0.10223,
#   'station_proximities': {'Upney Station': 0.49135109007637057,
#    'Barking Station': 0.9843626525793772,
#    'Becontree Station': 1.1246845406246906},
#   'property_size': {},
#   'bedrooms': 3,
#   'bathrooms': 1,
#   'new_build': False},
#  '53, Salisbury Avenue, Barking, Greater London IG11 9XQ': {'property_type': 'Terraced',
#   'price': '£490,000',
#   'date': '10 Feb 2022',
#   'url': 'https://www.rightmove.co.uk/house-prices/details/england-114792137-14646496?s=248d9fe18b9f2d9a9e68043c2a4dc4a333e52393d38ab2cd53ba21aa6c2fd5ce',
#   'features': [],
#   'floorplan_url': 'https://media.rightmove.co.uk/215k/214967/114792137/214967_TAE210042_FLP_00_0000.jpeg',
#   'latitude': 51.538441,
#   'longitude': 0.084489,
#   'station_proximities': {'Barking Station': 0.13762288236438938,
#    'Upney Station': 0.7322906262926747,
#    'East Ham Station': 1.4188240651988882},
#   'property_size': {},
#   'bedrooms': 3,
#   'bathrooms': 1,
#   'new_build': False},
#  'Flat 305, Orvis Court, 12, Mizzen Street, Barking, Greater London IG11 7RZ': {'property_type': 'Flat',
#   'price': '£120,000',
#   'date': '9 Feb 2022',
#   'url': ''},
#  '14, Dereham Road, Barking, Greater London IG11 9HA': {'property_type': 'Terraced',
#   'price': '£490,000',
#   'date': '4 Feb 2022',
#   'url': 'https://www.rightmove.co.uk/house-prices/details/england-110326247-92994879?s=f43f3daa74fbd9905e5d20856459df5274b5843fbc060b4294ccabd51033a4cd',
#   'features': ['Leftley Estate',
#    'Two Reception Rooms',
#    'Double Glazed',
#    'Gas Central Heating',
#    'Good Transport Links'],
#   'floorplan_url': 'https://media.rightmove.co.uk/4k/3886/110326247/3886_BKG102893_FLP_00_0001.jpeg',
#   'latitude': 51.54434,
#   'longitude': 0.10146,
#   'station_proximities': {'Upney Station': 0.41626927511767664,
#    'Barking Station': 0.9241258877011996,
#    'Becontree Station': 1.1353214723194032},
#   'property_size': {},
#   'bedrooms': 3,
#   'bathrooms': 1,
#   'new_build': False},
#  '135, Woodbridge Road, Barking, Greater London IG11 9BB': {'property_type': 'Semi-Detached',
#   'price': '£575,000',
#   'date': '4 Feb 2022',
#   'url': 'https://www.rightmove.co.uk/house-prices/details/england-123848204-14974279?s=698ff7fe3c2114f15b688175f00e950efbd2ca851896f67229245ee813c6c494',
#   'features': ['EPC rating 69C',
#    'Very Well Presented',
#    'Three Bedrooms',
#    'Fitted Kitchen/Diner',
#    'Large Rear Garden'],
#   'floorplan_url': 'https://media.rightmove.co.uk/14k/13345/123848204/13345_31541215_FLP_00_0000.jpeg',
#   'latitude': 51.54495,
#   'longitude': 0.10769,
#   'station_proximities': {'Upney Station': 0.5311350011412322,
#    'Becontree Station': 0.8926337214376585,
#    'Barking Station': 1.1904452608244547},
#   'property_size': {},
#   'bedrooms': 3,
#   'bathrooms': 1,
#   'new_build': False},
#  '1, Sandringham Road, Barking, Greater London IG11 9AA': {'property_type': 'Semi-Detached',
#   'price': '£585,000',
#   'date': '4 Feb 2022',
#   'url': 'https://www.rightmove.co.uk/house-prices/details/england-112352594-14974267?s=e516f0bd79b463933462f808d9142837b55da9a0c491474dccd6d99aa56fd657',
#   'features': [],
#   'floorplan_url': 'https://media.rightmove.co.uk/14k/13345/112352594/13345_30901850_FLP_00_0000.jpeg',
#   'latitude': 51.541284,
#   'longitude': 0.097815,
#   'station_proximities': {'Upney Station': 0.2585437244642707,
#    'Barking Station': 0.7120915446818354,
#    'Becontree Station': 1.2580778345728036},
#   'property_size': {},
#   'bedrooms': 4,
#   'bathrooms': 1,
#   'new_build': False},
#  'Flat 202, Trinity House, 11, Academy Way, Dagenham, Greater London RM8 2FD': {'property_type': 'Flat',
#   'price': '£252,500',
#   'date': '3 Feb 2022',
#   'url': ''},
#  '31, Whiting Avenue, Barking, Greater London IG11 8JH': {'property_type': 'Terraced',
#   'price': '£455,000',
#   'date': '3 Feb 2022',
#   'url': 'https://www.rightmove.co.uk/house-prices/details/england-115504121-14646424?s=e51b610503d55c37c215e2ead50428b32a2b824d48e502ccc6e7930e93ef281a',
#   'features': ['THREE BEDROOMS',
#    'THROUGH LOUNGE',
#    'REQUIRES MODERNISATION',
#    'GARAGE',
#    'CLOSE TO BARKING TOWN CENTRE'],
#   'latitude': 51.53963,
#   'longitude': 0.07327,
#   'station_proximities': {'Barking Station': 0.36034632791067117,
#    'East Ham Station': 0.9337132169641371,
#    'Upney Station': 1.2193740962760242},
#   'property_size': {},
#   'bedrooms': 3,
#   'bathrooms': 1,
#   'new_build': False},
#  'Flat 25, Seawall Court, Dock Road, Barking, Greater London IG11 7GP': {'property_type': 'Flat',
#   'price': '£300,000',
#   'date': '31 Jan 2022',
#   'url': 'https://www.rightmove.co.uk/house-prices/details/england-80408235-14974195?s=e9d3068e0424d6b5d9cd3e16c6de1fee7309ae10dd232d7ee8898b944a9137db',
#   'features': ['CHAIN FREE',
#    'OWN PRIVATE BALCONY',
#    'ALLOCATED PARKING SPACE',
#    'COMMUNAL TERRACE',
#    'EWS1 FORM PROVIDED'],
#   'floorplan_url': 'https://media.rightmove.co.uk/4k/3886/80408235/3886_BKG102786_FLP_00_0000.jpeg',
#   'latitude': 51.53049,
#   'longitude': 0.0766,
#   'station_proximities': {'Barking Station': 0.6463686173554458,
#    'Upney Station': 1.201433053676778,
#    'East Ham Station': 1.2403040313420326},
#   'property_size': {},
#   'bedrooms': 2,
#   'bathrooms': 1,
#   'new_build': False},
#  '74, Sheringham Drive, Barking, Greater London IG11 9AN': {'property_type': 'Terraced',
#   'price': '£550,000',
#   'date': '31 Jan 2022',
#   'url': ''},
#  '102, London Road, Barking, Greater London IG11 8DD': {'property_type': 'Flat',
#   'price': '£220,000',
#   'date': '28 Jan 2022',
#   'url': 'https://www.rightmove.co.uk/house-prices/details/england-107822297-14974234?s=5610d8f11fe5cf5ea1e454c52652ff384b01a5ad744bff220a1c60658ccb9c25',
#   'features': ['Attractive 2nd floor flat',
#    'Spacious and sleek kitchen with integrated appliances',
#    'Reception filled with light and room to dine',
#    'Private balcony overlooking communal areas',
#    '2 Lovely double bedrooms',
#    'Bathroom with refurb potential and separate WC'],
#   'floorplan_url': 'https://media.rightmove.co.uk/182k/181043/107822297/181043_1171884_FLP_00_0000.png',
#   'latitude': 51.537645,
#   'longitude': 0.074055,
#   'station_proximities': {'Barking Station': 0.3452962249613603,
#    'East Ham Station': 0.974834096755202,
#    'Upney Station': 1.183101838167258},
#   'property_size': {'sqm': 65, 'sqft': 699, 'ha': 0.01, 'ac': 0.02},
#   'bedrooms': 2,
#   'bathrooms': 1,
#   'new_build': False},
#  '52, Bradfield Drive, Barking, Greater London IG11 9AR': {'property_type': 'Terraced',
#   'price': '£450,000',
#   'date': '28 Jan 2022',
#   'url': 'https://www.rightmove.co.uk/house-prices/details/england-112470395-14646454?s=f253fc49f1088374a681512f8d823e89c44719c70e8521deb8780d2b82c472b7',
#   'features': ['THREE BEDROOMS',
#    'TWO SHOWER ROOMS',
#    'SET WITHIN LEFTLEY ESTATE',
#    'KITCHEN/DINER',
#    'OFF STREET PARKING'],
#   'floorplan_url': 'https://media.rightmove.co.uk/4k/3886/112470395/3886_BKG102951_FLP_00_0000.jpeg',
#   'latitude': 51.54651,
#   'longitude': 0.10603,
#   'station_proximities': {'Upney Station': 0.5994795039255645,
#    'Becontree Station': 1.0015997143226345,
#    'Barking Station': 1.1649862005923675},
#   'property_size': {},
#   'bedrooms': 3,
#   'bathrooms': 2,
#   'new_build': False},
#  '12a, Tudor Road, Barking, Greater London IG11 9RX': {'property_type': 'Flat',
#   'price': '£270,000',
#   'date': '24 Jan 2022',
#   'url': 'https://www.rightmove.co.uk/house-prices/details/england-109958681-14974327?s=19737d1df4fd54e4955548ccd4d9616780610c71213c258d846202e24ee539b6',
#   'features': ['TWO BEDROOM MAISONETTE',
#    'LARGE BRIGHT &amp; AIRY LOUNGE',
#    'SEPARATE KITCHEN',
#    'OWN PRIVATE REAR GARDEN',
#    'GOOD TRANSPORT LINKS'],
#   'floorplan_url': 'https://media.rightmove.co.uk/4k/3886/109958681/3886_BKG102887_FLP_00_0000.jpeg',
#   'latitude': 51.53503,
#   'longitude': 0.09916,
#   'station_proximities': {'Upney Station': 0.24834900169674237,
#    'Barking Station': 0.8123567163907831,
#    'Becontree Station': 1.2501349486967075},
#   'property_size': {},
#   'bedrooms': 2,
#   'bathrooms': 1,
#   'new_build': False},
#  '353, Lodge Avenue, Dagenham, Greater London RM9 4QB': {'property_type': 'Terraced',
#   'price': '£333,500',
#   'date': '24 Jan 2022',
#   'url': 'https://www.rightmove.co.uk/house-prices/details/england-110731718-15075364?s=9d478a4a64b8b838cd96c8a5dc0cc6d5bf5dec610f7b764e27bab4d39a88990d',
#   'features': ['Two Bedroom Terraced House',
#    'Two Double Bedrooms',
#    'Open Plan Living/Dining ',
#    'First Floor Family Bathroom',
#    'Potential To Extend ( S.T.P.P.) ',
#    'Well Maintained Rear Garden ',
#    'Off Street Parking ',
#    'Close Proximity To Local Amenities ',
#    'Close Proximity To Local Transport Links ',
#    'Close Proximity To Local Schools '],
#   'floorplan_url': 'https://media.rightmove.co.uk/167k/166871/110731718/166871_RS0271_FLP_00_0000.jpeg',
#   'latitude': 51.537029,
#   'longitude': 0.112631,
#   'station_proximities': {'Upney Station': 0.4894932441962669,
#    'Becontree Station': 0.6548215197616807,
#    'Barking Station': 1.3468581082427815},
#   'property_size': {},
#   'bedrooms': 2,
#   'bathrooms': 1,
#   'new_build': False},
#  '162, Canonsleigh Road, Dagenham, Greater London RM9 4DH': {'property_type': 'Terraced',
#   'price': '£365,000',
#   'date': '21 Jan 2022',
#   'url': 'https://www.rightmove.co.uk/house-prices/details/england-115760906-93088050?s=4f1f6786f52f1d4757eff388a58f07f23f5cc3963cdb08b0dfaa4becb395d66f',
#   'features': ['Mid-Terrace House',
#    'Two Double Bedrooms',
#    'Kitchen/Dining Area',
#    'Off Street Parking',
#    'Low Maintenance Rear Garden',
#    'UPVC Double Glazed Windows',
#    'Gas Central Heating (Untested By Griffin)',
#    'Modern Fitted Shower Room',
#    'Within Close Proximity To Becontree Station',
#    "Internal Viewing's Highly Recommended!"],
#   'latitude': 51.53767,
#   'longitude': 0.117704,
#   'station_proximities': {'Becontree Station': 0.43499318429934664,
#    'Upney Station': 0.7014785248041876,
#    'Dagenham Heathway Station': 1.3190017871733526},
#   'property_size': {},
#   'bedrooms': 2,
#   'bathrooms': 1,
#   'new_build': False},
#  '172, Westrow Drive, Barking, Greater London IG11 9BP': {'property_type': 'Terraced',
#   'price': '£740,000',
#   'date': '17 Jan 2022',
#   'url': 'https://www.rightmove.co.uk/house-prices/details/england-109850075-14974285?s=42f4cdc1702ff8df879ad4d942cc2995bbe16b0a5a3e7496e1de95e08bf9420e',
#   'features': ['FIVE BEDROOMS ',
#    'SEMI DETACHED HOUSE ',
#    'TWO RECEPTION ROOMS',
#    'FITTED KITCHEN / DINER ',
#    'OFF STREET PARKING FOR 4 CARS ',
#    'ATTACHED DOUBLE GARAGE   ',
#    'FULLY DOUBLE GLAZED ',
#    'GAS CENTRAL HEATING ',
#    'GROUND FLOOR CLOAKROOM /W.C.',
#    'POTENTIAL FOR FURTHER EXTENSION'],
#   'floorplan_url': 'https://media.rightmove.co.uk/7k/6489/109850075/6489_5557_FLP_00_0000.jpeg',
#   'latitude': 51.54408,
#   'longitude': 0.10621,
#   'station_proximities': {'Upney Station': 0.44766905129810663,
#    'Becontree Station': 0.9332282144505784,
#    'Barking Station': 1.1110116637624203},
#   'property_size': {},
#   'bedrooms': 5,
#   'bathrooms': None,
#   'new_build': False},
#  'Flat 42, Cromwell Lodge, Longbridge Road, Barking, Greater London IG11 8UB': {'property_type': 'Flat',
#   'price': '£125,000',
#   'date': '17 Jan 2022',
#   'url': ''},
#  '291, Sheppey Road, Dagenham, Greater London RM9 4JU': {'property_type': 'Terraced',
#   'price': '£390,000',
#   'date': '17 Jan 2022',
#   'url': ''},
#  '24, John Burns Drive, Barking, Greater London IG11 9RQ': {'property_type': 'Flat',
#   'price': '£223,000',
#   'date': '14 Jan 2022',
#   'url': 'https://www.rightmove.co.uk/house-prices/details/england-79570740-14974324?s=91437e91490165c4f4d2330de81f2bf9202ebca040df6837b8ebdcaceeca93da',
#   'features': ['TWO DOUBLE BEDROOM FLAT',
#    'THIRD FLOOR',
#    'LONG LEASE',
#    'FREE PARKING',
#    'GROUND FLOOR STORAGE FACILITIES',
#    'WALKING DISTANCE TO BARKING TOWN CENTRE',
#    'A SHORT WALK FROM UPNEY UNDERGROUND STATION',
#    'GUIDE PRICE OF £240,000 - £260,000'],
#   'floorplan_url': 'https://media.rightmove.co.uk/55k/54989/79570740/54989_jbd24_FLP_00_0000.png',
#   'latitude': 51.5362,
#   'longitude': 0.09431,
#   'station_proximities': {'Upney Station': 0.34178916694491146,
#    'Barking Station': 0.5881051430641587,
#    'Becontree Station': 1.4339812695319527},
#   'property_size': {},
#   'bedrooms': 2,
#   'bathrooms': 1,
#   'new_build': False},
#  '106, Roxwell Road, Barking, Greater London IG11 0PT': {'property_type': 'Terraced',
#   'price': '£200,000',
#   'date': '14 Jan 2022',
#   'url': 'https://www.rightmove.co.uk/house-prices/details/england-7790472-92994801?s=7729629a6c35619f6453f88b4c71eea11e5c98778b9623ae83e1f5277f4fdec8',
#   'features': ['Hallway',
#    'Bedroom x 1',
#    'Bedroom x 2',
#    'Bathroom',
#    'Kitchen',
#    'Reception'],
#   'latitude': 51.52818,
#   'longitude': 0.11023,
#   'station_proximities': {'Upney Station': 0.796455928729626,
#    'Becontree Station': 1.100052211237354,
#    'Barking Station': 1.4541769368042994},
#   'property_size': {},
#   'bedrooms': 2,
#   'bathrooms': None,
#   'new_build': False},
#  '242, Bastable Avenue, Barking, Greater London IG11 0LJ': {'property_type': 'Flat',
#   'price': '£247,000',
#   'date': '10 Jan 2022',
#   'url': 'https://www.rightmove.co.uk/house-prices/details/england-107852873-14974168?s=4192ada888f03cbcd07d14d4627d37d1aa1b5b4cb0db00e8bdac3057af175d34',
#   'features': ['Up and Coming Area',
#    'Fantastic Rail,  Bus and Road links into London',
#    'Schools , Shops and Amenities close by'],
#   'floorplan_url': 'https://media.rightmove.co.uk/1k/218/107852873/218_BAR210179_FLP_00_0001.jpeg',
#   'latitude': 51.527181,
#   'longitude': 0.11017,
#   'station_proximities': {'Upney Station': 0.8567602120634734,
#    'Becontree Station': 1.1547569572421539,
#    'Barking Station': 1.489727007311508},
#   'property_size': {},
#   'bedrooms': 2,
#   'bathrooms': 1,
#   'new_build': False},
#  '150, Morley Road, Barking, Greater London IG11 7DH': {'property_type': 'Terraced',
#   'price': '£355,000',
#   'date': '7 Jan 2022',
#   'url': 'https://www.rightmove.co.uk/house-prices/details/england-113232674-14974189?s=c080f935858837413a1561b49e5747dce55f8fe10bcad5570a6654b288093324',
#   'features': ['Calling all first time buyers / investors',
#    '0.6 miles walk from the station',
#    'Located convinent for the local shops'],
#   'floorplan_url': 'https://media.rightmove.co.uk/1k/218/113232674/218_BAR210299_FLP_00_0001.jpeg',
#   'latitude': 51.533626,
#   'longitude': 0.085653,
#   'station_proximities': {'Barking Station': 0.42933705866593097,
#    'Upney Station': 0.7553755786678661,
#    'East Ham Station': 1.520584437263029},
#   'property_size': {},
#   'bedrooms': 2,
#   'bathrooms': 1,
#   'new_build': False},
#  '469, Longbridge Road, Barking, Greater London IG11 9DG': {'property_type': 'Flat',
#   'price': '£210,000',
#   'date': '6 Jan 2022',
#   'url': ''},
# ...
#   'features': ['1 Bedroom Flat',
#    'Available Immediately with No Forward Chain',
#    'Double Glazing &amp; Central Heating',
#    'Walking Distance to Barking Town Centre &amp; Train Station',
#    'No Stamp Duty for First Time Buyers'],
#   'latitude': 51.532093,
#   'longitude': 0.078102,
#   'station_proximities': {'Barking Station': 0.5208020398524325,
#    'Upney Station': 1.095864073776182,
#    'East Ham Station': 1.248225918547322},
#   'property_size': {},
#   'bedrooms': 1,
#   'bathrooms': 1,
#   'new_build': False},
#  '542, Goresbrook Road, Dagenham, Greater London RM9 4XD': {'property_type': 'Terraced',
#   'price': '£258,000',
#   'date': '30 Sep 2019',
#   'url': 'https://www.rightmove.co.uk/house-prices/details/england-72338428-10868389?s=10dbddd61371b00e5bd31028c778528784d8967e0bc93c038a1c3ee83a188551',
#   'features': ['Two Double Bedrooms', 'Lounge', 'Kitchen', 'Family Bathroom'],
#   'floorplan_url': 'https://media.rightmove.co.uk/209k/208337/72338428/208337_TAR190045_FLP_02_0000.jpg',
#   'latitude': 51.534397,
#   'longitude': 0.117958,
#   'station_proximities': {'Becontree Station': 0.5577033395765895,
#    'Upney Station': 0.761004858532108,
#    'Dagenham Dock Station': 1.351672501339592},
#   'property_size': {},
#   'bedrooms': 2,
#   'bathrooms': 1,
#   'new_build': False},
#  '154, Gurney Close, Barking, Greater London IG11 8JZ': {'property_type': 'Terraced',
#   'price': '£199,750',
#   'date': '27 Sep 2019',
#   'url': 'https://www.rightmove.co.uk/house-prices/details/england-69124393-91207869?s=c12c29c66b2eedb4644db68e4182bf725a60239dab10628599b3267ad26c841e',
#   'features': ['TWO BEDROOM PURPOSE BUILT FLAT',
#    'WALKING DISTANCE TO BARKING TOWN CENTRE',
#    'IDEAL FIRST PURCHASE OR INVESTMENT',
#    'CLOSE TO MAJOR TRANSPORT LINKS',
#    ' GOOD DECORATIVE ORDER',
#    'PARKING ON SITE'],
#   'floorplan_url': 'https://media.rightmove.co.uk/66k/65633/69124393/65633_idlo_1269414022_FLP_01_0000.jpg',
#   'latitude': 51.543575,
#   'longitude': 0.069402,
#   'station_proximities': {'Barking Station': 0.6037127705587372,
#    'East Ham Station': 0.8197680035567114,
#    'Ilford Station': 1.0375731631243452},
#   'property_size': {},
#   'bedrooms': 2,
#   'bathrooms': 1,
#   'new_build': False},
#  'Flat 7, Pedley House, 6, Ripplegate Walk, Barking, Greater London IG11 0YB': {'property_type': 'Flat',
#   'price': '£251,995',
#   'date': '27 Sep 2019',
#   'url': ''},
#  '350, Uphall Road, Ilford, Greater London IG1 2JJ': {'property_type': 'Detached',
#   'price': '£450,000',
#   'date': '27 Sep 2019',
#   'url': 'https://www.rightmove.co.uk/house-prices/details/england-80487095-10770472?s=c86debbc8a5011de2dcc11da23f03fdb800b763a2f0deff821bba5f97c67e555',
#   'features': [],
#   'floorplan_url': 'https://media.rightmove.co.uk/63k/62254/80487095/62254_uphallrd_FLP_00_0000.jpg',
#   'latitude': 51.54386,
#   'longitude': 0.07288,
#   'station_proximities': {'Barking Station': 0.49103617090254575,
#    'East Ham Station': 0.9676219122995907,
#    'Ilford Station': 1.0281710598361196},
#   'property_size': {},
#   'bedrooms': 3,
#   'bathrooms': None,
#   'new_build': False},
#  '83, Sherwood Gardens, Barking, Greater London IG11 9TQ': {'property_type': 'Terraced',
#   'price': '£487,000',
#   'date': '27 Sep 2019',
#   'url': 'https://www.rightmove.co.uk/house-prices/details/england-73106677-10770862?s=6566179f615a844bb8f99d241afab9bb653d06de35252ad537d27246031625d8',
#   'features': ['THREE BEDROOMS',
#    'ATTACHED GARAGE',
#    'HUGE PLOT WITH POTENTIAL TO EXTEND',
#    'CLOSE TO BARKING TOWN CENTRE AND STATION',
#    'LARGE DRIVEWAY'],
#   'latitude': 51.53935,
#   'longitude': 0.08798,
#   'station_proximities': {'Barking Station': 0.27469876597011694,
#    'Upney Station': 0.5860444831004783,
#    'Ilford Station': 1.5498942467156243},
#   'property_size': {},
#   'bedrooms': 3,
#   'bathrooms': 1,
#   'new_build': False},
#  '14, Meadow Road, Barking, Greater London IG11 9QS': {'property_type': 'Terraced',
#   'price': '£280,000',
#   'date': '27 Sep 2019',
#   'url': 'https://www.rightmove.co.uk/house-prices/details/england-75374143-10770859?s=8526a03dd24edad2145e8ade870aa08b6dbcc5ef239cb527890dab763942840f',
#   'features': ['Newly decorated',
#    'Off street parking',
#    '2 Bed House',
#    'Big Garden',
#    'Great transport link',
#    "Min's Walk To Amenities &amp; Transport",
#    'Unfurnished',
#    'Call  '],
#   'latitude': 51.537045,
#   'longitude': 0.104331,
#   'station_proximities': {'Upney Station': 0.15163571678833207,
#    'Barking Station': 0.9920938271992802,
#    'Becontree Station': 0.9990353452016594},
#   'property_size': {},
#   'bedrooms': 2,
#   'bathrooms': None,
#   'new_build': False},
#  '234, Westrow Drive, Barking, Greater London IG11 9BT': {'property_type': 'Terraced',
#   'price': '£440,000',
#   'date': '27 Sep 2019',
#   'url': 'https://www.rightmove.co.uk/house-prices/details/england-76606505-10770829?s=07b8899411c05e8f65a6667ed6b83cc999e5372828a4dd69ea9e963129ba802a',
#   'features': ['Middle terrace',
#    'Three bedrooms',
#    'Two receptions',
#    'Off street parking',
#    'Gas central heating',
#    'Double glazing',
#    'Leftley Estate'],
#   'latitude': 51.547151,
#   'longitude': 0.106945,
#   'station_proximities': {'Upney Station': 0.6546852071000351,
#    'Becontree Station': 0.9870433728199166,
#    'Barking Station': 1.2198247134206042},
#   'property_size': {},
#   'bedrooms': 3,
#   'bathrooms': 1,
#   'new_build': False},
#  '186, Longbridge Road, Barking, Greater London IG11 8SU': {'property_type': 'Semi-Detached',
#   'price': '£610,000',
#   'date': '27 Sep 2019',
#   'url': 'https://www.rightmove.co.uk/house-prices/details/england-62564571-10770823?s=54533374853fda163a9976d14f6528afed8135a86d6080c6bb05857252f64b71',
#   'features': ['FOUR DOUBLE BEDROOMS',
#    'FOUR RECEPTION ROOMS',
#    'LARGE REAR GARDEN',
#    'DETACHED GARAGE',
#    'HIGHLY SOUGHT-AFTER PROMINENT LOCATION'],
#   'latitude': 51.54425,
#   'longitude': 0.0907,
#   'station_proximities': {'Barking Station': 0.5203614214287469,
#    'Upney Station': 0.6195100301927466,
#    'Ilford Station': 1.3477030646573296},
#   'property_size': {},
#   'bedrooms': 4,
#   'bathrooms': 1,
#   'new_build': False},
#  '72, Melford Avenue, Barking, Greater London IG11 9HT': {'property_type': 'Terraced',
#   'price': '£443,000',
#   'date': '26 Sep 2019',
#   'url': 'https://www.rightmove.co.uk/house-prices/details/england-71674321-10770838?s=0d37e56df9b63932b0a49953ad85e947f7931038df60a47f7afb056ed690faec',
#   'features': ['MID TERRACE',
#    'THREE BEDROOMS',
#    'TWO RECEPTION ROOMS',
#    'EXTENDED',
#    'STATION LOCATION',
#    'SCHOOLS AND SHOPS NEAR BY'],
#   'latitude': 51.54298,
#   'longitude': 0.09693,
#   'station_proximities': {'Upney Station': 0.3770322920733545,
#    'Barking Station': 0.7078950967930042,
#    'Becontree Station': 1.3081799815093473},
#   'property_size': {},
#   'bedrooms': 3,
#   'bathrooms': None,
#   'new_build': False},
#  '19, Ridley Close, Barking, Greater London IG11 9PJ': {'property_type': 'Flat',
#   'price': '£267,500',
#   'date': '26 Sep 2019',
#   'url': 'https://www.rightmove.co.uk/house-prices/details/england-72495412-10770847?s=0a25be9c3930b25e639a19b29c48e4f0bedd115ad73ecdd5ec5edf50945a4585',
#   'features': ['TWO DOUBLE BEDROOMS',
#    'EN-SUITE BATHROOM',
#    'WELL-PRESENTED THROUGHOUT',
#    'MODERN PURPOSE BUILT BLOCK',
#    'MOMENTS FROM UPNEY STATION'],
#   'latitude': 51.54,
#   'longitude': 0.09924,
#   'station_proximities': {'Upney Station': 0.15080300271610148,
#    'Barking Station': 0.7617467937894262,
#    'Becontree Station': 1.1944951054448056},
#   'property_size': {},
#   'bedrooms': 2,
#   'bathrooms': 2,
#   'new_build': False},
#  '32, Suffolk Road, Barking, Greater London IG11 7QW': {'property_type': 'Terraced',
#   'price': '£285,000',
#   'date': '23 Sep 2019',
#   'url': 'https://www.rightmove.co.uk/house-prices/details/england-85765066-10770796?s=9bfca89c5212785352cba49d16b37e10bb61bff8e3a5aaf494aafe86cdabe108',
#   'features': ['Four Bedroom House In Barking',
#    'Two Reception Rooms',
#    'Newly Refurbished Throughout',
#    'Three Bathrooms',
#    'New Flooring Throughout',
#    'Spacious Private Garden',
#    'Gas Central Heating',
#    'Double Glazing',
#    'Offered Unfurnished',
#    'Great Transport Links'],
#   'latitude': 51.536598,
#   'longitude': 0.089202,
#   'station_proximities': {'Barking Station': 0.3769425900276866,
#    'Upney Station': 0.5422576273786396,
#    'East Ham Station': 1.6319760208837115},
#   'property_size': {},
#   'bedrooms': 4,
#   'bathrooms': 3,
#   'new_build': False},
#  '9, Bridgeway, Barking, Greater London IG11 9QF': {'property_type': 'Terraced',
#   'price': '£366,500',
#   'date': '20 Sep 2019',
#   'url': 'https://www.rightmove.co.uk/house-prices/details/england-61847403-10494718?s=4667a61751f4fbcc789dc792fbd91830cfd85ce95a2b62c0ecd0ee5479a247d5',
#   'features': ['3 Bedroom House',
#    'Double Fronted &amp; Semi-detached',
#    'Large Rear Garden with Side Access',
#    '2 Double Bedrooms',
#    '2 Separate Receptions',
#    'Near Upney Underground Station',
#    'Close to Schools &amp; Hospital',
#    'Good Access to A13'],
#   'latitude': 51.53733,
#   'longitude': 0.10128,
#   'station_proximities': {'Upney Station': 0.0689447183960953,
#    'Barking Station': 0.859066152550396,
#    'Becontree Station': 1.1241392884044925},
#   'property_size': {},
#   'bedrooms': 3,
#   'bathrooms': 1,
#   'new_build': False},
#  '2, Kemmel Road, Dagenham, Greater London RM9 4BT': {'property_type': 'Terraced',
#   'price': '£375,000',
#   'date': '20 Sep 2019',
#   'url': ''},
#  '292, Gurney Close, Barking, Greater London IG11 8LD': {'property_type': 'Flat',
#   'price': '£205,000',
#   'date': '20 Sep 2019',
#   'url': 'https://www.rightmove.co.uk/house-prices/details/england-44511243-10770811?s=5bc55548cc634a2c9d055dffb56faa7ddb655c2cb99856b349a63efcf7eee9e0',
#   'features': ['One Double Bedroom Furnished Apartment',
#    'Electric Heating',
#    'Recently Refurbished Throughout',
#    'Modern Kitchen With New Appliances',
#    'Newly Installed Bathroom',
#    'Double Glazed Throughout',
#    'New &amp; Good Quality Furnishings',
#    'Located On The 1st Floor',
#    'Close To Barking Town Centre &amp; Transport',
#    'Available 15th May 2017'],
#   'latitude': 51.54261,
#   'longitude': 0.07268,
#   'station_proximities': {'Barking Station': 0.4479399175970257,
#    'East Ham Station': 0.9351459019747558,
#    'Ilford Station': 1.112713956894847},
#   'property_size': {},
#   'bedrooms': 1,
#   'bathrooms': 1,
#   'new_build': False},
#  '5, Moore Crescent, Dagenham, Greater London RM9 4XP': {'property_type': 'Flat',
#   'price': '£180,000',
#   'date': '20 Sep 2019',
#   'url': 'https://www.rightmove.co.uk/house-prices/details/england-79422858-10868392?s=59c7639185e42b363d8f065930dda772dc4e881a7f5c2da78b1546f65513c9bb',
#   'features': ['One Bedroom First Floor Apartment',
#    'Balcony Onto Communal Gardens',
#    'Over 100+ Year Lease',
#    'Modern  Three Piece Bathroom',
#    'Spacious Rooms Throughout',
#    'Well Maintained Throughout',
#    'Close To Upney Station'],
#   'floorplan_url': 'https://media.rightmove.co.uk/152k/151079/79422858/151079_1160837-1_FLP_00_0000.jpeg',
#   'latitude': 51.533542,
#   'longitude': 0.111543,
#   'station_proximities': {'Upney Station': 0.5457521487141589,
#    'Becontree Station': 0.8079591667108028,
#    'Barking Station': 1.3508158549032827},
#   'property_size': {},
#   'bedrooms': 1,
#   'bathrooms': 1,
#   'new_build': False},
#  '29, Glenmore Way, Barking, Greater London IG11 0LY': {'property_type': 'Terraced',
#   'price': '£250,000',
#   'date': '17 Sep 2019',
#   'url': 'https://www.rightmove.co.uk/house-prices/details/england-72373024-10770709?s=37ccac4b2b90cc8caf311a86bc62587e5d2c1b938df52f081531827c348682f6',
#   'features': ['NO ONWARD CHAIN',
#    'QUIET LOCATION',
#    'POTENTIAL TO EXTEND SUBJECT TO PLANNING',
#    'CLOSE TO LOCAL AMENITIES',
#    'FIRST FLOOR BATHROOM',
#    'CENTRAL HEATING'],
#   'floorplan_url': 'https://media.rightmove.co.uk/66k/65633/72373024/65633_idlo_656890129_FLP_01_0000.jpg',
#   'latitude': 51.526978,
#   'longitude': 0.108125,
#   'station_proximities': {'Upney Station': 0.8351383765059848,
#    'Becontree Station': 1.2224069833896813,
#    'Barking Station': 1.4260230315412308},
#   'property_size': {},
#   'bedrooms': 2,
#   'bathrooms': 1,
#   'new_build': False},
#  '103b, Park Avenue, Barking, Greater London IG11 8QX': {'property_type': 'Flat',
#   'price': '£260,000',
#   'date': '13 Sep 2019',
#   'url': ''},
#  '312, Westrow Drive, Barking, Greater London IG11 9BX': {'property_type': 'Terraced',
#   'price': '£246,945',
#   'date': '13 Sep 2019',
#   'url': 'https://www.rightmove.co.uk/house-prices/details/england-32900360-10770832?s=e34982253599574819543841d3802e893754c9bee95cd10d2db72184d2bc6114',
#   'features': [],
#   'latitude': 51.54939,
#   'longitude': 0.10559,
#   'station_proximities': {'Upney Station': 0.7858068231640234,
#    'Seven Kings Station': 1.045082352725093,
#    'Becontree Station': 1.1185519130008},
#   'property_size': {},
#   'bedrooms': 3,
#   'bathrooms': None,
#   'new_build': False},
#  '143, Oxlow Lane, Dagenham, Greater London RM10 7ST': {'property_type': 'Terraced',
#   'price': '£380,000',
#   'date': '7 Apr 2022',
#   'url': 'https://www.rightmove.co.uk/house-prices/details/england-8009013-93086133?s=00933840a159947c7b85e927cd6a7337d1a9c1e2ae74734652af423fe74d897e',
#   'features': ['Three Bedrooms',
#    'Lounge',
#    'Ground Floor Bathroom',
#    'Central Heating',
#    "Approx. 75' Rear Garden",
#    'Semi-Detached',
#    'Fitted Kitchen',
#    'Double Glazed (where specified)',
#    'Off Street Parking',
#    'No Onward Chain'],
#   'latitude': 51.55104,
#   'longitude': 0.14865,
#   'station_proximities': {'Dagenham Heathway Station': 0.6528545228108056,
#    'Dagenham East Station': 0.8815098250851147,
#    'Becontree Station': 1.1991523163302213},
#   'property_size': {},
#   'bedrooms': 3,
#   'bathrooms': None,
#   'new_build': False},
#  '463, Rainham Road South, Dagenham, Greater London RM10 7XP': {'property_type': 'Semi-Detached',
#   'price': '£401,000',
#   'date': '29 Mar 2022',
#   'url': ''},
#  '93, Gay Gardens, Dagenham, Greater London RM10 7TD': {'property_type': 'Terraced',
#   'price': '£450,000',
#   'date': '24 Mar 2022',
#   'url': 'https://www.rightmove.co.uk/house-prices/details/england-113436419-93086136?s=5655f61eb17274b446951797a235aa1936033678dae594ddb424c82670b6659a',
#   'features': ['Family Home',
#    'Open Plan Living',
#    'Lounge/Dining Room',
#    'Modern Kitchen/Breakfast Room',
#    'Modern Shower Room',
#    'Double Glazing',
#    'Gas Central Heating',
#    'No Chain',
#    'Contemporary Decor',
#    'Garage &amp; Off Road Parking'],
#   'floorplan_url': 'https://media.rightmove.co.uk/239k/238277/113436419/238277_S42062_FLP_00_0000.jpeg',
#   'latitude': 51.548382,
#   'longitude': 0.164504,
#   'station_proximities': {'Dagenham East Station': 0.303119806685548,
#    'Dagenham Heathway Station': 0.8648226934681791,
#    'Elm Park Station': 1.4369442025329007},
#   'property_size': {},
#   'bedrooms': 3,
#   'bathrooms': 1,
#   'new_build': False},
#  '53, Crescent Road, Dagenham, Greater London RM10 7HS': {'property_type': 'Terraced',
#   'price': '£270,000',
#   'date': '21 Mar 2022',
#   'url': ''},
#  '24, Greenwood Avenue, Dagenham, Greater London RM10 7DL': {'property_type': 'Semi-Detached',
#   'price': '£425,000',
#   'date': '11 Mar 2022',
#   'url': 'https://www.rightmove.co.uk/house-prices/details/england-113231633-15073171?s=68ed69c9e6bae0169abddb3e0a6d145f25d1a85c9388622b6c47987aad92725a',
#   'features': ['Three Good Sized Bedrooms',
#    "1930's Semi Detached Family Home",
#    'Kitchen/Diner',
#    'Lounge',
#    'Garden Room',
#    'Gas Central Heating',
#    'Attractive Rear Garden Measuring Approx 100ft ',
#    'Offers and Abundance of Potential',
#    'Within Easy Reach to Local Schools, Shops and Amenities',
#    'Close to Dagenham East Tube Station and Transport Links'],
#   'floorplan_url': 'https://media.rightmove.co.uk/238k/237173/113231633/237173_102741013544_FLP_00_0000.png',
#   'latitude': 51.55295,
#   'longitude': 0.1623,
#   'station_proximities': {'Dagenham East Station': 0.6319928722733894,
#    'Dagenham Heathway Station': 1.006875299832901,
#    'Elm Park Station': 1.5457068712199835},
#   'property_size': {},
#   'bedrooms': 3,
#   'bathrooms': 1,
#   'new_build': False},
#  ...}

# %%
# change price from a string into an int
def price_int(x):
    a = x[1:]
    b = a.replace(",", "")
    b = int(b)
    return b

for features in houses.values():
    y = features['price']
    z = price_int(y)
    features['price'] = z

# %%
houses
# Out:
# {'105, Canonsleigh Road, Dagenham, Greater London RM9 4DH': {'property_type': 'Terraced',
#   'price': 390000,
#   'date': '16 May 2022',
#   'url': ''},
#  '59, Bateman Close, Barking, Greater London IG11 8QS': {'property_type': 'Flat',
#   'price': 225000,
#   'date': '12 May 2022',
#   'url': 'https://www.rightmove.co.uk/house-prices/details/england-123105338-14974252?s=791fe9e857a8dea92f2d04177af0a010ed90647d8449404cd8f3099af0e6d49f',
#   'features': [],
#   'floorplan_url': 'https://media.rightmove.co.uk/60k/59646/123105338/59646_CW0434_FLP_00_0000.jpeg',
#   'latitude': 51.54126,
#   'longitude': 0.08243,
#   'station_proximities': {'Barking Station': 0.14006575393753187,
#    'Upney Station': 0.8457992920654402,
#    'Ilford Station': 1.3208233936340128},
#   'property_size': {'ac': 0.01, 'ha': 0, 'sqft': 506, 'sqm': 47},
#   'bedrooms': 1,
#   'bathrooms': 1,
#   'new_build': False},
#  '54, Greenslade Road, Barking, Greater London IG11 9XE': {'property_type': 'Flat',
#   'price': 241000,
#   'date': '11 May 2022',
#   'url': 'https://www.rightmove.co.uk/house-prices/details/england-115102496-14974342?s=fb8af65fb80afb811abebb05215fd28bcdff9193da6b48bc501dcafc411ba4ac',
#   'features': ['EPC RATING D',
#    'Two bedrooms',
#    'Lounge',
#    'Kitchen',
#    'Bathroom',
#    'Parking',
#    'Close to Barking Station',
#    'Lease 164 years'],
#   'latitude': 51.538168,
#   'longitude': 0.089375,
#   'station_proximities': {'Barking Station': 0.34386191509746006,
#    'Upney Station': 0.5216595998294455,
#    'East Ham Station': 1.6301863560020884},
#   'property_size': {},
#   'bedrooms': 2,
#   'bathrooms': 1,
#   'new_build': False},
#  '21, Felton Road, Barking, Greater London IG11 7XZ': {'property_type': 'Terraced',
#   'price': 435000,
#   'date': '10 May 2022',
#   'url': 'https://www.rightmove.co.uk/house-prices/details/england-114572909-14974216?s=e0e73f3737db9e443df7a9d41022456ec205747086c32884e5c7ed295cb34da6',
#   'features': ['EPC - D',
#    'Side access',
#    'End terraced house',
#    'Three bedrooms',
#    'Large reception',
#    'Kitchen/Diner',
#    'Gas central heating',
#    'Double glazing'],
#   'floorplan_url': 'https://media.rightmove.co.uk/14k/13345/114572909/13345_31014351_FLP_00_0001.jpeg',
#   'latitude': 51.531142,
#   'longitude': 0.093814,
#   'station_proximities': {'Upney Station': 0.5961229381400764,
#    'Barking Station': 0.7714892849810918,
#    'Becontree Station': 1.5597990404450608},
#   'property_size': {},
#   'bedrooms': 3,
#   'bathrooms': 1,
#   'new_build': False},
#  '28, Sparsholt Road, Barking, Greater London IG11 7YQ': {'property_type': 'Terraced',
#   'price': 337000,
#   'date': '29 Apr 2022',
#   'url': 'https://www.rightmove.co.uk/house-prices/details/england-120065753-14974225?s=1fe88f997bfaa202d7ad1789b68eebb3c6bd7ea562dad14d7d8ca3c00523bd2d',
#   'features': ["FOR SALE BY ONLINE AUCTION T&amp;C'S APPLY",
#    'Fantastic size living space',
#    'Lovely size lounge/diner',
#    'Modern Kitchen',
#    'Modern Bathroom',
#    'Separate WC',
#    'Nice Size Rear Garden',
#    '0.5 miles to Upney station and 0.6 miles to Barking station',
#    'Great investment with a potential yield of 5.9%'],
#   'floorplan_url': 'https://media.rightmove.co.uk/75k/74660/120065753/74660_393158_FLP_00_0000.jpeg',
#   'latitude': 51.53375,
#   'longitude': 0.09174,
#   'station_proximities': {'Upney Station': 0.5252772877650792,
#    'Barking Station': 0.5814680261545995,
#    'Becontree Station': 1.5820836475328188},
#   'property_size': {},
#   'bedrooms': 2,
#   'bathrooms': None,
#   'new_build': False},
#  '36, Halsham Crescent, Barking, Greater London IG11 9HG': {'property_type': 'Terraced',
#   'price': 500000,
#   'date': '14 Apr 2022',
#   'url': 'https://www.rightmove.co.uk/house-prices/details/england-112852988-92994882?s=917f38af7b974ef5309fe5d6733a7c7b33734cb5526f69470334fd49cc06ba8e',
#   'features': ['LEFTLEY ESTATE',
#    'THREE BEDROOM TERRACE HOUSE',
#    'TWO RECEPTION ROOMS',
#    'GOOD SIZE GARDEN',
#    'GREAT LOCATION',
#    'CATCHMENT AREA FOR MANOR SCHOOL'],
#   'latitude': 51.54652,
#   'longitude': 0.10012,
#   'station_proximities': {'Upney Station': 0.5699910847643922,
#    'Barking Station': 0.9413842456733089,
#    'Seven Kings Station': 1.1818231602745783},
#   'property_size': {},
#   'bedrooms': 3,
#   'bathrooms': 1,
#   'new_build': False},
#  '10a, Sandringham Road, Barking, Greater London IG11 9AA': {'property_type': 'Semi-Detached',
#   'price': 645000,
#   'date': '14 Apr 2022',
#   'url': 'https://www.rightmove.co.uk/house-prices/details/england-113907608-14974270?s=1cb2cd4d9884ef7edef8f8e670dcc00ff1ed6184a1c7a992587d2dc3bcbdbb82',
#   'features': ['EPC RATING D',
#    'Three bedrooms',
#    'One reception room',
#    'Kitchen',
#    'Bathroom',
#    'Garden',
#    'Double garage'],
#   'floorplan_url': 'https://media.rightmove.co.uk/14k/13345/113907608/13345_30975020_FLP_00_0002.jpeg',
#   'latitude': 51.541494,
#   'longitude': 0.098756,
#   'station_proximities': {'Upney Station': 0.24872581115434403,
#    'Barking Station': 0.7547301668936481,
#    'Becontree Station': 1.2185546139356807},
#   'property_size': {},
#   'bedrooms': 3,
#   'bathrooms': 2,
#   'new_build': False},
#  '60, Wedderburn Road, Barking, Greater London IG11 7XG': {'property_type': 'Terraced',
#   'price': 405000,
#   'date': '14 Apr 2022',
#   'url': 'https://www.rightmove.co.uk/house-prices/details/england-52948397-92994828?s=a309abe85f55987c1ccb7c22c2ca0f6e0828295459737b692814a492cf48de38',
#   'features': ['GCH',
#    'Excellent Condition',
#    'Double Glazing',
#    'Garden',
#    'Wooden Floors',
#    'SOLE AGENTS'],
#   'latitude': 51.53403,
#   'longitude': 0.08988,
#   'station_proximities': {'Barking Station': 0.5098781241574322,
#    'Upney Station': 0.5812033463890981,
#    'Becontree Station': 1.6540886256549543},
#   'property_size': {},
#   'bedrooms': 3,
#   'bathrooms': None,
#   'new_build': False},
#  '33, Westminster Gardens, Barking, Greater London IG11 0BJ': {'property_type': 'Terraced',
#   'price': 390000,
#   'date': '14 Apr 2022',
#   'url': 'https://www.rightmove.co.uk/house-prices/details/england-52658818-92994789?s=288d439e47c63d252304eba8af6627d23d80e05f4afc2d0b66344d119b049803',
#   'features': ['first floor bathroom',
#    'Fitted Kitchen',
#    'Ideal Family Home',
#    'Large private rear garden',
#    'Must be seen ',
#    'Newly refurbished property ',
#    'No Ground Rent',
#    'No Onward Chain',
#    'Off-street parking',
#    'Sought After Location'],
#   'floorplan_url': 'https://media.rightmove.co.uk/46k/45641/52658818/45641_RS0048_FLP_01_0000.jpg',
#   'latitude': 51.528289,
#   'longitude': 0.089402,
#   'station_proximities': {'Barking Station': 0.832241141350607,
#    'Upney Station': 0.8671630349044476,
#    'Beckton Station': 1.5334639362038498},
#   'property_size': {},
#   'bedrooms': 3,
#   'bathrooms': 2,
#   'new_build': False},
#  '29, Edgefield Avenue, Barking, Greater London IG11 9JL': {'property_type': 'Terraced',
#   'price': 515000,
#   'date': '8 Apr 2022',
#   'url': 'https://www.rightmove.co.uk/house-prices/details/england-121862396-92994888?s=fd9029ec9aa9ed7353c517e7a7038b69faff7d36300913b257abfa5eb9f3179b',
#   'features': [],
#   'latitude': 51.53912,
#   'longitude': 0.103353,
#   'station_proximities': {'Upney Station': 0.09824976396690367,
#    'Barking Station': 0.9376520333844574,
#    'Becontree Station': 1.0198116402067932},
#   'property_size': {},
#   'bedrooms': 3,
#   'bathrooms': None,
#   'new_build': False},
#  '164, Park Avenue, Barking, Greater London IG11 8QY': {'property_type': 'Terraced',
#   'price': 530000,
#   'date': '8 Apr 2022',
#   'url': 'https://www.rightmove.co.uk/house-prices/details/england-51746176-92994861?s=5a780d399bc19659f402dba1ebb59cd8174776b06ad0b790a8924d74d4cf287c',
#   'features': [],
#   'floorplan_url': 'https://media.rightmove.co.uk/1k/218/51746176/218_BAR150376_FLP_00_0000.JPG',
#   'latitude': 51.54401,
#   'longitude': 0.07952,
#   'station_proximities': {'Barking Station': 0.3379233592816707,
#    'Upney Station': 1.0249779777248265,
#    'Ilford Station': 1.0960083062163342},
#   'property_size': {},
#   'bedrooms': 3,
#   'bathrooms': None,
#   'new_build': False},
#  '94, Bastable Avenue, Barking, Greater London IG11 0LF': {'property_type': 'Flat',
#   'price': 260000,
#   'date': '8 Apr 2022',
#   'url': 'https://www.rightmove.co.uk/house-prices/details/england-109820012-14974165?s=4bd7096afbb213554a3c080e5954430735a9cf5df784927f9bc041c5ebf82ae4',
#   'features': [],
#   'floorplan_url': 'https://media.rightmove.co.uk/75k/74746/109820012/74746_102491002028_FLP_00_0000.png',
#   'latitude': 51.52776,
#   'longitude': 0.09868,
#   'station_proximities': {'Upney Station': 0.7400455046313016,
#    'Barking Station': 1.0856680536134722,
#    'Becontree Station': 1.4917201908735183},
#   'property_size': {'sqm': 77, 'ac': 0.02, 'ha': 0.01, 'sqft': 833},
#   'bedrooms': 2,
#   'bathrooms': 1,
#   'new_build': False},
#  '127, Fanshawe Avenue, Barking, Greater London IG11 8RF': {'property_type': 'Terraced',
#   'price': 450000,
#   'date': '8 Apr 2022',
#   'url': 'https://www.rightmove.co.uk/house-prices/details/england-113843432-14974255?s=e9e666710babc3dcdb9ebe596efcc817c378009c842658392167879d8072e26a',
#   'features': ['FOUR BEDROOM VICTORIAN PROPERTY',
#    'REQUIRES FULL MODERNISATION',
#    'CLOSE TO BARKING STATION',
#    'CHAIN FREE',
#    'CLOSE TO LOCAL AMENITIES',
#    'BUS ROUTES'],
#   'floorplan_url': 'https://media.rightmove.co.uk/4k/3886/113843432/3886_BKG103028_FLP_00_0000.jpeg',
#   'latitude': 51.54266,
#   'longitude': 0.07975,
#   'station_proximities': {'Barking Station': 0.24578917611864165,
#    'Upney Station': 0.9834576898684728,
#    'Ilford Station': 1.1860461701933986},
#   'property_size': {},
#   'bedrooms': 4,
#   'bathrooms': 1,
#   'new_build': False},
#  'Flat 29, St Aidans Court, Blessing Way, Barking, Greater London IG11 0XH': {'property_type': 'Flat',
#   'price': 200000,
#   'date': '4 Apr 2022',
#   'url': 'https://www.rightmove.co.uk/house-prices/details/england-87964106-14974177?s=f176e14859ff2fd90bfa35054ab2f305f864da9fca1f267a45b57b57416742b9',
#   'features': [],
#   'floorplan_url': 'https://media.rightmove.co.uk/1k/218/87964106/218_BAR190118_FLP_01_0000.jpg',
#   'latitude': 51.52688,
#   'longitude': 0.11738,
#   'station_proximities': {'Becontree Station': 1.009110073824787,
#    'Upney Station': 1.0471651616276645,
#    'Dagenham Dock Station': 1.2494810416646394},
#   'property_size': {},
#   'bedrooms': 2,
#   'bathrooms': 1,
#   'new_build': False},
#  '405, Lodge Avenue, Dagenham, Greater London RM9 4QD': {'property_type': 'Terraced',
#   'price': 189400,
#   'date': '1 Apr 2022',
#   'url': ''},
#  '32, Sparsholt Road, Barking, Greater London IG11 7YQ': {'property_type': 'Terraced',
#   'price': 325000,
#   'date': '31 Mar 2022',
#   'url': 'https://www.rightmove.co.uk/house-prices/details/england-113118203-92994834?s=9cda147e83cd6dd287ef974a9077b85132146f1a57583983cf557d3dd17634f6',
#   'features': ['Two bedrooms',
#    'Great for first time buyer / investor house.',
#    'Located close by A13',
#    'Popular location'],
#   'floorplan_url': 'https://media.rightmove.co.uk/1k/218/113118203/218_BAR210259_FLP_00_0000.jpeg',
#   'latitude': 51.53373,
#   'longitude': 0.0916,
#   'station_proximities': {'Upney Station': 0.530937948871915,
#    'Barking Station': 0.5778671239983861,
#    'Becontree Station': 1.5882661865596484},
#   'property_size': {},
#   'bedrooms': 2,
#   'bathrooms': 1,
#   'new_build': False},
#  '13, Shirley Gardens, Barking, Greater London IG11 9UZ': {'property_type': 'Terraced',
#   'price': 500000,
#   'date': '31 Mar 2022',
#   'url': ''},
#  '16, Fairfield Road, Ilford, Greater London IG1 2JL': {'property_type': 'Terraced',
#   'price': 510000,
#   'date': '30 Mar 2022',
#   'url': 'https://www.rightmove.co.uk/house-prices/details/england-65174661-14973853?s=9cd589c64d020ab74b6938eec5586cfa327679429b975fc1ccb4d83f1c5f1f94',
#   'features': ['FOUR BEDROOM MID TERRACE HOUSE',
#    'TWO RECEPTION ROOM',
#    'TWO BATHROOM',
#    'LARGE KITCHEN/DINNER',
#    'EXCEPTIONALLY LARGE OUTHOUSE',
#    'EXCELLENT CONDITION THROUGHOUT',
#    'PERFECT FAMILY HOME',
#    'CLOSE TO A VAST ARRAY SHOPS AND RESTAURANTS',
#    'CLOSE ILFORD &amp; BARKING TRAIN STATION'],
#   'latitude': 51.544511,
#   'longitude': 0.074814,
#   'station_proximities': {'Barking Station': 0.4644385106912864,
#    'Ilford Station': 0.9993493362909769,
#    'East Ham Station': 1.061148168400449},
#   'property_size': {},
#   'bedrooms': 4,
#   'bathrooms': 2,
#   'new_build': False},
#  '20, Faircross Mansions, Longbridge Road, Barking, Greater London IG11 8UP': {'property_type': 'Flat',
#   'price': 228000,
#   'date': '30 Mar 2022',
#   'url': ''},
#  '420, Lodge Avenue, Dagenham, Greater London RM9 4QU': {'property_type': 'Terraced',
#   'price': 410000,
#   'date': '29 Mar 2022',
#   'url': ''},
#  '408, Lodge Avenue, Dagenham, Greater London RM9 4QU': {'property_type': 'Terraced',
#   'price': 390000,
#   'date': '28 Mar 2022',
#   'url': 'https://www.rightmove.co.uk/house-prices/details/england-121862465-93088068?s=2e46d60727e1fad410c31c2121b07dbd8382c8f295651cec2a523b0c9b01de79',
#   'features': [],
#   'floorplan_url': 'https://media.rightmove.co.uk/1k/232/121862465/232_DAG200427_FLP_00_0000.jpeg',
#   'latitude': 51.536049,
#   'longitude': 0.111575,
#   'station_proximities': {'Upney Station': 0.463184329534941,
#    'Becontree Station': 0.7220639783737582,
#    'Barking Station': 1.3115584889524814},
#   'property_size': {},
#   'bedrooms': 2,
#   'bathrooms': 1,
#   'new_build': False},
#  '3, Chilworth Place, Barking, Greater London IG11 0FL': {'property_type': 'Terraced',
#   'price': 302000,
#   'date': '25 Mar 2022',
#   'url': ''},
#  '14, Lyndhurst Gardens, Barking, Greater London IG11 9YB': {'property_type': 'Terraced',
#   'price': 520000,
#   'date': '25 Mar 2022',
#   'url': 'https://www.rightmove.co.uk/house-prices/details/england-115507229-14974348?s=fb81c898f1435f99e39376f58f9f43e12e8224c8a5f9067284bb174bbfdabe73',
#   'features': ['EPC RATING - C',
#    'THREE BEDROOMS',
#    'TWO RECEPTION ROOMS',
#    'FIRST FLOOR BATHROOM',
#    'GOOD SZIE GARDEN',
#    'SPACIOUS GARDEN',
#    'DOUBLE GLAZED WINDOWS'],
#   'floorplan_url': 'https://media.rightmove.co.uk/14k/13345/115507229/13345_31062102_FLP_00_0000.jpeg',
#   'latitude': 51.543991,
#   'longitude': 0.091938,
#   'station_proximities': {'Upney Station': 0.5680651324499264,
#    'Barking Station': 0.5509368062395386,
#    'Seven Kings Station': 1.3649051924939533},
#   'property_size': {},
#   'bedrooms': 3,
#   'bathrooms': 1,
#   'new_build': False},
#  '2, Cecil Avenue, Barking, Greater London IG11 9TA': {'property_type': 'Terraced',
#   'price': 530000,
#   'date': '24 Mar 2022',
#   'url': 'https://www.rightmove.co.uk/house-prices/details/england-108631253-14974333?s=d2f4054be45d25d382745b8d579f90d5591d2f76e9ea096d6fd67b0ca2b23ec2',
#   'features': ['EPC RATING - E',
#    'DOUBLE GLAZED WINDOWS',
#    'BASEMENT',
#    'GAS CENTRAL HEATING',
#    'REAR ACCESS TO GARDEN',
#    'FOUR BEDROOM HOUSE',
#    'END TERRACE',
#    'TWO LARGE RECEPTION ROOMS.'],
#   'floorplan_url': 'https://media.rightmove.co.uk/14k/13345/108631253/13345_30723151_FLP_00_0001.jpeg',
#   'latitude': 51.540587,
#   'longitude': 0.084162,
#   'station_proximities': {'Barking Station': 0.14152370339756776,
#    'Upney Station': 0.7626109116027343,
#    'East Ham Station': 1.405684005311977},
#   'property_size': {},
#   'bedrooms': 4,
#   'bathrooms': 1,
#   'new_build': False},
#  '157, Maplestead Road, Dagenham, Greater London RM9 4XU': {'property_type': 'Terraced',
#   'price': 338500,
#   'date': '23 Mar 2022',
#   'url': 'https://www.rightmove.co.uk/house-prices/details/england-59626675-15075376?s=20f0880c7ec7dc22907c7fa3aa8f2ecbf6caf41130e0ee3b641540a19cda3512',
#   'features': ['Three  Bedrooms',
#    'Terraced House',
#    'Lounge Dining ',
#    'Fitted Kitchen',
#    'Garden',
#    'Two Toilets',
#    'Three Piece Bathroom',
#    'Off Road Parking'],
#   'floorplan_url': 'https://media.rightmove.co.uk/152k/151079/59626675/151079_223115-1_FLP_07_0000.gif',
#   'latitude': 51.533498,
#   'longitude': 0.114764,
#   'station_proximities': {'Upney Station': 0.6631982072348066,
#    'Becontree Station': 0.700325420617907,
#    'Dagenham Dock Station': 1.4544425059528812},
#   'property_size': {},
#   'bedrooms': 3,
#   'bathrooms': 1,
#   'new_build': False},
#  '370a, Longbridge Road, Barking, Greater London IG11 9EF': {'property_type': 'Flat',
#   'price': 260000,
#   'date': '22 Mar 2022',
#   'url': 'https://www.rightmove.co.uk/house-prices/details/england-8660586-14974294?s=fd93cd34aedf9083f550bd71bf8efadcc013e3c97a393e77562c82d935297ca0',
#   'features': ['Laminated Flooring',
#    '2 Large Bedrooms',
#    'Study Room',
#    'New Fitted Kitchen',
#    'New Bathroom',
#    'Good Condition',
#    'No Chain',
#    'Communal Gardens',
#    'Close To Barking Station',
#    'Ideal For 1st Time Buyers'],
#   'latitude': 51.54866,
#   'longitude': 0.10166,
#   'station_proximities': {'Upney Station': 0.7150342372374018,
#    'Seven Kings Station': 1.046127257703796,
#    'Barking Station': 1.079914742808776},
#   'property_size': {},
#   'bedrooms': 2,
#   'bathrooms': None,
#   'new_build': False},
#  '16, Sutton Road, Barking, Greater London IG11 7YD': {'property_type': 'Terraced',
#   'price': 307500,
#   'date': '21 Mar 2022',
#   'url': ''},
#  '94, Waterside Close, Barking, Greater London IG11 9EQ': {'property_type': 'Flat',
#   'price': 265000,
#   'date': '18 Mar 2022',
#   'url': 'https://www.rightmove.co.uk/house-prices/details/england-107667539-14974297?s=146d2eed88b3111d835db2f70ae40a366653b9cd99ef8c7d98b3a6bd38654f32',
#   'features': ['TWO BEDROOM MAISONETTE',
#    'CHAIN FREE',
#    'COMMUNAL GARDENS',
#    'ALLOCATED PARKING SPACE',
#    'CLOSE TO TRANSPORT LINKS AND AMENITIES'],
#   'floorplan_url': 'https://media.rightmove.co.uk/4k/3886/107667539/3886_BKG102836_FLP_01_0000.jpeg',
#   'latitude': 51.55008,
#   'longitude': 0.10749,
#   'station_proximities': {'Upney Station': 0.8535964991823323,
#    'Seven Kings Station': 1.0343003587199844,
#    'Goodmayes Station': 1.0750775911358563},
#   'property_size': {},
#   'bedrooms': 2,
#   'bathrooms': 1,
#   'new_build': False},
#  '382, Lodge Avenue, Dagenham, Greater London RM9 4QX': {'property_type': 'Terraced',
#   'price': 357000,
#   'date': '18 Mar 2022',
#   'url': 'https://www.rightmove.co.uk/house-prices/details/england-115494677-15075370?s=ce5568208de729141fdab3ba4270054468a3491d17a10381520e9b5097571fcd',
#   'features': ['Three Bedroom Terrace House',
#    'Mid-Terraced House',
#    'Family Bathroom',
#    'One Reception',
#    'Double Glazed &amp; Gas Central Heating',
#    'Private Rear Garden',
#    'Potential To Extend (STPP)'],
#   'floorplan_url': 'https://media.rightmove.co.uk/203k/202751/115494677/202751_1266758-1_FLP_00_0000.jpeg',
#   'latitude': 51.537264,
#   'longitude': 0.11209,
#   'station_proximities': {'Upney Station': 0.46373903682763523,
#    'Becontree Station': 0.6717586020978101,
#    'Barking Station': 1.321858627572797},
#   'property_size': {},
#   'bedrooms': 3,
#   'bathrooms': 1,
#   'new_build': False},
#  '254, Stamford Road, Dagenham, Greater London RM9 4EJ': {'property_type': 'Terraced',
#   'price': 345000,
#   'date': '16 Mar 2022',
#   'url': 'https://www.rightmove.co.uk/house-prices/details/england-114224180-93088053?s=45797d911004150be68ca7e8669dc9ae7b8ae75b9acf64e80186739487b54ada',
#   'features': ['Two Bedroom Mid Terraced Property',
#    'First Floor Shower Room',
#    'Well Maintained Throughout',
#    'Off Street Parking',
#    'No Onward Chain',
#    'Close To Becontree Station'],
#   'floorplan_url': 'https://media.rightmove.co.uk/203k/202751/114224180/202751_1252686-1_FLP_00_0000.jpeg',
#   'latitude': 51.535807,
#   'longitude': 0.115109,
#   'station_proximities': {'Becontree Station': 0.5937586647679007,
#    'Upney Station': 0.613281232826402,
#    'Dagenham Heathway Station': 1.4588073348148916},
#   'property_size': {},
#   'bedrooms': 2,
#   'bathrooms': 1,
#   'new_build': False},
#  'Flat 6, Victory Court, Atlantis Close, Barking, Greater London IG11 0GP': {'property_type': 'Flat',
#   'price': 248000,
#   'date': '11 Mar 2022',
#   'url': 'https://www.rightmove.co.uk/house-prices/details/england-116231291-92994795?s=f73f6786dda27898bd0806ead21439af15a9e28cd79b7d29012bccdbc3c56a6e',
#   'features': ['2nd Floor flat set in a secure development',
#    'Delightful reception with a Juliette balcony',
#    'Separate kitchen with integrated appliances',
#    '2 Double bedrooms',
#    'Modern bathroom'],
#   'floorplan_url': 'https://media.rightmove.co.uk/182k/181043/116231291/181043_1188722_FLP_00_0000.png',
#   'latitude': 51.52235,
#   'longitude': 0.111355,
#   'station_proximities': {'Upney Station': 1.1837250893492084,
#    'Becontree Station': 1.4054333167392936,
#    'Dagenham Dock Station': 1.5300990261489877},
#   'property_size': {'sqft': 599, 'ha': 0.01, 'sqm': 56, 'ac': 0.01},
#   'bedrooms': 2,
#   'bathrooms': 1,
#   'new_build': False},
#  '52, Capel Gardens, Ilford, Greater London IG3 9DG': {'property_type': 'Terraced',
#   'price': 540000,
#   'date': '7 Mar 2022',
#   'url': 'https://www.rightmove.co.uk/house-prices/details/england-43058264-14974486?s=b969950deddc27687ddc83559c5eae4edb42f5baab31165c1a00b59437275e6d',
#   'features': ['Beautiful three bedroom ',
#    'Two receptions',
#    'Newly refurbished',
#    'Black gloss fully fitted kitchen open plan to lounge',
#    'Ground floor guest W/C',
#    'Landscaped garden and built in shed',
#    'Neutral decor throughout',
#    'Gas central heating, double glazed',
#    'Off street parking',
#    'Close to barking tube and Seven Kings Rail Station'],
#   'latitude': 51.55072,
#   'longitude': 0.10175,
#   'station_proximities': {'Upney Station': 0.8575167212809995,
#    'Seven Kings Station': 0.9078260316660406,
#    'Goodmayes Station': 1.0932723365051582},
#   'property_size': {},
#   'bedrooms': 3,
#   'bathrooms': 2,
#   'new_build': False},
#  '31, Bateman Close, Barking, Greater London IG11 8QR': {'property_type': 'Flat',
#   'price': 240000,
#   'date': '7 Mar 2022',
#   'url': 'https://www.rightmove.co.uk/house-prices/details/england-54611797-14974246?s=2f409d0b57aa70b6b38335a7f37a9bf5aa205bd75e79a39c129f49b3a8306d8c',
#   'features': ['ONE BEDROOM',
#    'FIRST FLOOR',
#    'DOUBLE BEDROOM',
#    'WALKING DISTANCE TO STATION',
#    'CLOSE TO SCHOOLS',
#    'CHAIN FREE'],
#   'floorplan_url': 'https://media.rightmove.co.uk/12k/11664/54611797/11664_0041_HRT004111612_FLP_01_0001.JPG',
#   'latitude': 51.54128,
#   'longitude': 0.08142,
#   'station_proximities': {'Barking Station': 0.13715729068976681,
#    'Upney Station': 0.8884528194164957,
#    'East Ham Station': 1.2916589213582352},
#   'property_size': {},
#   'bedrooms': 1,
#   'bathrooms': 1,
#   'new_build': False},
#  '90, Lambourne Road, Barking, Greater London IG11 9QA': {'property_type': 'Terraced',
#   'price': 340000,
#   'date': '4 Mar 2022',
#   'url': 'https://www.rightmove.co.uk/house-prices/details/england-112610513-14974318?s=662a2cef26de3f49ab920192bb89c4619034836870fe414b8498116144a8d623',
#   'features': ['ClOSE TO UPNEY STATION',
#    'TWO BEDROOMS',
#    'LOUNGE',
#    'DINER',
#    'KITCHEN',
#    'FIRST FLOOR BATHROOM',
#    'FF WC',
#    'REAR GARDEN',
#    'NO ONWARD CHAIN',
#    'IDEAL FIRST HOME'],
#   'latitude': 51.537578,
#   'longitude': 0.098592,
#   'station_proximities': {'Upney Station': 0.1342919849954579,
#    'Barking Station': 0.7419026453142522,
#    'Becontree Station': 1.2357615119066938},
#   'property_size': {},
#   'bedrooms': 2,
#   'bathrooms': 1,
#   'new_build': False},
#  '2, Lupin Crescent, Ilford, Greater London IG1 2JR': {'property_type': 'Terraced',
#   'price': 440000,
#   'date': '4 Mar 2022',
#   'url': 'https://www.rightmove.co.uk/house-prices/details/england-19764388-14973856?s=b528c10e63636eac0839ca3b150e79292d66eab65d60075592e9e92b614c0004',
#   'features': ['Fully Furnished',
#    'Shops and amenities nearby',
#    'Fitted Kitchen',
#    'Double glazing',
#    'Close to public transport',
#    'Garden',
#    'Parking'],
#   'latitude': 51.54433,
#   'longitude': 0.07204,
#   'station_proximities': {'Barking Station': 0.5396715649904265,
#    'East Ham Station': 0.9446605884298649,
#    'Ilford Station': 0.9913738644344926},
#   'property_size': {},
#   'bedrooms': 4,
#   'bathrooms': None,
#   'new_build': False},
#  'Flat 114, Academy Court, 566, Longbridge Road, Dagenham, Greater London RM8 2AR': {'property_type': 'Flat',
#   'price': 240000,
#   'date': '28 Feb 2022',
#   'url': ''},
#  '35, Ridley Close, Barking, Greater London IG11 9PJ': {'property_type': 'Flat',
#   'price': 285000,
#   'date': '25 Feb 2022',
#   'url': 'https://www.rightmove.co.uk/house-prices/details/england-113049578-14974315?s=55197aad147ed5207aaca850768ff80e4e757f8fed24489a9e0f7e1aa94c42bb',
#   'features': ['Great investment',
#    'Great first time purchase',
#    'Local to Upney station',
#    '110 year lease (Approx to be confirmed) ',
#    'En-suite to main bedroom',
#    'Fantastic transport links'],
#   'floorplan_url': 'https://media.rightmove.co.uk/1k/218/113049578/218_BAR210252_FLP_00_0000.jpeg',
#   'latitude': 51.53998,
#   'longitude': 0.09909,
#   'station_proximities': {'Upney Station': 0.15397375174994432,
#    'Barking Station': 0.7552047598353046,
#    'Becontree Station': 1.2009796102388153},
#   'property_size': {},
#   'bedrooms': 2,
#   'bathrooms': 2,
#   'new_build': False},
#  '73, Westbury Road, Barking, Greater London IG11 7PL': {'property_type': 'Flat',
#   'price': 203000,
#   'date': '25 Feb 2022',
#   'url': 'https://www.rightmove.co.uk/house-prices/details/england-112583789-14974198?s=7633c1bb8ddc95b99c8d123f98605bf3c49ac4efd37c356fbae31b40b3e90884',
#   'features': ['Chain Free',
#    'Double Glazing',
#    'Easy Reach of C2C station',
#    'Fitted Kitchen',
#    'Entry Phone System ',
#    'Excellent Condition'],
#   'floorplan_url': 'https://media.rightmove.co.uk/75k/74609/112583789/74609_RS0023_FLP_00_0000.jpeg',
#   'latitude': 51.534513,
#   'longitude': 0.084883,
#   'station_proximities': {'Barking Station': 0.3598445356923717,
#    'Upney Station': 0.7621869019795803,
#    'East Ham Station': 1.4733403500977942},
#   'property_size': {},
#   'bedrooms': 1,
#   'bathrooms': 1,
#   'new_build': False},
#  '30, Cavendish Gardens, Barking, Greater London IG11 9DU': {'property_type': 'Semi-Detached',
#   'price': 550000,
#   'date': '24 Feb 2022',
#   'url': ''},
#  '73, Essex Road, Barking, Greater London IG11 7QN': {'property_type': 'Terraced',
#   'price': 500000,
#   'date': '23 Feb 2022',
#   'url': 'https://www.rightmove.co.uk/house-prices/details/england-120535865-14974204?s=d47a5dcb2cf2991c67e40b8d10371e3817e510d357a57bcdf34d701fa222684a',
#   'features': [],
#   'latitude': 51.536631,
#   'longitude': 0.086987,
#   'station_proximities': {'Barking Station': 0.2963479544162566,
#    'Upney Station': 0.6353644248583672,
#    'East Ham Station': 1.5368841904161161},
#   'property_size': {},
#   'bedrooms': 5,
#   'bathrooms': 2,
#   'new_build': False},
#  '135, St Awdrys Road, Barking, Greater London IG11 7QE': {'property_type': 'Terraced',
#   'price': 395000,
#   'date': '18 Feb 2022',
#   'url': 'https://www.rightmove.co.uk/house-prices/details/england-79889283-14974201?s=4b476d3055c5fcbfec0b10308426e741f30fbced9cd32fe56ff74f82f416065d',
#   'features': ['Full Of Character',
#    'Excellently Maintained Throughout',
#    'Two Double Bedrooms',
#    'First Floor Family Bath/Shower Suite',
#    'Further Scope To Extend STPP',
#    'Benefitting With Rear Access',
#    '0.2 Miles From Barking Town &amp; Station',
#    'Surrounded With Excellent Transport Facilities',
#    'Local To Shops, Supermarkets &amp; Schools',
#    'Local To A406, A13 &amp; M11 Roads'],
#   'floorplan_url': 'https://media.rightmove.co.uk/205k/204362/79889283/204362_224613_FLP_00_0000.jpeg',
#   'latitude': 51.537237,
#   'longitude': 0.0839,
#   'station_proximities': {'Barking Station': 0.17349538845328888,
#    'Upney Station': 0.7613432153479548,
#    'East Ham Station': 1.3998231566376431},
#   'property_size': {},
#   'bedrooms': 2,
#   'bathrooms': 1,
#   'new_build': False},
#  '5, Graham Mansions, Lansbury Avenue, Barking, Greater London IG11 9NL': {'property_type': 'Flat',
#   'price': 260000,
#   'date': '18 Feb 2022',
#   'url': ''},
#  '18, Rosedale Gardens, Dagenham, Greater London RM9 4EA': {'property_type': 'Terraced',
#   'price': 340000,
#   'date': '18 Feb 2022',
#   'url': 'https://www.rightmove.co.uk/house-prices/details/england-21263060-15075340?s=48d7cc2206113d50961d9f07bbd001959bb387ff4ce5e0e3715ccb7aaf47a779',
#   'features': ['TWO-BEDROOM HOME WITH OWN DRIVEWAY PARKING',
#    "LOUNGE : 12' 11 x 12' 8 (3.94m x 3.86m)",
#    "FITTED KITCHEN : 10' 3 x 8' 2 (3.12m x 2.49m)",
#    "SUN LOUNGE AT THE BACK OF THE HOUSE TO LINK THE KITCHEN WITH A SEPARATE DINING AREA : 11' 0 x 7' 6 (",
#    'RADIATOR CENTRAL HEATING\tUPVC DOUBLE-GLAZED WINDOWS &amp; DOORS',
#    "BEDROOM ONE WITH STYLISH FURNITURE : 16' 2 x 9' 11 (4.94m x 3.02m)",
#    "BEDROOM TWO WITH FITTED WARDROBES : 11' 7 x 9' 10 (3.54m x 2.99m)",
#    'UPSTAIRS BATHROOM/WC'],
#   'latitude': 51.53665,
#   'longitude': 0.11423,
#   'station_proximities': {'Upney Station': 0.5622253662311234,
#    'Becontree Station': 0.6005327741574055,
#    'Barking Station': 1.4185145413241877},
#   'property_size': {},
#   'bedrooms': 2,
#   'bathrooms': None,
#   'new_build': False},
#  '199, Westrow Drive, Barking, Greater London IG11 9BS': {'property_type': 'Terraced',
#   'price': 580000,
#   'date': '17 Feb 2022',
#   'url': 'https://www.rightmove.co.uk/house-prices/details/england-116740940-14974288?s=f83574206c32c01ac46bf28248a88fd3c9dc3344aa93979cfe4200b4ad22b067',
#   'features': ['Spacious garden',
#    '1 Bathroom',
#    '3 Bedrooms',
#    'Excellent transport links',
#    'Off street parking'],
#   'floorplan_url': 'https://media.rightmove.co.uk/239k/238325/116740940/238325_S23_FLP_00_0000.jpeg',
#   'latitude': 51.54668,
#   'longitude': 0.10661,
#   'station_proximities': {'Upney Station': 0.619102074880409,
#    'Becontree Station': 0.9844432745906524,
#    'Barking Station': 1.1926171675639554},
#   'property_size': {},
#   'bedrooms': 3,
#   'bathrooms': 1,
#   'new_build': False},
#  '9, Lodge Avenue, Dagenham, Greater London RM8 2JA': {'property_type': 'Terraced',
#   'price': 345000,
#   'date': '15 Feb 2022',
#   'url': 'https://www.rightmove.co.uk/house-prices/details/england-111005870-15075277?s=37820a7e6d6850f5fd206b3e49375802a0d9d5682e77d772511e4cdea0bd2b60',
#   'features': ['Two Bedroom House ',
#    'CHAIN FREE',
#    'Fully Refurbished',
#    'Good Transport Links ',
#    '70ft Plus Garden ',
#    'New Roof and Windows',
#    'Brand New Kitchen and Bathroom '],
#   'floorplan_url': 'https://media.rightmove.co.uk/51k/50598/111005870/50598_10976141_FLP_00_0000.jpeg',
#   'latitude': 51.55069,
#   'longitude': 0.113523,
#   'station_proximities': {'Becontree Station': 0.9277785315274418,
#    'Upney Station': 1.0008468225630884,
#    'Goodmayes Station': 1.0300969417944925},
#   'property_size': {},
#   'bedrooms': 2,
#   'bathrooms': 1,
#   'new_build': False},
#  '17, Stern Close, Barking, Greater London IG11 0XW': {'property_type': 'Terraced',
#   'price': 430000,
#   'date': '14 Feb 2022',
#   'url': 'https://www.rightmove.co.uk/house-prices/details/england-109400963-92994810?s=37cff2082441f58011a3c6bc2a32a4b4259a7e20ca618d90a8d80614aff72f3d',
#   'features': ['THREE BEDROOMS',
#    'THROUGH LOUNGE',
#    'CONSERVATORY',
#    'WELL-MAINTAINED REAR GARDEN',
#    'ATTACHED GARAGE'],
#   'floorplan_url': 'https://media.rightmove.co.uk/4k/3886/109400963/3886_BKG102885_FLP_01_0000.jpeg',
#   'latitude': 51.52775,
#   'longitude': 0.119,
#   'station_proximities': {'Becontree Station': 0.9264859690921198,
#    'Upney Station': 1.051543462870483,
#    'Dagenham Dock Station': 1.18401457623822},
#   'property_size': {},
#   'bedrooms': 3,
#   'bathrooms': 1,
#   'new_build': False},
#  '45, Devon Road, Barking, Greater London IG11 7QX': {'property_type': 'Terraced',
#   'price': 385000,
#   'date': '14 Feb 2022',
#   'url': 'https://www.rightmove.co.uk/house-prices/details/england-114297305-14974207?s=cbe25bac9264885bbf4c7af86f372e4d47c64fb4f4935dfd534d36f2a0327e75',
#   'features': ['CHAIN FREE',
#    'THREE BEDROOMS',
#    'CHARACTER PROPERTY',
#    'ORIGINAL FEATURES',
#    'CLOSE TO TRANSPORT LINKS'],
#   'floorplan_url': 'https://media.rightmove.co.uk/4k/3886/114297305/3886_BKG103083_FLP_00_0000.jpeg',
#   'latitude': 51.53426,
#   'longitude': 0.09191,
#   'station_proximities': {'Upney Station': 0.4987701671119957,
#    'Barking Station': 0.5645685157142195,
#    'Becontree Station': 1.5654227989904166},
#   'property_size': {},
#   'bedrooms': 3,
#   'bathrooms': 1,
#   'new_build': False},
#  '30, Sandringham Road, Barking, Greater London IG11 9AJ': {'property_type': 'Terraced',
#   'price': 565000,
#   'date': '11 Feb 2022',
#   'url': 'https://www.rightmove.co.uk/house-prices/details/england-115180100-14646448?s=f8c6264e0011b261280ab18d7cd8a660c5ae21bf4f2bd77aa1bb6e2ac6d75924',
#   'features': ['Sold by Douglas Allen',
#    'Potential to extend into the loft and rear (sstp)',
#    'Close to local shops and transport services',
#    'No Onward Chain',
#    'Has Integral garage as well as Off Road Parking',
#    'Walking Distance to Barking Abbey school as well as Barking Park',
#    'EPC energy rating E'],
#   'latitude': 51.54695,
#   'longitude': 0.10361,
#   'station_proximities': {'Upney Station': 0.6038361507771566,
#    'Barking Station': 1.08609613190931,
#    'Becontree Station': 1.1089177400515375},
#   'property_size': {},
#   'bedrooms': 4,
#   'bathrooms': 1,
#   'new_build': False},
#  '71, Woodbridge Road, Barking, Greater London IG11 9ES': {'property_type': 'Terraced',
#   'price': 540000,
#   'date': '11 Feb 2022',
#   'url': 'https://www.rightmove.co.uk/house-prices/details/england-80125011-14974300?s=24b01e29c295018cc0d03cef15ac0e649cadb28b7c3307f5a6386ed5e8b01ce2',
#   'features': ['LEFTLEY ESTATE',
#    'ATTACHED GARAGE',
#    'THREE BEDROOMS ',
#    'LARGE THROUGH LOUNGE',
#    'LARGE REAR GARDEN'],
#   'floorplan_url': 'https://media.rightmove.co.uk/4k/3886/80125011/3886_BKG102740_FLP_00_0000.jpeg',
#   'latitude': 51.54541,
#   'longitude': 0.10223,
#   'station_proximities': {'Upney Station': 0.49135109007637057,
#    'Barking Station': 0.9843626525793772,
#    'Becontree Station': 1.1246845406246906},
#   'property_size': {},
#   'bedrooms': 3,
#   'bathrooms': 1,
#   'new_build': False},
#  '53, Salisbury Avenue, Barking, Greater London IG11 9XQ': {'property_type': 'Terraced',
#   'price': 490000,
#   'date': '10 Feb 2022',
#   'url': 'https://www.rightmove.co.uk/house-prices/details/england-114792137-14646496?s=248d9fe18b9f2d9a9e68043c2a4dc4a333e52393d38ab2cd53ba21aa6c2fd5ce',
#   'features': [],
#   'floorplan_url': 'https://media.rightmove.co.uk/215k/214967/114792137/214967_TAE210042_FLP_00_0000.jpeg',
#   'latitude': 51.538441,
#   'longitude': 0.084489,
#   'station_proximities': {'Barking Station': 0.13762288236438938,
#    'Upney Station': 0.7322906262926747,
#    'East Ham Station': 1.4188240651988882},
#   'property_size': {},
#   'bedrooms': 3,
#   'bathrooms': 1,
#   'new_build': False},
#  'Flat 305, Orvis Court, 12, Mizzen Street, Barking, Greater London IG11 7RZ': {'property_type': 'Flat',
#   'price': 120000,
#   'date': '9 Feb 2022',
#   'url': ''},
#  '14, Dereham Road, Barking, Greater London IG11 9HA': {'property_type': 'Terraced',
#   'price': 490000,
#   'date': '4 Feb 2022',
#   'url': 'https://www.rightmove.co.uk/house-prices/details/england-110326247-92994879?s=f43f3daa74fbd9905e5d20856459df5274b5843fbc060b4294ccabd51033a4cd',
#   'features': ['Leftley Estate',
#    'Two Reception Rooms',
#    'Double Glazed',
#    'Gas Central Heating',
#    'Good Transport Links'],
#   'floorplan_url': 'https://media.rightmove.co.uk/4k/3886/110326247/3886_BKG102893_FLP_00_0001.jpeg',
#   'latitude': 51.54434,
#   'longitude': 0.10146,
#   'station_proximities': {'Upney Station': 0.41626927511767664,
#    'Barking Station': 0.9241258877011996,
#    'Becontree Station': 1.1353214723194032},
#   'property_size': {},
#   'bedrooms': 3,
#   'bathrooms': 1,
#   'new_build': False},
#  '135, Woodbridge Road, Barking, Greater London IG11 9BB': {'property_type': 'Semi-Detached',
#   'price': 575000,
#   'date': '4 Feb 2022',
#   'url': 'https://www.rightmove.co.uk/house-prices/details/england-123848204-14974279?s=698ff7fe3c2114f15b688175f00e950efbd2ca851896f67229245ee813c6c494',
#   'features': ['EPC rating 69C',
#    'Very Well Presented',
#    'Three Bedrooms',
#    'Fitted Kitchen/Diner',
#    'Large Rear Garden'],
#   'floorplan_url': 'https://media.rightmove.co.uk/14k/13345/123848204/13345_31541215_FLP_00_0000.jpeg',
#   'latitude': 51.54495,
#   'longitude': 0.10769,
#   'station_proximities': {'Upney Station': 0.5311350011412322,
#    'Becontree Station': 0.8926337214376585,
#    'Barking Station': 1.1904452608244547},
#   'property_size': {},
#   'bedrooms': 3,
#   'bathrooms': 1,
#   'new_build': False},
#  '1, Sandringham Road, Barking, Greater London IG11 9AA': {'property_type': 'Semi-Detached',
#   'price': 585000,
#   'date': '4 Feb 2022',
#   'url': 'https://www.rightmove.co.uk/house-prices/details/england-112352594-14974267?s=e516f0bd79b463933462f808d9142837b55da9a0c491474dccd6d99aa56fd657',
#   'features': [],
#   'floorplan_url': 'https://media.rightmove.co.uk/14k/13345/112352594/13345_30901850_FLP_00_0000.jpeg',
#   'latitude': 51.541284,
#   'longitude': 0.097815,
#   'station_proximities': {'Upney Station': 0.2585437244642707,
#    'Barking Station': 0.7120915446818354,
#    'Becontree Station': 1.2580778345728036},
#   'property_size': {},
#   'bedrooms': 4,
#   'bathrooms': 1,
#   'new_build': False},
#  'Flat 202, Trinity House, 11, Academy Way, Dagenham, Greater London RM8 2FD': {'property_type': 'Flat',
#   'price': 252500,
#   'date': '3 Feb 2022',
#   'url': ''},
#  '31, Whiting Avenue, Barking, Greater London IG11 8JH': {'property_type': 'Terraced',
#   'price': 455000,
#   'date': '3 Feb 2022',
#   'url': 'https://www.rightmove.co.uk/house-prices/details/england-115504121-14646424?s=e51b610503d55c37c215e2ead50428b32a2b824d48e502ccc6e7930e93ef281a',
#   'features': ['THREE BEDROOMS',
#    'THROUGH LOUNGE',
#    'REQUIRES MODERNISATION',
#    'GARAGE',
#    'CLOSE TO BARKING TOWN CENTRE'],
#   'latitude': 51.53963,
#   'longitude': 0.07327,
#   'station_proximities': {'Barking Station': 0.36034632791067117,
#    'East Ham Station': 0.9337132169641371,
#    'Upney Station': 1.2193740962760242},
#   'property_size': {},
#   'bedrooms': 3,
#   'bathrooms': 1,
#   'new_build': False},
#  'Flat 25, Seawall Court, Dock Road, Barking, Greater London IG11 7GP': {'property_type': 'Flat',
#   'price': 300000,
#   'date': '31 Jan 2022',
#   'url': 'https://www.rightmove.co.uk/house-prices/details/england-80408235-14974195?s=e9d3068e0424d6b5d9cd3e16c6de1fee7309ae10dd232d7ee8898b944a9137db',
#   'features': ['CHAIN FREE',
#    'OWN PRIVATE BALCONY',
#    'ALLOCATED PARKING SPACE',
#    'COMMUNAL TERRACE',
#    'EWS1 FORM PROVIDED'],
#   'floorplan_url': 'https://media.rightmove.co.uk/4k/3886/80408235/3886_BKG102786_FLP_00_0000.jpeg',
#   'latitude': 51.53049,
#   'longitude': 0.0766,
#   'station_proximities': {'Barking Station': 0.6463686173554458,
#    'Upney Station': 1.201433053676778,
#    'East Ham Station': 1.2403040313420326},
#   'property_size': {},
#   'bedrooms': 2,
#   'bathrooms': 1,
#   'new_build': False},
#  '74, Sheringham Drive, Barking, Greater London IG11 9AN': {'property_type': 'Terraced',
#   'price': 550000,
#   'date': '31 Jan 2022',
#   'url': ''},
#  '102, London Road, Barking, Greater London IG11 8DD': {'property_type': 'Flat',
#   'price': 220000,
#   'date': '28 Jan 2022',
#   'url': 'https://www.rightmove.co.uk/house-prices/details/england-107822297-14974234?s=5610d8f11fe5cf5ea1e454c52652ff384b01a5ad744bff220a1c60658ccb9c25',
#   'features': ['Attractive 2nd floor flat',
#    'Spacious and sleek kitchen with integrated appliances',
#    'Reception filled with light and room to dine',
#    'Private balcony overlooking communal areas',
#    '2 Lovely double bedrooms',
#    'Bathroom with refurb potential and separate WC'],
#   'floorplan_url': 'https://media.rightmove.co.uk/182k/181043/107822297/181043_1171884_FLP_00_0000.png',
#   'latitude': 51.537645,
#   'longitude': 0.074055,
#   'station_proximities': {'Barking Station': 0.3452962249613603,
#    'East Ham Station': 0.974834096755202,
#    'Upney Station': 1.183101838167258},
#   'property_size': {'sqm': 65, 'sqft': 699, 'ha': 0.01, 'ac': 0.02},
#   'bedrooms': 2,
#   'bathrooms': 1,
#   'new_build': False},
#  '52, Bradfield Drive, Barking, Greater London IG11 9AR': {'property_type': 'Terraced',
#   'price': 450000,
#   'date': '28 Jan 2022',
#   'url': 'https://www.rightmove.co.uk/house-prices/details/england-112470395-14646454?s=f253fc49f1088374a681512f8d823e89c44719c70e8521deb8780d2b82c472b7',
#   'features': ['THREE BEDROOMS',
#    'TWO SHOWER ROOMS',
#    'SET WITHIN LEFTLEY ESTATE',
#    'KITCHEN/DINER',
#    'OFF STREET PARKING'],
#   'floorplan_url': 'https://media.rightmove.co.uk/4k/3886/112470395/3886_BKG102951_FLP_00_0000.jpeg',
#   'latitude': 51.54651,
#   'longitude': 0.10603,
#   'station_proximities': {'Upney Station': 0.5994795039255645,
#    'Becontree Station': 1.0015997143226345,
#    'Barking Station': 1.1649862005923675},
#   'property_size': {},
#   'bedrooms': 3,
#   'bathrooms': 2,
#   'new_build': False},
#  '12a, Tudor Road, Barking, Greater London IG11 9RX': {'property_type': 'Flat',
#   'price': 270000,
#   'date': '24 Jan 2022',
#   'url': 'https://www.rightmove.co.uk/house-prices/details/england-109958681-14974327?s=19737d1df4fd54e4955548ccd4d9616780610c71213c258d846202e24ee539b6',
#   'features': ['TWO BEDROOM MAISONETTE',
#    'LARGE BRIGHT &amp; AIRY LOUNGE',
#    'SEPARATE KITCHEN',
#    'OWN PRIVATE REAR GARDEN',
#    'GOOD TRANSPORT LINKS'],
#   'floorplan_url': 'https://media.rightmove.co.uk/4k/3886/109958681/3886_BKG102887_FLP_00_0000.jpeg',
#   'latitude': 51.53503,
#   'longitude': 0.09916,
#   'station_proximities': {'Upney Station': 0.24834900169674237,
#    'Barking Station': 0.8123567163907831,
#    'Becontree Station': 1.2501349486967075},
#   'property_size': {},
#   'bedrooms': 2,
#   'bathrooms': 1,
#   'new_build': False},
#  '353, Lodge Avenue, Dagenham, Greater London RM9 4QB': {'property_type': 'Terraced',
#   'price': 333500,
#   'date': '24 Jan 2022',
#   'url': 'https://www.rightmove.co.uk/house-prices/details/england-110731718-15075364?s=9d478a4a64b8b838cd96c8a5dc0cc6d5bf5dec610f7b764e27bab4d39a88990d',
#   'features': ['Two Bedroom Terraced House',
#    'Two Double Bedrooms',
#    'Open Plan Living/Dining ',
#    'First Floor Family Bathroom',
#    'Potential To Extend ( S.T.P.P.) ',
#    'Well Maintained Rear Garden ',
#    'Off Street Parking ',
#    'Close Proximity To Local Amenities ',
#    'Close Proximity To Local Transport Links ',
#    'Close Proximity To Local Schools '],
#   'floorplan_url': 'https://media.rightmove.co.uk/167k/166871/110731718/166871_RS0271_FLP_00_0000.jpeg',
#   'latitude': 51.537029,
#   'longitude': 0.112631,
#   'station_proximities': {'Upney Station': 0.4894932441962669,
#    'Becontree Station': 0.6548215197616807,
#    'Barking Station': 1.3468581082427815},
#   'property_size': {},
#   'bedrooms': 2,
#   'bathrooms': 1,
#   'new_build': False},
#  '162, Canonsleigh Road, Dagenham, Greater London RM9 4DH': {'property_type': 'Terraced',
#   'price': 365000,
#   'date': '21 Jan 2022',
#   'url': 'https://www.rightmove.co.uk/house-prices/details/england-115760906-93088050?s=4f1f6786f52f1d4757eff388a58f07f23f5cc3963cdb08b0dfaa4becb395d66f',
#   'features': ['Mid-Terrace House',
#    'Two Double Bedrooms',
#    'Kitchen/Dining Area',
#    'Off Street Parking',
#    'Low Maintenance Rear Garden',
#    'UPVC Double Glazed Windows',
#    'Gas Central Heating (Untested By Griffin)',
#    'Modern Fitted Shower Room',
#    'Within Close Proximity To Becontree Station',
#    "Internal Viewing's Highly Recommended!"],
#   'latitude': 51.53767,
#   'longitude': 0.117704,
#   'station_proximities': {'Becontree Station': 0.43499318429934664,
#    'Upney Station': 0.7014785248041876,
#    'Dagenham Heathway Station': 1.3190017871733526},
#   'property_size': {},
#   'bedrooms': 2,
#   'bathrooms': 1,
#   'new_build': False},
#  '172, Westrow Drive, Barking, Greater London IG11 9BP': {'property_type': 'Terraced',
#   'price': 740000,
#   'date': '17 Jan 2022',
#   'url': 'https://www.rightmove.co.uk/house-prices/details/england-109850075-14974285?s=42f4cdc1702ff8df879ad4d942cc2995bbe16b0a5a3e7496e1de95e08bf9420e',
#   'features': ['FIVE BEDROOMS ',
#    'SEMI DETACHED HOUSE ',
#    'TWO RECEPTION ROOMS',
#    'FITTED KITCHEN / DINER ',
#    'OFF STREET PARKING FOR 4 CARS ',
#    'ATTACHED DOUBLE GARAGE   ',
#    'FULLY DOUBLE GLAZED ',
#    'GAS CENTRAL HEATING ',
#    'GROUND FLOOR CLOAKROOM /W.C.',
#    'POTENTIAL FOR FURTHER EXTENSION'],
#   'floorplan_url': 'https://media.rightmove.co.uk/7k/6489/109850075/6489_5557_FLP_00_0000.jpeg',
#   'latitude': 51.54408,
#   'longitude': 0.10621,
#   'station_proximities': {'Upney Station': 0.44766905129810663,
#    'Becontree Station': 0.9332282144505784,
#    'Barking Station': 1.1110116637624203},
#   'property_size': {},
#   'bedrooms': 5,
#   'bathrooms': None,
#   'new_build': False},
#  'Flat 42, Cromwell Lodge, Longbridge Road, Barking, Greater London IG11 8UB': {'property_type': 'Flat',
#   'price': 125000,
#   'date': '17 Jan 2022',
#   'url': ''},
#  '291, Sheppey Road, Dagenham, Greater London RM9 4JU': {'property_type': 'Terraced',
#   'price': 390000,
#   'date': '17 Jan 2022',
#   'url': ''},
#  '24, John Burns Drive, Barking, Greater London IG11 9RQ': {'property_type': 'Flat',
#   'price': 223000,
#   'date': '14 Jan 2022',
#   'url': 'https://www.rightmove.co.uk/house-prices/details/england-79570740-14974324?s=91437e91490165c4f4d2330de81f2bf9202ebca040df6837b8ebdcaceeca93da',
#   'features': ['TWO DOUBLE BEDROOM FLAT',
#    'THIRD FLOOR',
#    'LONG LEASE',
#    'FREE PARKING',
#    'GROUND FLOOR STORAGE FACILITIES',
#    'WALKING DISTANCE TO BARKING TOWN CENTRE',
#    'A SHORT WALK FROM UPNEY UNDERGROUND STATION',
#    'GUIDE PRICE OF £240,000 - £260,000'],
#   'floorplan_url': 'https://media.rightmove.co.uk/55k/54989/79570740/54989_jbd24_FLP_00_0000.png',
#   'latitude': 51.5362,
#   'longitude': 0.09431,
#   'station_proximities': {'Upney Station': 0.34178916694491146,
#    'Barking Station': 0.5881051430641587,
#    'Becontree Station': 1.4339812695319527},
#   'property_size': {},
#   'bedrooms': 2,
#   'bathrooms': 1,
#   'new_build': False},
#  '106, Roxwell Road, Barking, Greater London IG11 0PT': {'property_type': 'Terraced',
#   'price': 200000,
#   'date': '14 Jan 2022',
#   'url': 'https://www.rightmove.co.uk/house-prices/details/england-7790472-92994801?s=7729629a6c35619f6453f88b4c71eea11e5c98778b9623ae83e1f5277f4fdec8',
#   'features': ['Hallway',
#    'Bedroom x 1',
#    'Bedroom x 2',
#    'Bathroom',
#    'Kitchen',
#    'Reception'],
#   'latitude': 51.52818,
#   'longitude': 0.11023,
#   'station_proximities': {'Upney Station': 0.796455928729626,
#    'Becontree Station': 1.100052211237354,
#    'Barking Station': 1.4541769368042994},
#   'property_size': {},
#   'bedrooms': 2,
#   'bathrooms': None,
#   'new_build': False},
#  '242, Bastable Avenue, Barking, Greater London IG11 0LJ': {'property_type': 'Flat',
#   'price': 247000,
#   'date': '10 Jan 2022',
#   'url': 'https://www.rightmove.co.uk/house-prices/details/england-107852873-14974168?s=4192ada888f03cbcd07d14d4627d37d1aa1b5b4cb0db00e8bdac3057af175d34',
#   'features': ['Up and Coming Area',
#    'Fantastic Rail,  Bus and Road links into London',
#    'Schools , Shops and Amenities close by'],
#   'floorplan_url': 'https://media.rightmove.co.uk/1k/218/107852873/218_BAR210179_FLP_00_0001.jpeg',
#   'latitude': 51.527181,
#   'longitude': 0.11017,
#   'station_proximities': {'Upney Station': 0.8567602120634734,
#    'Becontree Station': 1.1547569572421539,
#    'Barking Station': 1.489727007311508},
#   'property_size': {},
#   'bedrooms': 2,
#   'bathrooms': 1,
#   'new_build': False},
#  '150, Morley Road, Barking, Greater London IG11 7DH': {'property_type': 'Terraced',
#   'price': 355000,
#   'date': '7 Jan 2022',
#   'url': 'https://www.rightmove.co.uk/house-prices/details/england-113232674-14974189?s=c080f935858837413a1561b49e5747dce55f8fe10bcad5570a6654b288093324',
#   'features': ['Calling all first time buyers / investors',
#    '0.6 miles walk from the station',
#    'Located convinent for the local shops'],
#   'floorplan_url': 'https://media.rightmove.co.uk/1k/218/113232674/218_BAR210299_FLP_00_0001.jpeg',
#   'latitude': 51.533626,
#   'longitude': 0.085653,
#   'station_proximities': {'Barking Station': 0.42933705866593097,
#    'Upney Station': 0.7553755786678661,
#    'East Ham Station': 1.520584437263029},
#   'property_size': {},
#   'bedrooms': 2,
#   'bathrooms': 1,
#   'new_build': False},
#  '469, Longbridge Road, Barking, Greater London IG11 9DG': {'property_type': 'Flat',
#   'price': 210000,
#   'date': '6 Jan 2022',
#   'url': ''},
#  'Flat 12, 1, Harbard Close, Barking, Greater London IG11 8SG': {'property_type': 'Flat',
#   'price': 192000,
#   'date': '20 Dec 2021',
#   'url': ''},
#  '21, Roxwell Road, Barking, Greater London IG11 0PP': {'property_type': 'Terraced',
#   'price': 291000,
#   'date': '20 Dec 2021',
# ...
#   'date': '30 Sep 2019',
#   'url': 'https://www.rightmove.co.uk/house-prices/details/england-71196934-10770781?s=1b1e9945ab44dd599ec451bf676ef963fea17004b512d86511064f46879ccc38',
#   'features': ['1 Bedroom Flat',
#    'Available Immediately with No Forward Chain',
#    'Double Glazing &amp; Central Heating',
#    'Walking Distance to Barking Town Centre &amp; Train Station',
#    'No Stamp Duty for First Time Buyers'],
#   'latitude': 51.532093,
#   'longitude': 0.078102,
#   'station_proximities': {'Barking Station': 0.5208020398524325,
#    'Upney Station': 1.095864073776182,
#    'East Ham Station': 1.248225918547322},
#   'property_size': {},
#   'bedrooms': 1,
#   'bathrooms': 1,
#   'new_build': False},
#  '542, Goresbrook Road, Dagenham, Greater London RM9 4XD': {'property_type': 'Terraced',
#   'price': 258000,
#   'date': '30 Sep 2019',
#   'url': 'https://www.rightmove.co.uk/house-prices/details/england-72338428-10868389?s=10dbddd61371b00e5bd31028c778528784d8967e0bc93c038a1c3ee83a188551',
#   'features': ['Two Double Bedrooms', 'Lounge', 'Kitchen', 'Family Bathroom'],
#   'floorplan_url': 'https://media.rightmove.co.uk/209k/208337/72338428/208337_TAR190045_FLP_02_0000.jpg',
#   'latitude': 51.534397,
#   'longitude': 0.117958,
#   'station_proximities': {'Becontree Station': 0.5577033395765895,
#    'Upney Station': 0.761004858532108,
#    'Dagenham Dock Station': 1.351672501339592},
#   'property_size': {},
#   'bedrooms': 2,
#   'bathrooms': 1,
#   'new_build': False},
#  '154, Gurney Close, Barking, Greater London IG11 8JZ': {'property_type': 'Terraced',
#   'price': 199750,
#   'date': '27 Sep 2019',
#   'url': 'https://www.rightmove.co.uk/house-prices/details/england-69124393-91207869?s=c12c29c66b2eedb4644db68e4182bf725a60239dab10628599b3267ad26c841e',
#   'features': ['TWO BEDROOM PURPOSE BUILT FLAT',
#    'WALKING DISTANCE TO BARKING TOWN CENTRE',
#    'IDEAL FIRST PURCHASE OR INVESTMENT',
#    'CLOSE TO MAJOR TRANSPORT LINKS',
#    ' GOOD DECORATIVE ORDER',
#    'PARKING ON SITE'],
#   'floorplan_url': 'https://media.rightmove.co.uk/66k/65633/69124393/65633_idlo_1269414022_FLP_01_0000.jpg',
#   'latitude': 51.543575,
#   'longitude': 0.069402,
#   'station_proximities': {'Barking Station': 0.6037127705587372,
#    'East Ham Station': 0.8197680035567114,
#    'Ilford Station': 1.0375731631243452},
#   'property_size': {},
#   'bedrooms': 2,
#   'bathrooms': 1,
#   'new_build': False},
#  'Flat 7, Pedley House, 6, Ripplegate Walk, Barking, Greater London IG11 0YB': {'property_type': 'Flat',
#   'price': 251995,
#   'date': '27 Sep 2019',
#   'url': ''},
#  '350, Uphall Road, Ilford, Greater London IG1 2JJ': {'property_type': 'Detached',
#   'price': 450000,
#   'date': '27 Sep 2019',
#   'url': 'https://www.rightmove.co.uk/house-prices/details/england-80487095-10770472?s=c86debbc8a5011de2dcc11da23f03fdb800b763a2f0deff821bba5f97c67e555',
#   'features': [],
#   'floorplan_url': 'https://media.rightmove.co.uk/63k/62254/80487095/62254_uphallrd_FLP_00_0000.jpg',
#   'latitude': 51.54386,
#   'longitude': 0.07288,
#   'station_proximities': {'Barking Station': 0.49103617090254575,
#    'East Ham Station': 0.9676219122995907,
#    'Ilford Station': 1.0281710598361196},
#   'property_size': {},
#   'bedrooms': 3,
#   'bathrooms': None,
#   'new_build': False},
#  '83, Sherwood Gardens, Barking, Greater London IG11 9TQ': {'property_type': 'Terraced',
#   'price': 487000,
#   'date': '27 Sep 2019',
#   'url': 'https://www.rightmove.co.uk/house-prices/details/england-73106677-10770862?s=6566179f615a844bb8f99d241afab9bb653d06de35252ad537d27246031625d8',
#   'features': ['THREE BEDROOMS',
#    'ATTACHED GARAGE',
#    'HUGE PLOT WITH POTENTIAL TO EXTEND',
#    'CLOSE TO BARKING TOWN CENTRE AND STATION',
#    'LARGE DRIVEWAY'],
#   'latitude': 51.53935,
#   'longitude': 0.08798,
#   'station_proximities': {'Barking Station': 0.27469876597011694,
#    'Upney Station': 0.5860444831004783,
#    'Ilford Station': 1.5498942467156243},
#   'property_size': {},
#   'bedrooms': 3,
#   'bathrooms': 1,
#   'new_build': False},
#  '14, Meadow Road, Barking, Greater London IG11 9QS': {'property_type': 'Terraced',
#   'price': 280000,
#   'date': '27 Sep 2019',
#   'url': 'https://www.rightmove.co.uk/house-prices/details/england-75374143-10770859?s=8526a03dd24edad2145e8ade870aa08b6dbcc5ef239cb527890dab763942840f',
#   'features': ['Newly decorated',
#    'Off street parking',
#    '2 Bed House',
#    'Big Garden',
#    'Great transport link',
#    "Min's Walk To Amenities &amp; Transport",
#    'Unfurnished',
#    'Call  '],
#   'latitude': 51.537045,
#   'longitude': 0.104331,
#   'station_proximities': {'Upney Station': 0.15163571678833207,
#    'Barking Station': 0.9920938271992802,
#    'Becontree Station': 0.9990353452016594},
#   'property_size': {},
#   'bedrooms': 2,
#   'bathrooms': None,
#   'new_build': False},
#  '234, Westrow Drive, Barking, Greater London IG11 9BT': {'property_type': 'Terraced',
#   'price': 440000,
#   'date': '27 Sep 2019',
#   'url': 'https://www.rightmove.co.uk/house-prices/details/england-76606505-10770829?s=07b8899411c05e8f65a6667ed6b83cc999e5372828a4dd69ea9e963129ba802a',
#   'features': ['Middle terrace',
#    'Three bedrooms',
#    'Two receptions',
#    'Off street parking',
#    'Gas central heating',
#    'Double glazing',
#    'Leftley Estate'],
#   'latitude': 51.547151,
#   'longitude': 0.106945,
#   'station_proximities': {'Upney Station': 0.6546852071000351,
#    'Becontree Station': 0.9870433728199166,
#    'Barking Station': 1.2198247134206042},
#   'property_size': {},
#   'bedrooms': 3,
#   'bathrooms': 1,
#   'new_build': False},
#  '186, Longbridge Road, Barking, Greater London IG11 8SU': {'property_type': 'Semi-Detached',
#   'price': 610000,
#   'date': '27 Sep 2019',
#   'url': 'https://www.rightmove.co.uk/house-prices/details/england-62564571-10770823?s=54533374853fda163a9976d14f6528afed8135a86d6080c6bb05857252f64b71',
#   'features': ['FOUR DOUBLE BEDROOMS',
#    'FOUR RECEPTION ROOMS',
#    'LARGE REAR GARDEN',
#    'DETACHED GARAGE',
#    'HIGHLY SOUGHT-AFTER PROMINENT LOCATION'],
#   'latitude': 51.54425,
#   'longitude': 0.0907,
#   'station_proximities': {'Barking Station': 0.5203614214287469,
#    'Upney Station': 0.6195100301927466,
#    'Ilford Station': 1.3477030646573296},
#   'property_size': {},
#   'bedrooms': 4,
#   'bathrooms': 1,
#   'new_build': False},
#  '72, Melford Avenue, Barking, Greater London IG11 9HT': {'property_type': 'Terraced',
#   'price': 443000,
#   'date': '26 Sep 2019',
#   'url': 'https://www.rightmove.co.uk/house-prices/details/england-71674321-10770838?s=0d37e56df9b63932b0a49953ad85e947f7931038df60a47f7afb056ed690faec',
#   'features': ['MID TERRACE',
#    'THREE BEDROOMS',
#    'TWO RECEPTION ROOMS',
#    'EXTENDED',
#    'STATION LOCATION',
#    'SCHOOLS AND SHOPS NEAR BY'],
#   'latitude': 51.54298,
#   'longitude': 0.09693,
#   'station_proximities': {'Upney Station': 0.3770322920733545,
#    'Barking Station': 0.7078950967930042,
#    'Becontree Station': 1.3081799815093473},
#   'property_size': {},
#   'bedrooms': 3,
#   'bathrooms': None,
#   'new_build': False},
#  '19, Ridley Close, Barking, Greater London IG11 9PJ': {'property_type': 'Flat',
#   'price': 267500,
#   'date': '26 Sep 2019',
#   'url': 'https://www.rightmove.co.uk/house-prices/details/england-72495412-10770847?s=0a25be9c3930b25e639a19b29c48e4f0bedd115ad73ecdd5ec5edf50945a4585',
#   'features': ['TWO DOUBLE BEDROOMS',
#    'EN-SUITE BATHROOM',
#    'WELL-PRESENTED THROUGHOUT',
#    'MODERN PURPOSE BUILT BLOCK',
#    'MOMENTS FROM UPNEY STATION'],
#   'latitude': 51.54,
#   'longitude': 0.09924,
#   'station_proximities': {'Upney Station': 0.15080300271610148,
#    'Barking Station': 0.7617467937894262,
#    'Becontree Station': 1.1944951054448056},
#   'property_size': {},
#   'bedrooms': 2,
#   'bathrooms': 2,
#   'new_build': False},
#  '32, Suffolk Road, Barking, Greater London IG11 7QW': {'property_type': 'Terraced',
#   'price': 285000,
#   'date': '23 Sep 2019',
#   'url': 'https://www.rightmove.co.uk/house-prices/details/england-85765066-10770796?s=9bfca89c5212785352cba49d16b37e10bb61bff8e3a5aaf494aafe86cdabe108',
#   'features': ['Four Bedroom House In Barking',
#    'Two Reception Rooms',
#    'Newly Refurbished Throughout',
#    'Three Bathrooms',
#    'New Flooring Throughout',
#    'Spacious Private Garden',
#    'Gas Central Heating',
#    'Double Glazing',
#    'Offered Unfurnished',
#    'Great Transport Links'],
#   'latitude': 51.536598,
#   'longitude': 0.089202,
#   'station_proximities': {'Barking Station': 0.3769425900276866,
#    'Upney Station': 0.5422576273786396,
#    'East Ham Station': 1.6319760208837115},
#   'property_size': {},
#   'bedrooms': 4,
#   'bathrooms': 3,
#   'new_build': False},
#  '9, Bridgeway, Barking, Greater London IG11 9QF': {'property_type': 'Terraced',
#   'price': 366500,
#   'date': '20 Sep 2019',
#   'url': 'https://www.rightmove.co.uk/house-prices/details/england-61847403-10494718?s=4667a61751f4fbcc789dc792fbd91830cfd85ce95a2b62c0ecd0ee5479a247d5',
#   'features': ['3 Bedroom House',
#    'Double Fronted &amp; Semi-detached',
#    'Large Rear Garden with Side Access',
#    '2 Double Bedrooms',
#    '2 Separate Receptions',
#    'Near Upney Underground Station',
#    'Close to Schools &amp; Hospital',
#    'Good Access to A13'],
#   'latitude': 51.53733,
#   'longitude': 0.10128,
#   'station_proximities': {'Upney Station': 0.0689447183960953,
#    'Barking Station': 0.859066152550396,
#    'Becontree Station': 1.1241392884044925},
#   'property_size': {},
#   'bedrooms': 3,
#   'bathrooms': 1,
#   'new_build': False},
#  '2, Kemmel Road, Dagenham, Greater London RM9 4BT': {'property_type': 'Terraced',
#   'price': 375000,
#   'date': '20 Sep 2019',
#   'url': ''},
#  '292, Gurney Close, Barking, Greater London IG11 8LD': {'property_type': 'Flat',
#   'price': 205000,
#   'date': '20 Sep 2019',
#   'url': 'https://www.rightmove.co.uk/house-prices/details/england-44511243-10770811?s=5bc55548cc634a2c9d055dffb56faa7ddb655c2cb99856b349a63efcf7eee9e0',
#   'features': ['One Double Bedroom Furnished Apartment',
#    'Electric Heating',
#    'Recently Refurbished Throughout',
#    'Modern Kitchen With New Appliances',
#    'Newly Installed Bathroom',
#    'Double Glazed Throughout',
#    'New &amp; Good Quality Furnishings',
#    'Located On The 1st Floor',
#    'Close To Barking Town Centre &amp; Transport',
#    'Available 15th May 2017'],
#   'latitude': 51.54261,
#   'longitude': 0.07268,
#   'station_proximities': {'Barking Station': 0.4479399175970257,
#    'East Ham Station': 0.9351459019747558,
#    'Ilford Station': 1.112713956894847},
#   'property_size': {},
#   'bedrooms': 1,
#   'bathrooms': 1,
#   'new_build': False},
#  '5, Moore Crescent, Dagenham, Greater London RM9 4XP': {'property_type': 'Flat',
#   'price': 180000,
#   'date': '20 Sep 2019',
#   'url': 'https://www.rightmove.co.uk/house-prices/details/england-79422858-10868392?s=59c7639185e42b363d8f065930dda772dc4e881a7f5c2da78b1546f65513c9bb',
#   'features': ['One Bedroom First Floor Apartment',
#    'Balcony Onto Communal Gardens',
#    'Over 100+ Year Lease',
#    'Modern  Three Piece Bathroom',
#    'Spacious Rooms Throughout',
#    'Well Maintained Throughout',
#    'Close To Upney Station'],
#   'floorplan_url': 'https://media.rightmove.co.uk/152k/151079/79422858/151079_1160837-1_FLP_00_0000.jpeg',
#   'latitude': 51.533542,
#   'longitude': 0.111543,
#   'station_proximities': {'Upney Station': 0.5457521487141589,
#    'Becontree Station': 0.8079591667108028,
#    'Barking Station': 1.3508158549032827},
#   'property_size': {},
#   'bedrooms': 1,
#   'bathrooms': 1,
#   'new_build': False},
#  '29, Glenmore Way, Barking, Greater London IG11 0LY': {'property_type': 'Terraced',
#   'price': 250000,
#   'date': '17 Sep 2019',
#   'url': 'https://www.rightmove.co.uk/house-prices/details/england-72373024-10770709?s=37ccac4b2b90cc8caf311a86bc62587e5d2c1b938df52f081531827c348682f6',
#   'features': ['NO ONWARD CHAIN',
#    'QUIET LOCATION',
#    'POTENTIAL TO EXTEND SUBJECT TO PLANNING',
#    'CLOSE TO LOCAL AMENITIES',
#    'FIRST FLOOR BATHROOM',
#    'CENTRAL HEATING'],
#   'floorplan_url': 'https://media.rightmove.co.uk/66k/65633/72373024/65633_idlo_656890129_FLP_01_0000.jpg',
#   'latitude': 51.526978,
#   'longitude': 0.108125,
#   'station_proximities': {'Upney Station': 0.8351383765059848,
#    'Becontree Station': 1.2224069833896813,
#    'Barking Station': 1.4260230315412308},
#   'property_size': {},
#   'bedrooms': 2,
#   'bathrooms': 1,
#   'new_build': False},
#  '103b, Park Avenue, Barking, Greater London IG11 8QX': {'property_type': 'Flat',
#   'price': 260000,
#   'date': '13 Sep 2019',
#   'url': ''},
#  '312, Westrow Drive, Barking, Greater London IG11 9BX': {'property_type': 'Terraced',
#   'price': 246945,
#   'date': '13 Sep 2019',
#   'url': 'https://www.rightmove.co.uk/house-prices/details/england-32900360-10770832?s=e34982253599574819543841d3802e893754c9bee95cd10d2db72184d2bc6114',
#   'features': [],
#   'latitude': 51.54939,
#   'longitude': 0.10559,
#   'station_proximities': {'Upney Station': 0.7858068231640234,
#    'Seven Kings Station': 1.045082352725093,
#    'Becontree Station': 1.1185519130008},
#   'property_size': {},
#   'bedrooms': 3,
#   'bathrooms': None,
#   'new_build': False},
#  '143, Oxlow Lane, Dagenham, Greater London RM10 7ST': {'property_type': 'Terraced',
#   'price': 380000,
#   'date': '7 Apr 2022',
#   'url': 'https://www.rightmove.co.uk/house-prices/details/england-8009013-93086133?s=00933840a159947c7b85e927cd6a7337d1a9c1e2ae74734652af423fe74d897e',
#   'features': ['Three Bedrooms',
#    'Lounge',
#    'Ground Floor Bathroom',
#    'Central Heating',
#    "Approx. 75' Rear Garden",
#    'Semi-Detached',
#    'Fitted Kitchen',
#    'Double Glazed (where specified)',
#    'Off Street Parking',
#    'No Onward Chain'],
#   'latitude': 51.55104,
#   'longitude': 0.14865,
#   'station_proximities': {'Dagenham Heathway Station': 0.6528545228108056,
#    'Dagenham East Station': 0.8815098250851147,
#    'Becontree Station': 1.1991523163302213},
#   'property_size': {},
#   'bedrooms': 3,
#   'bathrooms': None,
#   'new_build': False},
#  '463, Rainham Road South, Dagenham, Greater London RM10 7XP': {'property_type': 'Semi-Detached',
#   'price': 401000,
#   'date': '29 Mar 2022',
#   'url': ''},
#  '93, Gay Gardens, Dagenham, Greater London RM10 7TD': {'property_type': 'Terraced',
#   'price': 450000,
#   'date': '24 Mar 2022',
#   'url': 'https://www.rightmove.co.uk/house-prices/details/england-113436419-93086136?s=5655f61eb17274b446951797a235aa1936033678dae594ddb424c82670b6659a',
#   'features': ['Family Home',
#    'Open Plan Living',
#    'Lounge/Dining Room',
#    'Modern Kitchen/Breakfast Room',
#    'Modern Shower Room',
#    'Double Glazing',
#    'Gas Central Heating',
#    'No Chain',
#    'Contemporary Decor',
#    'Garage &amp; Off Road Parking'],
#   'floorplan_url': 'https://media.rightmove.co.uk/239k/238277/113436419/238277_S42062_FLP_00_0000.jpeg',
#   'latitude': 51.548382,
#   'longitude': 0.164504,
#   'station_proximities': {'Dagenham East Station': 0.303119806685548,
#    'Dagenham Heathway Station': 0.8648226934681791,
#    'Elm Park Station': 1.4369442025329007},
#   'property_size': {},
#   'bedrooms': 3,
#   'bathrooms': 1,
#   'new_build': False},
#  '53, Crescent Road, Dagenham, Greater London RM10 7HS': {'property_type': 'Terraced',
#   'price': 270000,
#   'date': '21 Mar 2022',
#   'url': ''},
#  '24, Greenwood Avenue, Dagenham, Greater London RM10 7DL': {'property_type': 'Semi-Detached',
#   'price': 425000,
#   'date': '11 Mar 2022',
#   'url': 'https://www.rightmove.co.uk/house-prices/details/england-113231633-15073171?s=68ed69c9e6bae0169abddb3e0a6d145f25d1a85c9388622b6c47987aad92725a',
#   'features': ['Three Good Sized Bedrooms',
#    "1930's Semi Detached Family Home",
#    'Kitchen/Diner',
#    'Lounge',
#    'Garden Room',
#    'Gas Central Heating',
#    'Attractive Rear Garden Measuring Approx 100ft ',
#    'Offers and Abundance of Potential',
#    'Within Easy Reach to Local Schools, Shops and Amenities',
#    'Close to Dagenham East Tube Station and Transport Links'],
#   'floorplan_url': 'https://media.rightmove.co.uk/238k/237173/113231633/237173_102741013544_FLP_00_0000.png',
#   'latitude': 51.55295,
#   'longitude': 0.1623,
#   'station_proximities': {'Dagenham East Station': 0.6319928722733894,
#    'Dagenham Heathway Station': 1.006875299832901,
#    'Elm Park Station': 1.5457068712199835},
#   'property_size': {},
#   'bedrooms': 3,
#   'bathrooms': 1,
#   'new_build': False},
#  ...}

# %%
# Change the format of the date

# %%
# OCR
# Import the necessary libraries
# import all of the necessary libraries
import easyocr
import cv2

# %%
image1 = "https://media.rightmove.co.uk/72k/71134/111198221/71134_30837396_FLP_00_0002.jpeg"
reader = easyocr.Reader(['en'], gpu=False)
result = reader.readtext(image1)
result
# Out:
# Using CPU. Note: This module is much faster with a GPU.
# Progress: |█████████████████████████████████████████████████████| 107.2% Complete
# [([[4, 70], [262, 70], [262, 124], [4, 124]],
#   '13th Floor',
#   0.9569405236450418),
#  ([[469, 97], [489, 97], [489, 119], [469, 119]], 'w', 0.5976982000865974),
#  ([[284, 320], [372, 320], [372, 344], [284, 344]],
#   '"Bedroom',
#   0.7574518358776843),
#  ([[279, 341], [383, 341], [383, 359], [279, 359]],
#   '0.0Om * 4.78m1',
#   0.4299373247246344),
#  ([[325, 353], [367, 353], [367, 373], [325, 373]],
#   '15*8")',
#   0.5845066549310215),
#  ([[394, 504], [478, 504], [478, 528], [394, 528]],
#   'Bedroom',
#   0.9999056945221165),
#  ([[385, 523], [489, 523], [489, 543], [385, 543]],
#   '3.19m * 2.70m',
#   0.6102979585241233),
#  ([[389, 539], [483, 539], [483, 557], [389, 557]],
#   '(10\'6" x 8\'10")',
#   0.7197790498556401),
#  ([[392, 702], [478, 702], [478, 726], [392, 726]],
#   'Bedroom',
#   0.9898320707542342),
#  ([[383, 723], [487, 723], [487, 741], [383, 741]],
#   '3.18m * 2.70m',
#   0.613414440517468),
#  ([[391, 737], [483, 737], [483, 755], [391, 755]],
#   '(10\'5" x 8\'10")',
#   0.4137179057800107),
#  ([[355, 1085], [452, 1085], [452, 1113], [355, 1113]],
#   'Reception',
#   0.9999781845810336),
#  ([[378, 1106], [434, 1106], [434, 1130], [378, 1130]],
#   'Room',
#   0.9983822703361511),
#  ([[353, 1127], [457, 1127], [457, 1143], [353, 1143]],
#   '7.98m X 3.77m',
#   0.7561979611072809),
#  ([[357, 1139], [453, 1139], [453, 1159], [357, 1159]],
#   '(262" x 124")',
#   0.3787256426467716),
#  ([[197, 1201], [251, 1201], [251, 1217], [197, 1217]],
#   'Kitchen',
#   0.9999309270383838),
#  ([[193, 1215], [257, 1215], [257, 1229], [193, 1229]],
#   '93m X 2.Jem',
#   0.3849487271053876),
#  ([[191, 1227], [253, 1227], [253, 1239], [191, 1239]],
#   '(190x7271',
#   0.11356274390281199),
#  ([[384, 1334], [463, 1334], [463, 1362], [384, 1362]],
#   'Balcony',
#   0.7593797814676481),
#  ([[411, 1357], [451, 1357], [451, 1377], [411, 1377]],
#   'Fire',
#   0.9999926090240479),
#  ([[397, 1373], [464, 1373], [464, 1401], [397, 1401]],
#   'Escape',
#   0.7790066704463618),
#  ([[130, 1450], [596, 1450], [596, 1473], [130, 1473]],
#   'Total area: approx. 101.1 sq. metres (1087.9 sq. feet)',
#   0.7546345074700543)]

# %%
image_1 = 'https://media.rightmove.co.uk/72k/71134/116482163/71134_31111584_FLP_00_0000.jpeg'
reader1 = easyocr.Reader(['en'], gpu=False)
result1 = reader.readtext(image_1)
result1
# Out:
# Using CPU. Note: This module is much faster with a GPU.
# Progress: |█████████████████████████████████████████████████████| 106.1% Complete
# [([[135, 0], [399, 0], [399, 43], [135, 43]],
#   'Second Floor',
#   0.9994564296643119),
#  ([[1026, 156], [1258, 156], [1258, 204], [1026, 204]],
#   'Third Floor',
#   0.9550033073947181),
#  ([[206, 176], [356, 176], [356, 231], [206, 231]],
#   'Balcony',
#   0.7510318448595686),
#  ([[1145, 460], [1312, 460], [1312, 509], [1145, 509]],
#   'Bedroom',
#   0.9999826981111722),
#  ([[1129, 501], [1333, 501], [1333, 539], [1129, 539]],
#   '3.77m x 2.58m',
#   0.6104654561744267),
#  ([[188, 518], [374, 518], [374, 568], [188, 568]],
#   'Reception',
#   0.9999980131775206),
#  ([[1147, 531], [1319, 531], [1319, 571], [1147, 571]],
#   '(12\'4" x 8\'6")',
#   0.8324985893054271),
#  ([[231, 559], [338, 559], [338, 602], [231, 602]],
#   'Room',
#   0.9999909996986389),
#  ([[182, 598], [384, 598], [384, 630], [182, 630]],
#   '4.93m X 4.04m',
#   0.6257794497852901),
#  ([[191, 627], [379, 627], [379, 663], [191, 663]],
#   '(162" x 133")',
#   0.4824622770668281),
#  ([[171, 969], [291, 969], [291, 1005], [171, 1005]],
#   'Kitchen',
#   0.8913363793598434),
#  ([[136, 1000], [320, 1000], [320, 1026], [136, 1026]],
#   '2.04m (6\'8") max',
#   0.980644071462289),
#  ([[148, 1024], [312, 1024], [312, 1054], [148, 1054]],
#   'x 4.04m (13\'3")',
#   0.9117043242375152),
#  ([[1153, 1029], [1317, 1029], [1317, 1071], [1153, 1071]],
#   'Bedroom',
#   0.7685779998369989),
#  ([[1134, 1072], [1336, 1072], [1336, 1104], [1134, 1104]],
#   '3.73m x 2.61m',
#   0.7791900561556904),
#  ([[1149, 1093], [1326, 1093], [1326, 1138], [1149, 1138]],
#   '(123" X 87")',
#   0.7578246888250539),
#  ([[254, 1386], [718, 1386], [718, 1436], [254, 1436]],
#   'Main area: Approx: 57.5 sq',
#   0.7307906954837988),
#  ([[729, 1384], [1128, 1384], [1128, 1436], [729, 1436]],
#   'metres (618.8 sq: feet)',
#   0.8737208568287944),
#  ([[428, 1428], [978, 1428], [978, 1458], [428, 1458]],
#   'Plus balconies, approx: 5.0 sq. metres (53.7 sq. feet)',
#   0.5711571218683534)]

# %%
scraped_text = ''
for i in result1:
    scraped_text += i[1]
    scraped_text += ","
    
text = scraped_text.split(",")
###text

# %%
scraped_text1 = ''
for i in result:
    scraped_text1 += i[1]
    scraped_text1 += ","
    
text1 = scraped_text1.split(",")
text1
# Out:
# ['13th Floor',
#  'w',
#  '"Bedroom',
#  '0.0Om * 4.78m1',
#  '15*8")',
#  'Bedroom',
#  '3.19m * 2.70m',
#  '(10\'6" x 8\'10")',
#  'Bedroom',
#  '3.18m * 2.70m',
#  '(10\'5" x 8\'10")',
#  'Reception',
#  'Room',
#  '7.98m X 3.77m',
#  '(262" x 124")',
#  'Kitchen',
#  '93m X 2.Jem',
#  '(190x7271',
#  'Balcony',
#  'Fire',
#  'Escape',
#  'Total area: approx. 101.1 sq. metres (1087.9 sq. feet)',
#  '']

# %%
m_pattern = re.compile(r"[+-]? *((?:\d+(?:\.\d*)?|\.\d+)(?:[eE][+-]?\d+)?)\s*(square meters|square metres|square meter|square metre|square m|square mt|sqmt|sq mt|sq.mt|sq. mt|sqm|sq m|sq.m|sq. m|meters2|metres2|meter2|metre2|mt2|m2)", re.IGNORECASE)
f_pattern = re.compile(r"[+-]? *((?:\d+(?:\.\d*)?|\.\d+)(?:[eE][+-]?\d+)?)\s*(square feet|square ft|square f|sqft|sq ft|sq.ft|sq. ft|sqf|sq f|sq.f|sq. f|feet2|ft2|f2)", re.IGNORECASE)
for x in text1:
    for match in re.finditer(m_pattern, x):
        print('%s : %s' % (match.groups()))
    for match in re.finditer(f_pattern, x):
        print('%s : %s' % (match.groups()))
# Out:
# 101.1 : sq. m
# 1087.9 : sq. f

# %%
def size_floorplan(floorplan):
    """Obtain the size data from the floorplan"""
    reader = easyocr.Reader(['en']) # GPU=false taken out for now
    result = reader.readtext(floorplan)
    
    scraped_text = ''
    for i in result:
        scraped_text += i[1]
        scraped_text += ","
    text_list = scraped_text.split(",")
    
    m_patterns = re.compile(r"[+-]? *((?:\d+(?:\.\d*)?|\.\d+)(?:[eE][+-]?\d+)?)\s*(square meters|square metres|square meter|square metre|square m|square mt|sqmt|sq mt|sq.mt|sq. mt|sqm|sq m|sq.m|sq. m|meters2|metres2|meter2|metre2|mt2|m2)", re.IGNORECASE)
    f_patterns = re.compile(r"[+-]? *((?:\d+(?:\.\d*)?|\.\d+)(?:[eE][+-]?\d+)?)\s*(square feet|square ft|square f|sqft|sq ft|sq.ft|sq. ft|sqf|sq f|sq.f|sq. f|feet2|ft2|f2)", re.IGNORECASE)
    house_size = []
    for x in text_list:
        for match in re.finditer(m_patterns, x):
            #print('%s : %s' % (match.groups()))
            house_size.append(list(match.groups()))
        for match in re.finditer(f_patterns, x):
            #print('%s : %s' % (match.groups())) 
            house_size.append(list(match.groups()))
    for a in house_size:
        try:
            a[0] = int(a[0])
        except ValueError:
            a[0] = float(a[0])
            
    # then here you could find the
    house_size = dict((house_size))
    return house_size

# %%
r = size_floorplan('https://media.rightmove.co.uk/77k/76792/48779142/76792_HAM547-t-3762_FLP_01_0000.jpg')
# Out:
# CUDA not available - defaulting to CPU. Note: This module is much faster with a GPU.
# Progress: |█████████████████████████████████████████████████████| 107.5% Complete

# %%
# Code to take the largest returned value from 
amount = 0
for size in r.keys():
    if size > amount:
        amount = size
largest_size = {}
largest_size[amount] = r[amount]
largest_size[amount] = largest_size[amount].lower()
print(largest_size)

metre_values = ["square meters", "square metres", "square meter", "square metre", "square m", "square mt", "sqmt", "sq mt",
                "sq.mt", "sq. mt", "sqm", "sq m", "sq.m", "sq. m", "meters2", "metres2", "meter2", "metre2", "mt2", "m2"]
feet_values = ["square feet","square ft","square f","sqft","sq ft","sq.ft","sq. ft","sqf","sq f","sq.f","sq. f","feet2",
               "ft2","f2"]


if largest_size[amount] in metre_values:
    largest_size[amount] = "sq m"
elif largest_size[amount] in feet_values:
    largest_size[amount] = "sq ft"
print(largest_size)
# Out:
# {1190: 'sq ft'}
# {1190: 'sq ft'}

# %%
import geopy.distance

# %%
outstanding_schools = [[51.4974948, -0.1356583],
                       [51.5202607, -0.0293396],
 [51.4935082, -0.1178424],
 [51.6569225, -0.1949252],
 [51.5202607, -0.0293396],
 [51.5345448, -0.2043853],
 [51.5202607, -0.0293396],
 [51.458373, -0.1891356],
 [51.4990156, -0.22915],
 [51.6569225, -0.1949252],
 [51.5906113, -0.1109709],
 [51.5202607, -0.0293396],
 [51.538621, -0.1028346],
 [51.5202607, -0.0293396],
 [51.5672808, -0.2710568],
 [51.6569225, -0.1949252],
 [51.5132537, -0.3043136],
 [51.5255162, 0.0352163],
 [51.5202607, -0.0293396],
 [51.4609218, -0.373149],
 [51.6569225, -0.1949252],
 [51.4990805, -0.1938253],
 [51.5255162, 0.0352163],
 [51.5255162, 0.0352163],
 [51.4935082, -0.1178424],
 [51.5436387, -0.0553621],
 [51.5202607, -0.0293396],
 [51.5436387, -0.0553621],
 [51.4935082, -0.1178424],
 [51.458373, -0.1891356],
 [51.4990156, -0.22915],
 [51.5886383, -0.0117625],
 [51.5390261, -0.1425516],
 [51.5132537, -0.3043136],
 [51.5906113, -0.1109709],
 [51.4990805, -0.1938253],
 [51.5886121, 0.0823982],
 [51.5436387, -0.0553621],
 [51.3769529, -0.0956895],
 [51.5886383, -0.0117625],
 [51.5132537, -0.3043136],
 [51.5906113, -0.1109709],
 [51.458373, -0.1891356],
 [51.5202607, -0.0293396],
 [51.4990805, -0.1938253],
 [51.5202607, -0.0293396],
 [51.5672808, -0.2710568],
 [51.5886383, -0.0117625],
 [51.4990156, -0.22915],
 [51.5132537, -0.3043136],
 [51.5202607, -0.0293396],
 [51.4609218, -0.373149],
 [51.4974948, -0.1356583],
 [51.5906113, -0.1109709],
 [51.4990805, -0.1938253],
 [51.4933675, 0.0098214],
 [51.5886121, 0.0823982],
 [51.5886121, 0.0823982],
 [51.502781, -0.087738],
 [51.4935082, -0.1178424],
 [51.5540666, 0.134017],
 [51.4935082, -0.1178424],
 [51.5886121, 0.0823982],
 [51.5886383, -0.0117625],
 [51.4611509, -0.0073177],
 [51.5390261, -0.1425516],
 [51.4609218, -0.373149],
 [51.5390261, -0.1425516],
 [51.4990805, -0.1938253],
 [51.5132537, -0.3043136],
 [51.4990805, -0.1938253],
 [51.4935082, -0.1178424],
 [51.5436387, -0.0553621],
 [51.5886121, 0.0823982],
 [51.5672808, -0.2710568],
 [51.5436387, -0.0553621],
 [51.5886121, 0.0823982],
 [51.5202607, -0.0293396],
 [51.5390261, -0.1425516],
 [51.502781, -0.087738],
 [51.4609218, -0.373149],
 [51.5436387, -0.0553621],
 [51.4974948, -0.1356583],
 [51.4609218, -0.373149],
 [51.538621, -0.1028346],
 [51.5123443, -0.0909852],
 [51.538621, -0.1028346],
 [51.5672808, -0.2710568],
 [51.5436387, -0.0553621],
 [51.5255162, 0.0352163],
 [51.5886383, -0.0117625],
 [51.538621, -0.1028346],
 [51.4935082, -0.1178424],
 [51.4990156, -0.22915],
 [51.538621, -0.1028346],
 [51.5906113, -0.1109709],
 [51.5906113, -0.1109709],
 [51.5906113, -0.1109709],
 [51.502781, -0.087738],
 [51.4935082, -0.1178424],
 [51.5202607, -0.0293396],
 [51.502781, -0.087738],
 [51.5202607, -0.0293396],
 [51.5540666, 0.134017],
 [51.4990156, -0.22915],
 [51.4609218, -0.373149],
 [51.4935082, -0.1178424],
 [51.5132537, -0.3043136],
 [51.6569225, -0.1949252],
 [51.4611509, -0.0073177],
 [51.4935082, -0.1178424],
 [51.538621, -0.1028346],
 [51.5202607, -0.0293396],
 [51.4933675, 0.0098214],
 [51.406025, 0.013156],
 [51.5886383, -0.0117625],
 [51.458373, -0.1891356],
 [51.5886383, -0.0117625],
 [51.502781, -0.087738],
 [51.4990805, -0.1938253],
 [51.4097742, -0.2108084],
 [51.4933675, 0.0098214],
 [51.6522994, -0.0807119],
 [51.5672808, -0.2710568],
 [51.502781, -0.087738],
 [51.4974948, -0.1356583],
 [51.580559, -0.341995],
 [51.5436387, -0.0553621],
 [51.4609218, -0.373149],
 [51.6569225, -0.1949252],
 [51.4611509, -0.0073177],
 [51.6522994, -0.0807119],
 [51.5132537, -0.3043136],
 [51.6522994, -0.0807119],
 [51.5132537, -0.3043136],
 [51.458373, -0.1891356],
 [51.4097742, -0.2108084],
 [51.6522994, -0.0807119],
 [51.5436387, -0.0553621],
 [51.4611509, -0.0073177],
 [51.502781, -0.087738],
 [51.6522994, -0.0807119],
 [51.4974948, -0.1356583],
 [51.458373, -0.1891356],
 [51.502781, -0.087738],
 [51.458373, -0.1891356],
 [51.5540666, 0.134017],
 [51.461311, -0.303742],
 [51.502781, -0.087738],
 [51.5672808, -0.2710568],
 [51.461311, -0.303742],
 [51.5906113, -0.1109709],
 [51.5886121, 0.0823982],
 [51.4990156, -0.22915],
 [51.458373, -0.1891356],
 [51.5886383, -0.0117625],
 [51.5886121, 0.0823982],
 [51.5672808, -0.2710568],
 [51.4609218, -0.373149],
 [51.4935082, -0.1178424],
 [51.577924, 0.2120829],
 [51.4990805, -0.1938253],
 [51.5886383, -0.0117625],
 [51.461311, -0.303742],
 [51.4935082, -0.1178424],
 [51.4990156, -0.22915],
 [51.5255162, 0.0352163],
 [51.502781, -0.087738],
 [51.5255162, 0.0352163],
 [51.5132537, -0.3043136],
 [51.5255162, 0.0352163],
 [51.4609218, -0.373149],
 [51.461311, -0.303742],
 [51.538621, -0.1028346],
 [51.3769529, -0.0956895],
 [51.6569225, -0.1949252],
 [51.580559, -0.341995],
 [51.5436387, -0.0553621],
 [51.5255162, 0.0352163],
 [51.4990805, -0.1938253],
 [51.439933, 0.154327],
 [51.4935082, -0.1178424],
 [51.5436387, -0.0553621],
 [51.3769529, -0.0956895],
 [51.3769529, -0.0956895],
 [51.5436387, -0.0553621],
 [51.439933, 0.154327],
 [51.6569225, -0.1949252],
 [51.4609218, -0.373149],
 [51.461311, -0.303742],
 [51.406025, 0.013156],
 [51.5351832, -0.4481378],
 [51.406025, 0.013156],
 [51.4097742, -0.2108084],
 [51.6522994, -0.0807119],
 [51.3769529, -0.0956895],
 [51.4609218, -0.373149],
 [51.538621, -0.1028346],
 [51.5886121, 0.0823982],
 [51.41233, -0.300689],
 [51.5436387, -0.0553621],
 [51.406025, 0.013156],
 [51.3769529, -0.0956895],
 [51.502781, -0.087738],
 [51.580559, -0.341995],
 [51.439933, 0.154327],
 [51.5906113, -0.1109709],
 [51.5351832, -0.4481378],
 [51.5255162, 0.0352163],
 [51.4974948, -0.1356583],
 [51.4097742, -0.2108084],
 [51.5436387, -0.0553621],
 [51.5202607, -0.0293396],
 [51.5390261, -0.1425516],
 [51.6569225, -0.1949252],
 [51.406025, 0.013156],
 [51.4990156, -0.22915],
 [51.3769529, -0.0956895],
 [51.4097742, -0.2108084],
 [51.4935082, -0.1178424],
 [51.5540666, 0.134017],
 [51.4974948, -0.1356583],
 [51.4933675, 0.0098214],
 [51.5540666, 0.134017],
 [51.3769529, -0.0956895],
 [51.5351832, -0.4481378],
 [51.4990156, -0.22915],
 [51.4935082, -0.1178424],
 [51.4611509, -0.0073177],
 [51.4611509, -0.0073177],
 [51.5886121, 0.0823982],
 [51.5906113, -0.1109709],
 [51.6522994, -0.0807119],
 [51.6522994, -0.0807119],
 [51.3769529, -0.0956895],
 [51.458373, -0.1891356],
 [51.4933675, 0.0098214],
 [51.406025, 0.013156],
 [51.4990156, -0.22915],
 [51.4097742, -0.2108084],
 [51.4935082, -0.1178424],
 [51.4611509, -0.0073177],
 [51.502781, -0.087738],
 [51.577924, 0.2120829],
 [51.406025, 0.013156],
 [51.5906113, -0.1109709],
 [51.461311, -0.303742],
 [51.406025, 0.013156],
 [51.439933, 0.154327],
 [51.3769529, -0.0956895],
 [51.461311, -0.303742],
 [51.5132537, -0.3043136],
 [51.4611509, -0.0073177],
 [51.5436387, -0.0553621],
 [51.3769529, -0.0956895],
 [51.461311, -0.303742],
 [51.5202607, -0.0293396],
 [51.4935082, -0.1178424],
 [51.4611509, -0.0073177],
 [51.4990805, -0.1938253],
 [51.6522994, -0.0807119],
 [51.5886121, 0.0823982],
 [51.439933, 0.154327],
 [51.4935082, -0.1178424],
 [51.5906113, -0.1109709],
 [51.41233, -0.300689],
 [51.5906113, -0.1109709],
 [51.4611509, -0.0073177],
 [51.4611509, -0.0073177],
 [51.439933, 0.154327],
 [51.406025, 0.013156],
 [51.4609218, -0.373149],
 [51.4611509, -0.0073177],
 [51.5906113, -0.1109709],
 [51.580559, -0.341995],
 [51.3769529, -0.0956895],
 [51.3769529, -0.0956895],
 [51.4097742, -0.2108084],
 [51.5886121, 0.0823982],
 [51.461311, -0.303742],
 [51.4935082, -0.1178424],
 [51.5132537, -0.3043136],
 [51.6569225, -0.1949252],
 [51.4097742, -0.2108084],
 [51.5906113, -0.1109709],
 [51.6569225, -0.1949252],
 [51.5886383, -0.0117625],
 [51.461311, -0.303742],
 [51.406025, 0.013156],
 [51.461311, -0.303742],
 [51.4609218, -0.373149],
 [51.577924, 0.2120829],
 [51.5351832, -0.4481378],
 [51.439933, 0.154327],
 [51.406025, 0.013156],
 [51.5351832, -0.4481378],
 [51.406025, 0.013156],
 [51.5906113, -0.1109709],
 [51.5886121, 0.0823982],
 [51.5672808, -0.2710568],
 [51.439933, 0.154327],
 [51.5436387, -0.0553621],
 [51.3769529, -0.0956895],
 [51.439933, 0.154327],
 [51.406025, 0.013156],
 [51.5886121, 0.0823982],
 [51.439933, 0.154327],
 [51.5351832, -0.4481378],
 [51.4609218, -0.373149],
 [51.5540666, 0.134017],
 [51.6569225, -0.1949252],
 [51.3769529, -0.0956895],
 [51.439933, 0.154327],
 [51.6569225, -0.1949252],
 [51.4609218, -0.373149],
 [51.4990805, -0.1938253],
 [51.3769529, -0.0956895],
 [51.580559, -0.341995],
 [51.4974948, -0.1356583],
 [51.3769529, -0.0956895],
 [51.4990156, -0.22915],
 [51.5351832, -0.4481378],
 [51.5202607, -0.0293396],
 [51.458373, -0.1891356],
 [51.461311, -0.303742],
 [51.5906113, -0.1109709],
 [51.5886121, 0.0823982],
 [51.4990156, -0.22915],
 [51.5132537, -0.3043136],
 [51.4609218, -0.373149],
 [51.5436387, -0.0553621],
 [51.5390261, -0.1425516],
 [51.5436387, -0.0553621],
 [51.406025, 0.013156],
 [51.502781, -0.087738],
 [51.458373, -0.1891356],
 [51.406025, 0.013156],
 [51.461311, -0.303742],
 [51.461311, -0.303742],
 [51.5436387, -0.0553621],
 [51.5351832, -0.4481378],
 [51.5351832, -0.4481378],
 [51.406025, 0.013156],
 [51.4611509, -0.0073177],
 [51.577924, 0.2120829],
 [51.3769529, -0.0956895],
 [51.4974948, -0.1356583],
 [51.5390261, -0.1425516],
 [51.458373, -0.1891356],
 [51.4974948, -0.1356583],
 [51.458373, -0.1891356],
 [51.5255162, 0.0352163],
 [51.4974948, -0.1356583],
 [51.6522994, -0.0807119],
 [51.4990156, -0.22915],
 [51.4990805, -0.1938253],
 [51.5390261, -0.1425516],
 [51.4990805, -0.1938253],
 [51.5202607, -0.0293396],
 [51.5886383, -0.0117625],
 [51.3769529, -0.0956895],
 [51.461311, -0.303742],
 [51.5202607, -0.0293396],
 [51.5540666, 0.134017],
 [51.406025, 0.013156],
 [51.461311, -0.303742],
 [51.4097742, -0.2108084],
 [51.5390261, -0.1425516],
 [51.4990156, -0.22915],
 [51.458373, -0.1891356],
 [51.5123443, -0.0909852],
 [51.461311, -0.303742],
 [51.458373, -0.1891356],
 [51.4097742, -0.2108084],
 [51.538621, -0.1028346],
 [51.5886121, 0.0823982],
 [51.4974948, -0.1356583],
 [51.458373, -0.1891356],
 [51.6569225, -0.1949252],
 [51.5132537, -0.3043136],
 [51.5436387, -0.0553621],
 [51.6569225, -0.1949252],
 [51.4935082, -0.1178424],
 [51.580559, -0.341995],
 [51.4935082, -0.1178424],
 [51.538621, -0.1028346],
 [51.6522994, -0.0807119],
 [51.5672808, -0.2710568],
 [51.5255162, 0.0352163],
 [51.4990805, -0.1938253],
 [51.4974948, -0.1356583],
 [51.4990156, -0.22915],
 [51.5672808, -0.2710568],
 [51.6522994, -0.0807119],
 [51.538621, -0.1028346],
 [51.5906113, -0.1109709],
 [51.6522994, -0.0807119],
 [51.4974948, -0.1356583],
 [51.5132537, -0.3043136],
 [51.5202607, -0.0293396],
 [51.5132537, -0.3043136],
 [51.5390261, -0.1425516],
 [51.4990805, -0.1938253],
 [51.5351832, -0.4481378],
 [51.5390261, -0.1425516],
 [51.580559, -0.341995],
 [51.458373, -0.1891356],
 [51.538621, -0.1028346],
 [51.4935082, -0.1178424],
 [51.580559, -0.341995],
 [51.5351832, -0.4481378],
 [51.502781, -0.087738],
 [51.4990156, -0.22915],
 [51.5886121, 0.0823982],
 [51.6569225, -0.1949252],
 [51.4990805, -0.1938253],
 [51.458373, -0.1891356],
 [51.4990156, -0.22915],
 [51.5132537, -0.3043136],
 [51.3769529, -0.0956895],
 [51.458373, -0.1891356],
 [51.5351832, -0.4481378],
 [51.4990805, -0.1938253],
 [51.502781, -0.087738],
 [51.458373, -0.1891356],
 [51.6522994, -0.0807119],
 [51.6569225, -0.1949252],
 [51.5672808, -0.2710568],
 [51.538621, -0.1028346],
 [51.5202607, -0.0293396],
 [51.4990805, -0.1938253],
 [51.6522994, -0.0807119],
 [51.4974948, -0.1356583],
 [51.4611509, -0.0073177],
 [51.580559, -0.341995],
 [51.577924, 0.2120829],
 [51.3769529, -0.0956895],
 [51.6569225, -0.1949252],
 [51.458373, -0.1891356],
 [51.502781, -0.087738],
 [51.41233, -0.300689],
 [51.5540666, 0.134017],
 [51.4609218, -0.373149],
 [51.538621, -0.1028346],
 [51.5351832, -0.4481378],
 [51.6522994, -0.0807119],
 [51.5390261, -0.1425516],
 [51.5132537, -0.3043136],
 [51.502781, -0.087738],
 [51.5132537, -0.3043136],
 [51.5351832, -0.4481378],
 [51.5202607, -0.0293396],
 [51.4990805, -0.1938253],
 [51.5672808, -0.2710568],
 [51.3769529, -0.0956895],
 [51.4990805, -0.1938253],
 [51.4990156, -0.22915],
 [51.4974948, -0.1356583],
 [51.5886121, 0.0823982],
 [51.461311, -0.303742],
 [51.5351832, -0.4481378],
 [51.5390261, -0.1425516],
 [51.5255162, 0.0352163],
 [51.538621, -0.1028346],
 [51.4097742, -0.2108084],
 [51.5886121, 0.0823982],
 [51.3769529, -0.0956895],
 [51.5390261, -0.1425516],
 [51.577924, 0.2120829],
 [51.5886383, -0.0117625],
 [51.406025, 0.013156],
 [51.4990805, -0.1938253],
 [51.3769529, -0.0956895],
 [51.6522994, -0.0807119],
 [51.4935082, -0.1178424],
 [51.461311, -0.303742],
 [51.580559, -0.341995],
 [51.3769529, -0.0956895],
 [51.580559, -0.341995],
 [51.406025, 0.013156],
 [51.6522994, -0.0807119],
 [51.4990156, -0.22915],
 [51.4611509, -0.0073177],
 [51.4933675, 0.0098214],
 [51.4974948, -0.1356583],
 [51.6522994, -0.0807119],
 [51.458373, -0.1891356],
 [51.4990156, -0.22915],
 [51.5886383, -0.0117625],
 [51.439933, 0.154327],
 [51.406025, 0.013156],
 [51.4609218, -0.373149],
 [51.406025, 0.013156],
 [51.458373, -0.1891356],
 [51.4609218, -0.373149],
 [51.5672808, -0.2710568],
 [51.5672808, -0.2710568],
 [51.4990805, -0.1938253],
 [51.5202607, -0.0293396],
 [51.5202607, -0.0293396],
 [51.580559, -0.341995],
 [51.5436387, -0.0553621],
 [51.538621, -0.1028346],
 [51.458373, -0.1891356],
 [51.458373, -0.1891356],
 [51.580559, -0.341995],
 [51.5390261, -0.1425516],
 [51.3769529, -0.0956895],
 [51.4609218, -0.373149],
 [51.458373, -0.1891356],
 [51.577924, 0.2120829],
 [51.5906113, -0.1109709],
 [51.406025, 0.013156],
 [51.4611509, -0.0073177],
 [51.4609218, -0.373149],
 [51.458373, -0.1891356],
 [51.458373, -0.1891356],
 [51.461311, -0.303742],
 [51.5886383, -0.0117625],
 [51.5390261, -0.1425516],
 [51.458373, -0.1891356],
 [51.580559, -0.341995],
 [51.5255162, 0.0352163],
 [51.5906113, -0.1109709],
 [51.4990156, -0.22915],
 [51.4990805, -0.1938253],
 [51.5436387, -0.0553621],
 [51.4609218, -0.373149],
 [51.4611509, -0.0073177],
 [51.3769529, -0.0956895],
 [51.4933675, 0.0098214],
 [51.577924, 0.2120829],
 [51.6522994, -0.0807119],
 [51.458373, -0.1891356],
 [51.4933675, 0.0098214],
 [51.4611509, -0.0073177],
 [51.4933675, 0.0098214],
 [51.4609218, -0.373149],
 [51.406025, 0.013156],
 [51.4935082, -0.1178424],
 [51.5436387, -0.0553621],
 [51.6522994, -0.0807119],
 [51.4933675, 0.0098214],
 [51.4974948, -0.1356583],
 [51.5906113, -0.1109709],
 [51.5351832, -0.4481378],
 [51.5436387, -0.0553621],
 [51.4990805, -0.1938253],
 [51.6569225, -0.1949252],
 [51.461311, -0.303742],
 [51.6569225, -0.1949252],
 [51.5436387, -0.0553621],
 [51.4609218, -0.373149],
 [51.4990805, -0.1938253],
 [51.5886121, 0.0823982],
 [51.5351832, -0.4481378],
 [51.6522994, -0.0807119],
 [51.5255162, 0.0352163],
 [51.461311, -0.303742],
 [51.4974948, -0.1356583],
 [51.502781, -0.087738],
 [51.5436387, -0.0553621],
 [51.5906113, -0.1109709],
 [51.580559, -0.341995],
 [51.5202607, -0.0293396],
 [51.5886121, 0.0823982],
 [51.439933, 0.154327],
 [51.5436387, -0.0553621],
 [51.458373, -0.1891356],
 [51.5255162, 0.0352163],
 [51.6569225, -0.1949252],
 [51.4933675, 0.0098214],
 [51.580559, -0.341995],
 [51.4974948, -0.1356583],
 [51.406025, 0.013156],
 [51.4611509, -0.0073177],
 [51.4974948, -0.1356583],
 [51.502781, -0.087738],
 [51.5132537, -0.3043136],
 [51.5132537, -0.3043136],
 [51.5436387, -0.0553621],
 [51.580559, -0.341995],
 [51.439933, 0.154327],
 [51.4611509, -0.0073177],
 [51.4933675, 0.0098214],
 [51.458373, -0.1891356],
 [51.4097742, -0.2108084],
 [51.5351832, -0.4481378],
 [51.406025, 0.013156],
 [51.580559, -0.341995],
 [51.4935082, -0.1178424],
 [51.461311, -0.303742],
 [51.439933, 0.154327],
 [51.3769529, -0.0956895],
 [51.4935082, -0.1178424],
 [51.458373, -0.1891356],
 [51.439933, 0.154327],
 [51.580559, -0.341995],
 [51.4933675, 0.0098214],
 [51.461311, -0.303742],
 [51.3769529, -0.0956895],
 [51.577924, 0.2120829],
 [51.5436387, -0.0553621],
 [51.406025, 0.013156],
 [51.5132537, -0.3043136],
 [51.4974948, -0.1356583],
 [51.5886383, -0.0117625],
 [51.4990156, -0.22915],
 [51.406025, 0.013156],
 [51.3769529, -0.0956895],
 [51.4609218, -0.373149],
 [51.3769529, -0.0956895],
 [51.538621, -0.1028346],
 [51.5436387, -0.0553621],
 [51.538621, -0.1028346],
 [51.439933, 0.154327],
 [51.458373, -0.1891356],
 [51.3769529, -0.0956895],
 [51.5672808, -0.2710568],
 [51.4935082, -0.1178424],
 [51.41233, -0.300689],
 [51.577924, 0.2120829],
 [51.6569225, -0.1949252],
 [51.5202607, -0.0293396],
 [51.6569225, -0.1949252],
 [51.41233, -0.300689],
 [51.3769529, -0.0956895],
 [51.458373, -0.1891356],
 [51.5132537, -0.3043136],
 [51.5436387, -0.0553621],
 [51.5906113, -0.1109709],
 [51.4990805, -0.1938253],
 [51.4609218, -0.373149],
 [51.5886121, 0.0823982],
 [51.458373, -0.1891356],
 [51.5132537, -0.3043136],
 [51.458373, -0.1891356],
 [51.4611509, -0.0073177],
 [51.461311, -0.303742],
 [51.4933675, 0.0098214],
 [51.4097742, -0.2108084],
 [51.5436387, -0.0553621],
 [51.577924, 0.2120829],
 [51.4990156, -0.22915],
 [51.406025, 0.013156],
 [51.580559, -0.341995],
 [51.406025, 0.013156],
 [51.4990156, -0.22915],
 [51.4990156, -0.22915],
 [51.458373, -0.1891356],
 [51.5123443, -0.0909852],
 [51.4990156, -0.22915],
 [51.5906113, -0.1109709],
 [51.3769529, -0.0956895],
 [51.580559, -0.341995],
 [51.461311, -0.303742],
 [51.406025, 0.013156],
 [51.3769529, -0.0956895],
 [51.4097742, -0.2108084],
 [51.3769529, -0.0956895],
 [51.406025, 0.013156],
 [51.461311, -0.303742],
 [51.5886121, 0.0823982],
 [51.4609218, -0.373149],
 [51.3769529, -0.0956895],
 [51.538621, -0.1028346],
 [51.6569225, -0.1949252],
 [51.5351832, -0.4481378],
 [51.6569225, -0.1949252],
 [51.4933675, 0.0098214],
 [51.458373, -0.1891356],
 [51.4935082, -0.1178424],
 [51.4974948, -0.1356583],
 [51.4609218, -0.373149],
 [51.6569225, -0.1949252],
 [51.406025, 0.013156],
 [51.458373, -0.1891356],
 [51.4609218, -0.373149],
 [51.458373, -0.1891356],
 [51.461311, -0.303742],
 [51.461311, -0.303742],
 [51.5351832, -0.4481378],
 [51.5540666, 0.134017],
 [51.439933, 0.154327],
 [51.406025, 0.013156],
 [51.4611509, -0.0073177],
 [51.458373, -0.1891356],
 [51.5672808, -0.2710568],
 [51.458373, -0.1891356],
 [51.4974948, -0.1356583],
 [51.4974948, -0.1356583],
 [51.5906113, -0.1109709],
 [51.5906113, -0.1109709],
 [51.5540666, 0.134017],
 [51.5390261, -0.1425516],
 [51.4990805, -0.1938253],
 [51.5390261, -0.1425516],
 [51.4609218, -0.373149],
 [51.4990156, -0.22915],
 [51.6522994, -0.0807119],
 [51.5672808, -0.2710568],
 [51.5436387, -0.0553621],
 [51.502781, -0.087738],
 [51.461311, -0.303742],
 [51.5436387, -0.0553621],
 [51.5351832, -0.4481378],
 [51.5886121, 0.0823982],
 [51.580559, -0.341995],
 [51.4097742, -0.2108084],
 [51.5886383, -0.0117625],
 [51.4611509, -0.0073177],
 [51.577924, 0.2120829],
 [51.5132537, -0.3043136],
 [51.5390261, -0.1425516],
 [51.5132537, -0.3043136],
 [51.502781, -0.087738],
 [51.538621, -0.1028346],
 [51.4097742, -0.2108084],
 [51.5132537, -0.3043136],
 [51.461311, -0.303742],
 [51.5886383, -0.0117625],
 [51.6569225, -0.1949252],
 [51.41233, -0.300689],
 [51.577924, 0.2120829],
 [51.3769529, -0.0956895],
 [51.461311, -0.303742],
 [51.458373, -0.1891356],
 [51.5202607, -0.0293396],
 [51.502781, -0.087738],
 [51.577924, 0.2120829],
 [51.5906113, -0.1109709],
 [51.4609218, -0.373149],
 [51.4609218, -0.373149],
 [51.5540666, 0.134017],
 [51.577924, 0.2120829],
 [51.5132537, -0.3043136],
 [51.5436387, -0.0553621],
 [51.4933675, 0.0098214],
 [51.5886383, -0.0117625],
 [51.406025, 0.013156],
 [51.439933, 0.154327],
 [51.3769529, -0.0956895],
 [51.5202607, -0.0293396],
 [51.461311, -0.303742],
 [51.4974948, -0.1356583],
 [51.461311, -0.303742],
 [51.5886383, -0.0117625],
 [51.458373, -0.1891356],
 [51.577924, 0.2120829],
 [51.458373, -0.1891356],
 [51.5886121, 0.0823982],
 [51.4097742, -0.2108084],
 [51.458373, -0.1891356],
 [51.458373, -0.1891356],
 [51.4611509, -0.0073177],
 [51.458373, -0.1891356],
 [51.577924, 0.2120829],
 [51.4935082, -0.1178424],
 [51.406025, 0.013156],
 [51.458373, -0.1891356],
 [51.4990805, -0.1938253],
 [51.6569225, -0.1949252],
 [51.6569225, -0.1949252],
 [51.5672808, -0.2710568],
 [51.5132537, -0.3043136],
 [51.5886383, -0.0117625],
 [51.458373, -0.1891356],
 [51.3769529, -0.0956895],
 [51.5390261, -0.1425516],
 [51.4990156, -0.22915],
 [51.3769529, -0.0956895],
 [51.5886121, 0.0823982],
 [51.406025, 0.013156],
 [51.5202607, -0.0293396],
 [51.461311, -0.303742],
 [51.580559, -0.341995],
 [51.6569225, -0.1949252],
 [51.5390261, -0.1425516],
 [51.406025, 0.013156],
 [51.5886121, 0.0823982],
 [51.538621, -0.1028346],
 [51.461311, -0.303742],
 [51.461311, -0.303742],
 [51.5886121, 0.0823982],
 [51.6569225, -0.1949252],
 [51.580559, -0.341995],
 [51.5906113, -0.1109709],
 [51.4990805, -0.1938253],
 [51.461311, -0.303742],
 [51.580559, -0.341995],
 [51.4990156, -0.22915],
 [51.5351832, -0.4481378],
 [51.5132537, -0.3043136],
 [51.5255162, 0.0352163],
 [51.5255162, 0.0352163],
 [51.538621, -0.1028346],
 [51.4609218, -0.373149],
 [51.5390261, -0.1425516],
 [51.5202607, -0.0293396],
 [51.580559, -0.341995],
 [51.458373, -0.1891356],
 [51.4609218, -0.373149],
 [51.4990156, -0.22915],
 [51.4609218, -0.373149],
 [51.4935082, -0.1178424],
 [51.5390261, -0.1425516],
 [51.461311, -0.303742],
 [51.5132537, -0.3043136],
 [51.461311, -0.303742],
 [51.3769529, -0.0956895],
 [51.5540666, 0.134017],
 [51.4933675, 0.0098214],
 [51.4609218, -0.373149],
 [51.461311, -0.303742],
 [51.5906113, -0.1109709],
 [51.5255162, 0.0352163],
 [51.580559, -0.341995],
 [51.5886121, 0.0823982],
 [51.458373, -0.1891356],
 [51.5886121, 0.0823982],
 [51.4990156, -0.22915],
 [51.6569225, -0.1949252],
 [51.5672808, -0.2710568],
 [51.5672808, -0.2710568],
 [51.538621, -0.1028346],
 [51.5540666, 0.134017],
 [51.406025, 0.013156],
 [51.461311, -0.303742],
 [51.406025, 0.013156],
 [51.5132537, -0.3043136],
 [51.406025, 0.013156],
 [51.461311, -0.303742],
 [51.4933675, 0.0098214],
 [51.5436387, -0.0553621],
 [51.4609218, -0.373149],
 [51.4609218, -0.373149],
 [51.538621, -0.1028346],
 [51.461311, -0.303742],
 [51.538621, -0.1028346],
 [51.4990156, -0.22915],
 [51.4935082, -0.1178424],
 [51.3769529, -0.0956895],
 [51.4097742, -0.2108084],
 [51.41233, -0.300689],
 [51.406025, 0.013156],
 [51.5351832, -0.4481378],
 [51.5132537, -0.3043136],
 [51.538621, -0.1028346],
 [51.41233, -0.300689],
 [51.538621, -0.1028346],
 [51.4990805, -0.1938253],
 [51.5436387, -0.0553621],
 [51.4609218, -0.373149],
 [51.538621, -0.1028346],
 [51.4974948, -0.1356583],
 [51.4935082, -0.1178424],
 [51.4609218, -0.373149],
 [51.458373, -0.1891356],
 [51.5255162, 0.0352163],
 [51.3769529, -0.0956895],
 [51.4609218, -0.373149],
 [51.4974948, -0.1356583],
 [51.538621, -0.1028346],
 [51.538621, -0.1028346],
 [51.458373, -0.1891356],
 [51.4609218, -0.373149],
 [51.461311, -0.303742],
 [51.5202607, -0.0293396],
 [51.458373, -0.1891356],
 [51.4935082, -0.1178424],
 [51.4933675, 0.0098214],
 [51.3769529, -0.0956895],
 [51.4990156, -0.22915],
 [51.5390261, -0.1425516],
 [51.4097742, -0.2108084],
 [51.4990805, -0.1938253],
 [51.4097742, -0.2108084],
 [51.5202607, -0.0293396],
 [51.580559, -0.341995],
 [51.577924, 0.2120829],
 [51.4974948, -0.1356583],
 [51.406025, 0.013156],
 [51.5886121, 0.0823982],
 [51.5436387, -0.0553621],
 [51.5351832, -0.4481378],
 [51.580559, -0.341995],
 [51.4974948, -0.1356583],
 [51.502781, -0.087738],
 [51.4609218, -0.373149],
 [51.5255162, 0.0352163],
 [51.580559, -0.341995],
 [51.5886383, -0.0117625],
 [51.4990805, -0.1938253],
 [51.502781, -0.087738],
 [51.3769529, -0.0956895],
 [51.577924, 0.2120829],
 [51.577924, 0.2120829],
 [51.406025, 0.013156],
 [51.4990156, -0.22915],
 [51.538621, -0.1028346],
 [51.4609218, -0.373149],
 [51.406025, 0.013156],
 [51.5390261, -0.1425516],
 [51.4990805, -0.1938253],
 [51.4990805, -0.1938253],
 [51.4935082, -0.1178424],
 [51.406025, 0.013156],
 [51.4933675, 0.0098214],
 [51.458373, -0.1891356],
 [51.6569225, -0.1949252],
 [51.458373, -0.1891356],
 [51.577924, 0.2120829],
 [51.502781, -0.087738],
 [51.5886121, 0.0823982],
 [51.4990156, -0.22915],
 [51.5886121, 0.0823982],
 [51.577924, 0.2120829],
 [51.4611509, -0.0073177],
 [51.4611509, -0.0073177]]

# %%
# Distance to the nearest outstanding school feature 
# this code can be placed in the while loop constructing all of the houses and their features

lat_example = houses['59, Bateman Close, Barking, Greater London IG11 8QS']["latitude"]
lon_example = houses['59, Bateman Close, Barking, Greater London IG11 8QS']["longitude"]

coords_1 = (lat_example, lon_example)
lower_boundary, upper_boundary = -0.05, 0.05
school_distances = []
for i in outstanding_schools:
    if (i[0] - lat_example > upper_boundary) or i[0] - lat_example < lower_boundary:
        continue
    elif (i[1] - lon_example > upper_boundary) or i[1] - lon_example < lower_boundary:
        continue
    else:
        coords_2 = (i[0], i[1])
        school_distances.append(geopy.distance.geodesic(coords_1, coords_2).km)

min(school_distances)
# Out:
# 3.7150173193710945

# %%
# Approach to help find the prices of nearby, similar properties
# THIS CODE NEEDS TO BE PERFORMED AFTER ALL OF THE HOUSES ARE STORED
# or even you could it after each URL iteration of the local area URL's, to save looping through all of the houses

######################## DO NOT RUN THIS CODE ##################


for i, v in houses.items():
    local_similar_prices = []
    # need to store the postcode, each house has a postcode so this will be easier
    postcode = i[-8:]
    if postcode[0] == " ":
        postcode = i[-7:]
    postcode_area = postcode.split(" ")[0]
    prop_type = v["property_type"]
    
    for a, b in houses.items():
        postcode = i[-8:]
        if postcode[0] == " ":
            postcode = i[-7:]
        postcode_area1 = postcode.split(" ")[0]
        if postcode_area == postcode_area1:
            if b["property_type"] == prop_type:
                local_similar_prices.append(b['price'])
    
    avg_local_price = avg(local_similar_prices)
    v["avg_local_price"] = avg_local_price
    
####################################################################
# Out:
# RM9
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# RM9
# IG11
# IG11
# IG1
# IG11
# RM9
# RM9
# IG11
# IG11
# IG11
# RM9
# IG11
# IG11
# IG11
# RM9
# RM9
# IG11
# IG3
# IG11
# IG11
# IG1
# RM8
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# RM9
# IG11
# RM8
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# RM8
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# RM9
# RM9
# IG11
# IG11
# RM9
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# RM9
# IG11
# IG11
# IG11
# IG3
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG1
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# RM9
# IG11
# IG11
# IG11
# IG11
# RM9
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG3
# IG11
# IG11
# IG11
# IG11
# RM8
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG3
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# RM9
# IG3
# RM9
# IG11
# IG11
# IG11
# IG11
# IG3
# IG11
# IG11
# IG11
# RM9
# IG11
# IG11
# IG11
# IG11
# RM9
# RM9
# IG11
# IG11
# IG3
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# RM9
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# RM9
# RM8
# RM9
# IG11
# IG11
# RM9
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# RM9
# IG3
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# RM9
# IG11
# IG11
# IG11
# IG11
# IG11
# RM9
# IG11
# RM9
# IG11
# IG11
# IG11
# IG11
# IG11
# IG1
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG1
# IG11
# IG11
# RM9
# IG11
# IG1
# IG11
# IG3
# IG11
# IG11
# IG11
# IG11
# IG11
# RM9
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG3
# IG3
# IG11
# IG11
# IG11
# RM9
# IG11
# IG11
# IG11
# IG11
# RM8
# IG11
# IG11
# IG11
# IG11
# RM8
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG3
# IG11
# RM9
# RM9
# IG11
# IG11
# RM9
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG1
# RM9
# IG11
# IG11
# IG3
# IG11
# IG11
# RM9
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# RM9
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# RM9
# IG11
# IG11
# IG3
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG3
# IG11
# IG11
# IG11
# IG3
# IG11
# IG11
# IG3
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG3
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# RM9
# RM9
# RM9
# IG11
# IG11
# RM9
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG3
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# RM9
# IG11
# IG11
# RM9
# IG11
# IG11
# IG11
# RM9
# IG11
# IG11
# IG11
# IG3
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG3
# IG11
# IG11
# IG11
# IG11
# IG1
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# RM9
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# RM8
# IG11
# IG1
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG1
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# RM9
# IG1
# IG3
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# RM9
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# RM9
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG1
# IG11
# IG11
# IG11
# IG11
# RM8
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# RM8
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG1
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# RM8
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# RM9
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG3
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# RM8
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# RM8
# IG11
# IG11
# IG11
# IG11
# IG11
# RM8
# IG11
# IG11
# IG11
# IG11
# RM8
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# RM8
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG1
# IG11
# RM8
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG3
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG1
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# RM9
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# RM8
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# RM8
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# RM9
# IG11
# IG11
# IG11
# IG11
# IG3
# RM8
# IG11
# IG1
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG3
# IG11
# RM8
# IG11
# IG11
# IG11
# IG3
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# RM9
# RM8
# RM8
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG3
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG3
# IG11
# IG11
# RM8
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# RM8
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG3
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# RM8
# RM8
# IG11
# IG11
# IG11
# IG11
# IG11
# RM9
# RM8
# RM9
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG3
# IG11
# IG11
# IG11
# IG11
# IG11
# RM9
# IG11
# IG11
# IG1
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# IG11
# RM9
# IG11
# RM9
# IG11
# IG11
# IG11
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
# RM10
